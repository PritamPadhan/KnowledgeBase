# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pdf_path = "/content/drive/MyDrive/KnowledgeDatabase/R048r12e.pdf"

# %%
store_dir = "/content/drive/MyDrive/KnowledgeGraphResults"

# %%
import os

# %%
os.path.exists(store_dir),os.path.exists(pdf_path)
# Out:
# (True, True)

# %%
# prompt: check current working directory

print(os.getcwd())
# Out:
# /content

# %%
os.chdir("/content/drive/MyDrive/")

# %% [markdown]
# # Using LLM Approach :

# %%
! pip install pymupdf
# Out:
# Collecting pymupdf
#   Downloading pymupdf-1.25.2-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.25.2-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 64.8 MB/s eta 0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.25.2

# %%
import os
import json
import re
import fitz  # PyMuPDF for PDF text extraction
import networkx as nx
from transformers import pipeline

def extract_text(file_path):
    """
    Extracts text from a PDF file using PyMuPDF.
    """
    text = ""
    # Open the PDF file
    with fitz.open(file_path) as pdf:
        for page_num in range(len(pdf)):
            page = pdf[page_num]
            # Extract text from each page
            text += page.get_text()
    return text

def clean_text(raw_text):
    """
    Cleans and structures text while retaining key content.
    """
    # Normalize whitespace
    cleaned_text = re.sub(r"[ \t]+", " ", raw_text)  # Replace tabs and multiple spaces with single space

    # Remove headers, footers, and artifacts
    cleaned_text = re.sub(r"E/ECE/.*", "", cleaned_text)  # Remove specific headers
    cleaned_text = re.sub(r"Page\s*\d+", "", cleaned_text)  # Remove page numbers
    cleaned_text = re.sub(r"GE\.\d+-", "", cleaned_text)  # Remove generic document codes

    # Add newline before numbered sections or headings for better segmentation
    cleaned_text = re.sub(r"(\d+\.\s+[A-Z].*?:)", r"\n\1\n", cleaned_text)

    # Retain numbered lists while removing excess formatting
    cleaned_text = re.sub(r"\s{2,}", " ", cleaned_text)  # Reduce multiple spaces
    cleaned_text = re.sub(r"(\d+\.?\d*)\s+", r"\1 ", cleaned_text)  # Remove spaces within numbered lists

    # Remove excessive newlines
    cleaned_text = re.sub(r"\n\s*\n+", "\n\n", cleaned_text)
    # Convert all text to lowercase
    cleaned_text = cleaned_text.lower()

    return cleaned_text


def save_text_to_file(text, output_path):
    with open(output_path, "w", encoding="utf-8") as file:
        file.write(text)

# %%
extracted_text = extract_text(pdf_path)
cleaned_text = clean_text(extracted_text)
cleaned_txt_path = "/content/drive/MyDrive/KnowledgeGraphResults/cleaned_text1.txt"
save_text_to_file(cleaned_text, cleaned_txt_path)

# %%
len(cleaned_text)
# Out:
# 250574

# %%
import time
import json
from transformers import pipeline
import numpy as np

def extract_entities(text, chunk_size=1000):
    """
    Extract entities from a large text using a pre-trained NER model with time estimation.
    """
    # Load the NER pipeline
    ner_pipeline = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", grouped_entities=True)

    entities = []
    text_chunks = [text[i:i+chunk_size] for i in range(0, len(text), chunk_size)]
    total_chunks = len(text_chunks)

    start_time = time.time()  # Start timer

    for idx, chunk in enumerate(text_chunks):
        chunk_start_time = time.time()  # Start time for this chunk

        # Process the current chunk
        chunk_entities = ner_pipeline(chunk)
        entities.extend(chunk_entities)

        # Estimate time remaining
        elapsed_time = time.time() - start_time
        avg_time_per_chunk = elapsed_time / (idx + 1)
        remaining_chunks = total_chunks - (idx + 1)
        estimated_time_remaining = avg_time_per_chunk * remaining_chunks

        print(f"Processed chunk {idx + 1}/{total_chunks}. "
              f"Estimated time remaining: {estimated_time_remaining:.2f} seconds.")

    return entities

def json_serializable(obj):
    """
    Custom function to convert non-serializable objects to serializable types.
    """
    if isinstance(obj, np.float32):  # Convert NumPy float32 to Python float
        return float(obj)
    if isinstance(obj, np.integer):  # Convert NumPy int to Python int
        return int(obj)
    return str(obj)  # Fallback: convert to string

# Extract entities with progress tracking
entities = extract_entities(cleaned_text)

# Save extracted entities to a JSON file
entities_json_path = "/content/drive/MyDrive/KnowledgeGraphResults/extracted_entities.json"
with open(entities_json_path, "w", encoding="utf-8") as file:
    json.dump(entities, file, indent=4, default=json_serializable)

print(f"Extracted {len(entities)} entities. Results saved to {entities_json_path}.")

# %%
! pip install transformers datasets torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.47.1)
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.11)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 9.4 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 12.7 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 14.4 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 19.6 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
import re
import json
from transformers import AutoTokenizer, AutoModelForTokenClassification, Trainer, TrainingArguments, pipeline
from datasets import Dataset
import evaluate

def preprocess_text(text):
    """
    Normalize text: remove unnecessary headings, extra whitespace, and format sections.
    """
    text = re.sub(r"Page\s*\d+", "", text)  # Remove page numbers
    text = re.sub(r"[ \t]+", " ", text)  # Normalize whitespace
    text = re.sub(r"\n\s*\n+", "\n\n", text)  # Remove excessive newlines
    return text.strip()

def chunk_text_by_sections(text):
    """
    Split text into logical sections based on headings or numbering patterns.
    """
    sections = re.split(r"^\d+\.\s|\n\d+\.\d+\.\s", text, flags=re.MULTILINE)  # Split on numbered sections
    return [section.strip() for section in sections if section.strip()]

def extract_labeled_data(text):
    """
    Automatically extract labeled examples from the text for NER fine-tuning.
    """
    labeled_data = []
    sentences = re.split(r"\. |\n", text)  # Split text into sentences

    for sentence in sentences:
        entities = []

        # Technical terms
        for match in re.finditer(r"\b[A-Za-z]+(?:[- ]?[A-Za-z]+)* system\b", sentence):
            entities.append({"start": match.start(), "end": match.end(), "label": "TECH_TERM"})

        # Dates
        for match in re.finditer(r"\b\d{1,2}\s\w+\s\d{4}\b", sentence):
            entities.append({"start": match.start(), "end": match.end(), "label": "DATE"})

        # Section references
        for match in re.finditer(r"paragraph\s\d+\.\d+", sentence, flags=re.IGNORECASE):
            entities.append({"start": match.start(), "end": match.end(), "label": "SECTION_REF"})

        if entities:
            labeled_data.append({"text": sentence.strip(), "entities": entities})

    return labeled_data


def fine_tune_ner_model(labeled_data, model_name="bert-base-uncased", num_epochs=3):
    """
    Fine-tune a pre-trained transformer model for domain-specific NER.
    """
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForTokenClassification.from_pretrained(model_name, num_labels=3)

    # Prepare datasets
    def tokenize_and_align_labels(examples):
        tokenized_inputs = tokenizer(examples["text"], truncation=True, padding=True)
        labels = []
        for i, label in enumerate(examples["entities"]):
            tokens = tokenized_inputs.tokens(i)
            label_ids = [0] * len(tokens)
            for entity in label:
                start, end, tag = entity["start"], entity["end"], entity["label"]
                for idx, token in enumerate(tokens):
                    if start <= token.offset and token.offset < end:
                        label_ids[idx] = tag
            labels.append(label_ids)
        tokenized_inputs["labels"] = labels
        return tokenized_inputs

    dataset = Dataset.from_list(labeled_data)
    tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)

    # Split into train and validation sets
    train_test_split = tokenized_dataset.train_test_split(test_size=0.2)
    train_dataset = train_test_split["train"]
    val_dataset = train_test_split["test"]

    # Evaluation metric
    metric = evaluate.load("seqeval")  # Use the seqeval metric for NER

    def compute_metrics(p):
        predictions, labels = p
        predictions = predictions.argmax(axis=2)
        true_predictions = [
            [model.config.id2label[p] for p, l in zip(pred, label) if l != -100]
            for pred, label in zip(predictions, labels)
        ]
        true_labels = [
            [model.config.id2label[l] for p, l in zip(pred, label) if l != -100]
            for pred, label in zip(predictions, labels)
        ]
        results = metric.compute(predictions=true_predictions, references=true_labels)
        return {"precision": results["overall_precision"], "recall": results["overall_recall"], "f1": results["overall_f1"]}

    # Training arguments
    training_args = TrainingArguments(
        output_dir="./results",
        evaluation_strategy="epoch",
        learning_rate=2e-5,
        per_device_train_batch_size=8,
        num_train_epochs=num_epochs,
        weight_decay=0.01,
        save_total_limit=2,
        logging_dir="./logs",
    )

    # Trainer
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=val_dataset,
        tokenizer=tokenizer,
        compute_metrics=compute_metrics
    )
    trainer.train()

    return trainer, model, tokenizer


def apply_fine_tuned_model(text, model, tokenizer):
    """
    Use the fine-tuned model for inference on new text.
    """
    ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer, grouped_entities=True)
    return ner_pipeline(text)

# Main pipeline
def main_pipeline(file_path):
    # Step 1: Load and preprocess the text
    with open(file_path, "r", encoding="utf-8") as file:
        raw_text = file.read()

    normalized_text = preprocess_text(raw_text)
    sections = chunk_text_by_sections(normalized_text)

    # Step 2: Extract labeled data
    labeled_data = []
    for section in sections:
        labeled_data.extend(extract_labeled_data(section))

    # Step 3: Fine-tune the NER model
    trainer, fine_tuned_model, tokenizer = fine_tune_ner_model(labeled_data)

    # Step 4: Apply the fine-tuned model to the text
    ner_results = []
    for section in sections:
        ner_results.append(apply_fine_tuned_model(section, fine_tuned_model, tokenizer))

    return ner_results

# Run the pipeline
file_path = "/content/drive/MyDrive/KnowledgeGraphResults/cleaned_text1.txt"
results = main_pipeline(file_path)

# Save results to a file
results_path = "/content/drive/MyDrive/KnowledgeGraphResults/extracted_entities.json"
with open(results_path, "w", encoding="utf-8") as file:
    json.dump(results, file, indent=4)

print(f"NER results saved to {results_path}.")

# %%
! pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.2.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.9.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.27.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.17.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.11.11)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
import spacy

def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(f"{ent.text} - {ent.start_char} - {ent.end_char} - {ent.label_} - {spacy.explain(ent.label_)}")
    else:
        print("No named entities found.")

# Example usage:
nlp = spacy.load("en_core_web_sm")
text = "Research suggests that including apples in a balanced diet may promote weight loss and improve overall health. Apples have several properties, for example, that may boost blood sugar control, heart health, and brain function. Regarding weight loss, it’s worth noting that apples are high in water, low in calorie density, and low in overall calories."

doc = nlp(text)
show_ents(doc)
# Out:
# No named entities found.

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char,ent.label_)
# Out:
# Apple 0 5 ORG
# Steve Jobs 21 31 PERSON
# Cupertino 35 44 GPE
# California 46 56 GPE

# %%
import spacy

# Function to display named entities
def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(f"{ent.text} - {ent.start_char} - {ent.end_char} - {ent.label_} - {spacy.explain(ent.label_)}")
    else:
        print("No named entities found.")

# Load spaCy model
nlp = spacy.load("en_core_web_lg")

# Read a large text file
file_path = "/content/drive/MyDrive/KnowledgeGraphResults/cleaned_text1.txt"  # Replace with your actual file path
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()  # Read the entire file into a string

# Process the text with spaCy
doc = nlp(text)

# Show named entities
show_ents(doc)
# Out:
# /usr/local/lib/python3.11/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# 2 - 281 - 282 - CARDINAL - Numerals that do not fall under another type
# 16 october 1995 - 336 - 351 - DATE - Absolute or relative dates or periods
# 47 - 362 - 364 - CARDINAL - Numerals that do not fall under another type
# 48 - 381 - 383 - CARDINAL - Numerals that do not fall under another type
# 12 - 393 - 395 - CARDINAL - Numerals that do not fall under another type
# 06 - 430 - 432 - CARDINAL - Numerals that do not fall under another type
# 1 - 466 - 467 - CARDINAL - Numerals that do not fall under another type
# 06 - 475 - 477 - CARDINAL - Numerals that do not fall under another type
# 15 july 2013 - 544 - 556 - DATE - Absolute or relative dates or periods
# 1 - 569 - 570 - CARDINAL - Numerals that do not fall under another type
# 1 - 585 - 586 - CARDINAL - Numerals that do not fall under another type
# 06 - 594 - 596 - CARDINAL - Numerals that do not fall under another type
# 13 - 664 - 666 - CARDINAL - Numerals that do not fall under another type
# march 2013 - 667 - 677 - DATE - Absolute or relative dates or periods
# 2 - 689 - 690 - CARDINAL - Numerals that do not fall under another type
# 06 - 698 - 700 - CARDINAL - Numerals that do not fall under another type
# 3 - 767 - 768 - CARDINAL - Numerals that do not fall under another type
# november 2013 - 769 - 782 - DATE - Absolute or relative dates or periods
# 3 - 794 - 795 - CARDINAL - Numerals that do not fall under another type
# 06 - 803 - 805 - CARDINAL - Numerals that do not fall under another type
# 10 june 2014 - 872 - 884 - DATE - Absolute or relative dates or periods
# 4 - 896 - 897 - CARDINAL - Numerals that do not fall under another type
# 06 - 905 - 907 - CARDINAL - Numerals that do not fall under another type
# 9 october 2014 - 974 - 988 - DATE - Absolute or relative dates or periods
# geneva - 1319 - 1325 - GPE - Countries, cities, states
# 20 march 1958 - 1329 - 1342 - DATE - Absolute or relative dates or periods
# 16 october 2014 - 1344 - 1359 - DATE - Absolute or relative dates or periods
# 48 - 1377 - 1379 - CARDINAL - Numerals that do not fall under another type
# 1 - 1533 - 1534 - CARDINAL - Numerals that do not fall under another type
# 5 2 - 1685 - 1688 - CARDINAL - Numerals that do not fall under another type
# 5 3 - 1839 - 1842 - CARDINAL - Numerals that do not fall under another type
# 19 4 - 1984 - 1988 - CARDINAL - Numerals that do not fall under another type
# ...................................................................................................................... - 2166 - 2284 - CARDINAL - Numerals that do not fall under another type
# 21 6 - 2285 - 2289 - CARDINAL - Numerals that do not fall under another type
# 30 7 - 2432 - 2436 - CARDINAL - Numerals that do not fall under another type
# 85 8 - 2664 - 2668 - CARDINAL - Numerals that do not fall under another type
# 86 9 - 2808 - 2812 - CARDINAL - Numerals that do not fall under another type
# 86 10 - 2943 - 2948 - CARDINAL - Numerals that do not fall under another type
# 86 11 - 3084 - 3089 - CARDINAL - Numerals that do not fall under another type
# 87 12 - 3315 - 3320 - CARDINAL - Numerals that do not fall under another type
# 87 - 3463 - 3465 - CARDINAL - Numerals that do not fall under another type
# 1 - 3474 - 3475 - CARDINAL - Numerals that do not fall under another type
# 91 2 - 3619 - 3623 - CARDINAL - Numerals that do not fall under another type
# 3 - 3760 - 3761 - CARDINAL - Numerals that do not fall under another type
# 96 4 - 3866 - 3870 - CARDINAL - Numerals that do not fall under another type
# 109 5 - 3986 - 3991 - CARDINAL - Numerals that do not fall under another type
# 110 6 - 4212 - 4217 - CARDINAL - Numerals that do not fall under another type
# 112 7 - 4326 - 4331 - CARDINAL - Numerals that do not fall under another type
# 6.2.6.1.1 - 4433 - 4442 - CARDINAL - Numerals that do not fall under another type
# 6.3.6.1.2 - 4524 - 4533 - CARDINAL - Numerals that do not fall under another type
# 117 8 - 4647 - 4652 - CARDINAL - Numerals that do not fall under another type
# 6.2.6.2.2 - 4726 - 4735 - CARDINAL - Numerals that do not fall under another type
# 118 9 - 4893 - 4898 - CARDINAL - Numerals that do not fall under another type
# 120 10 - 5032 - 5038 - CARDINAL - Numerals that do not fall under another type
# 123 11 - 5186 - 5192 - CARDINAL - Numerals that do not fall under another type
# 124 - 5309 - 5312 - CARDINAL - Numerals that do not fall under another type
# 12 - 5315 - 5317 - CARDINAL - Numerals that do not fall under another type
# 129 14 - 5591 - 5597 - CARDINAL - Numerals that do not fall under another type
# 130 - 5702 - 5705 - CARDINAL - Numerals that do not fall under another type
# 2.34 - 5796 - 5800 - CARDINAL - Numerals that do not fall under another type
# 131 - 5921 - 5924 - CARDINAL - Numerals that do not fall under another type
# 2 - 6102 - 6103 - CARDINAL - Numerals that do not fall under another type
# 2.1 - 6153 - 6156 - CARDINAL - Numerals that do not fall under another type
# 2.2 - 6316 - 6319 - CARDINAL - Numerals that do not fall under another type
# 2.2 - 6504 - 6507 - CARDINAL - Numerals that do not fall under another type
# 4 - 6509 - 6510 - CARDINAL - Numerals that do not fall under another type
# 2.2.4 - 6657 - 6662 - CARDINAL - Numerals that do not fall under another type
# 2.2.1 - 6927 - 6932 - CARDINAL - Numerals that do not fall under another type
# 2.2.2 - 6987 - 6992 - CARDINAL - Numerals that do not fall under another type
# 2.2.3 - 7037 - 7042 - PRODUCT - Objects, vehicles, foods, etc. (not services)
# 2.2.4 - 7075 - 7080 - CARDINAL - Numerals that do not fall under another type
# 2.3 - 7105 - 7108 - CARDINAL - Numerals that do not fall under another type
# 2.4 - 7215 - 7218 - CARDINAL - Numerals that do not fall under another type
# 2.5 - 7373 - 7376 - CARDINAL - Numerals that do not fall under another type
# 5 - 7609 - 7610 - CARDINAL - Numerals that do not fall under another type
# 2.6 - 7612 - 7615 - CARDINAL - Numerals that do not fall under another type
# one - 7686 - 7689 - CARDINAL - Numerals that do not fall under another type
# 2.6.1 - 7709 - 7714 - CARDINAL - Numerals that do not fall under another type
# 2 - www.unece.org/trans/main/wp29/wp29wgs/wp29gen/wp29resolutions.html - 8181 - 8251 - TIME - Times smaller than a day
# 6 2.7 - 8252 - 8257 - CARDINAL - Numerals that do not fall under another type
# 107 - 8608 - 8611 - CARDINAL - Numerals that do not fall under another type
# m3 - 8645 - 8647 - PERSON - People, including fictional
# 2.7.1.1 - 8697 - 8704 - CARDINAL - Numerals that do not fall under another type
# one - 8727 - 8730 - CARDINAL - Numerals that do not fall under another type
# one - 8799 - 8802 - CARDINAL - Numerals that do not fall under another type
# 2.7.1.1.1 - 8891 - 8900 - CARDINAL - Numerals that do not fall under another type
# 2.7.1.1.2 - 9042 - 9051 - CARDINAL - Numerals that do not fall under another type
# 2.7.1.1.3 - 9526 - 9535 - CARDINAL - Numerals that do not fall under another type
# one - 9639 - 9642 - CARDINAL - Numerals that do not fall under another type
# one - 9711 - 9714 - CARDINAL - Numerals that do not fall under another type
# 2.7.1.1.4 - 9771 - 9780 - CARDINAL - Numerals that do not fall under another type
# one - 9886 - 9889 - CARDINAL - Numerals that do not fall under another type
# 2.7.1.1.5 - 9944 - 9953 - CARDINAL - Numerals that do not fall under another type
# one - 10227 - 10230 - CARDINAL - Numerals that do not fall under another type
# 2.7.1.1.7 - 10308 - 10317 - CARDINAL - Numerals that do not fall under another type
# one - 10433 - 10436 - CARDINAL - Numerals that do not fall under another type
# 2.7.1.2 - 10493 - 10500 - CARDINAL - Numerals that do not fall under another type
# one - 10547 - 10550 - CARDINAL - Numerals that do not fall under another type
# 2.7.1.2.2 - 10973 - 10982 - CARDINAL - Numerals that do not fall under another type
# 7 - 11090 - 11091 - CARDINAL - Numerals that do not fall under another type
# 2.7.2 - 11423 - 11428 - CARDINAL - Numerals that do not fall under another type
# 2.7.3 - 11722 - 11727 - CARDINAL - Numerals that do not fall under another type
# axis,2 - 11831 - 11837 - NORP - Nationalities or religious or political groups
# 2.7.4 - 12032 - 12037 - DATE - Absolute or relative dates or periods
# axis2 - 12137 - 12142 - NORP - Nationalities or religious or political groups
# 2.7.5 - 12195 - 12200 - CARDINAL - Numerals that do not fall under another type
# axis,2 - 12301 - 12307 - PERSON - People, including fictional
# axis2 - 12645 - 12650 - NORP - Nationalities or religious or political groups
# 2.7.10.1 - 13489 - 13497 - CARDINAL - Numerals that do not fall under another type
# 2 - 13680 - 13681 - CARDINAL - Numerals that do not fall under another type
# 5 - 13785 - 13786 - CARDINAL - Numerals that do not fall under another type
# 3 - 13838 - 13839 - CARDINAL - Numerals that do not fall under another type
# 3 - 13936 - 13937 - CARDINAL - Numerals that do not fall under another type
# 7 - 13944 - 13945 - CARDINAL - Numerals that do not fall under another type
# 8 2.7.11 - 13947 - 13955 - CARDINAL - Numerals that do not fall under another type
# 97 - 14208 - 14210 - CARDINAL - Numerals that do not fall under another type
# 2.7.12 - 14212 - 14218 - CARDINAL - Numerals that do not fall under another type
# 2.7.13 - 14382 - 14388 - CARDINAL - Numerals that do not fall under another type
# 2.7.16.1 - 15145 - 15153 - CARDINAL - Numerals that do not fall under another type
# european - 15248 - 15256 - NORP - Nationalities or religious or political groups
# 2.7.16.4 - 15526 - 15534 - CARDINAL - Numerals that do not fall under another type
# 104 - 15614 - 15617 - CARDINAL - Numerals that do not fall under another type
# 2.7.17.1.1 - 16184 - 16194 - CARDINAL - Numerals that do not fall under another type
# 2.7.17.1.2 - 16307 - 16317 - CARDINAL - Numerals that do not fall under another type
# 9 2.7.19 - 16857 - 16865 - CARDINAL - Numerals that do not fall under another type
# 2.7.20 - 17026 - 17032 - CARDINAL - Numerals that do not fall under another type
# 2.7.22 - 17311 - 17317 - CARDINAL - Numerals that do not fall under another type
# 2.7.24 - 17869 - 17875 - CARDINAL - Numerals that do not fall under another type
# 2.7.25 - 17981 - 17987 - TIME - Times smaller than a day
# daytime - 17990 - 17997 - TIME - Times smaller than a day
# daytime - 18120 - 18127 - TIME - Times smaller than a day
# 2.7.26 - 18129 - 18135 - CARDINAL - Numerals that do not fall under another type
# 2.7.28 - 18835 - 18841 - DATE - Absolute or relative dates or periods
# 123 - 18954 - 18957 - CARDINAL - Numerals that do not fall under another type
# one - 19241 - 19244 - CARDINAL - Numerals that do not fall under another type
# one - 19387 - 19390 - CARDINAL - Numerals that do not fall under another type
# 10 2.7.28.4 - 19622 - 19633 - CARDINAL - Numerals that do not fall under another type
# 2.7.28.5 - 19800 - 19808 - CARDINAL - Numerals that do not fall under another type
# 6.22.7.4 - 19904 - 19912 - CARDINAL - Numerals that do not fall under another type
# 2.7.28.7 - 20174 - 20182 - CARDINAL - Numerals that do not fall under another type
# 2.7.29 - 20445 - 20451 - CARDINAL - Numerals that do not fall under another type
# 2.7.30 - 20625 - 20631 - CARDINAL - Numerals that do not fall under another type
# two - 20683 - 20686 - CARDINAL - Numerals that do not fall under another type
# three - 20690 - 20695 - CARDINAL - Numerals that do not fall under another type
# 2.7.30.1 - 20746 - 20754 - CARDINAL - Numerals that do not fall under another type
# 2.7.31 - 21035 - 21041 - CARDINAL - Numerals that do not fall under another type
# 2.8 - 21179 - 21182 - CARDINAL - Numerals that do not fall under another type
# 3 - 21398 - 21399 - CARDINAL - Numerals that do not fall under another type
# 1 - 21416 - 21417 - CARDINAL - Numerals that do not fall under another type
# 4 - 21423 - 21424 - CARDINAL - Numerals that do not fall under another type
# one - 21463 - 21466 - CARDINAL - Numerals that do not fall under another type
# 3 - 21811 - 21812 - CARDINAL - Numerals that do not fall under another type
# 5 - 21828 - 21829 - CARDINAL - Numerals that do not fall under another type
# 2.8.1 - 21832 - 21837 - CARDINAL - Numerals that do not fall under another type
# 2.9 - 22093 - 22096 - CARDINAL - Numerals that do not fall under another type
# 3 - 22132 - 22133 - CARDINAL - Numerals that do not fall under another type
# 2.9.1 - 22136 - 22141 - CARDINAL - Numerals that do not fall under another type
# 2.7.9 - 22199 - 22204 - CARDINAL - Numerals that do not fall under another type
# 2.7.10. - 22207 - 22214 - PERCENT - Percentage, including "%"
# 2.7.19 - 22216 - 22222 - CARDINAL - Numerals that do not fall under another type
# 2.7.26 - 22237 - 22243 - CARDINAL - Numerals that do not fall under another type
# 2.9.2 - 22493 - 22498 - CARDINAL - Numerals that do not fall under another type
# 11 - 22683 - 22685 - CARDINAL - Numerals that do not fall under another type
# one - 22867 - 22870 - CARDINAL - Numerals that do not fall under another type
# two - 22993 - 22996 - CARDINAL - Numerals that do not fall under another type
# 6.22.4 - 23224 - 23230 - CARDINAL - Numerals that do not fall under another type
# 8 - 23298 - 23299 - CARDINAL - Numerals that do not fall under another type
# 9 - 23301 - 23302 - DATE - Absolute or relative dates or periods
# 11 - 23307 - 23309 - DATE - Absolute or relative dates or periods
# 2.9.2 - 23474 - 23479 - CARDINAL - Numerals that do not fall under another type
# 2.7.11 - 23574 - 23580 - CARDINAL - Numerals that do not fall under another type
# 2.7.18. - 23594 - 23601 - GPE - Countries, cities, states
# 2.7.20 - 23603 - 23609 - CARDINAL - Numerals that do not fall under another type
# 2.7.22 - 23615 - 23621 - CARDINAL - Numerals that do not fall under another type
# 2.7.25 - 23626 - 23632 - CARDINAL - Numerals that do not fall under another type
# only 98 per cent - 23889 - 23905 - MONEY - Monetary values, including unit
# two - 24309 - 24312 - CARDINAL - Numerals that do not fall under another type
# 3 - 24770 - 24771 - CARDINAL - Numerals that do not fall under another type
# 2 - 24779 - 24780 - CARDINAL - Numerals that do not fall under another type
# 3 - 24782 - 24783 - CARDINAL - Numerals that do not fall under another type
# 5 - 24785 - 24786 - DATE - Absolute or relative dates or periods
# 2.9.3 - 24795 - 24800 - CARDINAL - Numerals that do not fall under another type
# 2.7.16 - 24857 - 24863 - CARDINAL - Numerals that do not fall under another type
# 2.10 - 25338 - 25342 - CARDINAL - Numerals that do not fall under another type
# 2.7.1.3 - 25798 - 25805 - ORG - Companies, agencies, institutions, etc.
# 12 - 25908 - 25910 - CARDINAL - Numerals that do not fall under another type
# 3 - 26103 - 26104 - CARDINAL - Numerals that do not fall under another type
# 2.11 - 26125 - 26129 - CARDINAL - Numerals that do not fall under another type
# 0° - 26311 - 26313 - PERCENT - Percentage, including "%"
# 2.12 - 26408 - 26412 - CARDINAL - Numerals that do not fall under another type
# 2.13 - 26575 - 26579 - CARDINAL - Numerals that do not fall under another type
# 2.14 - 27091 - 27095 - CARDINAL - Numerals that do not fall under another type
# 2.14.1 - 27288 - 27294 - CARDINAL - Numerals that do not fall under another type
# 2.14.2 - 27395 - 27401 - CARDINAL - Numerals that do not fall under another type
# 2.14.3 - 27451 - 27457 - CARDINAL - Numerals that do not fall under another type
# 2.14.4 - 27491 - 27497 - CARDINAL - Numerals that do not fall under another type
# 2.14.5 - 27646 - 27652 - CARDINAL - Numerals that do not fall under another type
# 2.14.6 - 27750 - 27756 - CARDINAL - Numerals that do not fall under another type
# m3 - 27824 - 27826 - PERSON - People, including fictional
# 2.7 - 27853 - 27856 - CARDINAL - Numerals that do not fall under another type
# two - 27916 - 27919 - CARDINAL - Numerals that do not fall under another type
# 2.14 - 27957 - 27961 - CARDINAL - Numerals that do not fall under another type
# 2.15.1 - 27970 - 27976 - CARDINAL - Numerals that do not fall under another type
# two - 28025 - 28028 - CARDINAL - Numerals that do not fall under another type
# 2.14 - 28066 - 28070 - CARDINAL - Numerals that do not fall under another type
# 2.15.2 - 28079 - 28085 - CARDINAL - Numerals that do not fall under another type
# two - 28135 - 28138 - CARDINAL - Numerals that do not fall under another type
# 13 2.16 - 28551 - 28558 - CARDINAL - Numerals that do not fall under another type
# 2.16.1 - 28588 - 28594 - CARDINAL - Numerals that do not fall under another type
# one - 28659 - 28662 - CARDINAL - Numerals that do not fall under another type
# one - 28702 - 28705 - CARDINAL - Numerals that do not fall under another type
# one - 28734 - 28737 - CARDINAL - Numerals that do not fall under another type
# two - 28844 - 28847 - CARDINAL - Numerals that do not fall under another type
# two - 28895 - 28898 - CARDINAL - Numerals that do not fall under another type
# two - 29304 - 29307 - CARDINAL - Numerals that do not fall under another type
# 15 mm - 29359 - 29364 - QUANTITY - Measurements, as of weight or distance
# two - 29441 - 29444 - CARDINAL - Numerals that do not fall under another type
# two - 29849 - 29852 - CARDINAL - Numerals that do not fall under another type
# 15 mm - 29904 - 29909 - QUANTITY - Measurements, as of weight or distance
# two - 30013 - 30016 - CARDINAL - Numerals that do not fall under another type
# three - 30020 - 30025 - CARDINAL - Numerals that do not fall under another type
# 75 mm - 30231 - 30236 - QUANTITY - Measurements, as of weight or distance
# two - 30299 - 30302 - CARDINAL - Numerals that do not fall under another type
# at least 0.4 m - 30549 - 30563 - QUANTITY - Measurements, as of weight or distance
# less than two - 30697 - 30710 - CARDINAL - Numerals that do not fall under another type
# 2.17 - 31103 - 31107 - CARDINAL - Numerals that do not fall under another type
# two - 31127 - 31130 - CARDINAL - Numerals that do not fall under another type
# two - 31211 - 31214 - CARDINAL - Numerals that do not fall under another type
# 14 - 31328 - 31330 - CARDINAL - Numerals that do not fall under another type
# 2.18 - 31424 - 31428 - CARDINAL - Numerals that do not fall under another type
# 2.19 - 31594 - 31598 - CARDINAL - Numerals that do not fall under another type
# 2.20 - 31777 - 31781 - CARDINAL - Numerals that do not fall under another type
# 2.21 - 31886 - 31890 - CARDINAL - Numerals that do not fall under another type
# 2.22 - 31989 - 31993 - CARDINAL - Numerals that do not fall under another type
# 2.23 - 32227 - 32231 - CARDINAL - Numerals that do not fall under another type
# 2.24 - 32435 - 32439 - CARDINAL - Numerals that do not fall under another type
# 2.24.1 - 32487 - 32493 - CARDINAL - Numerals that do not fall under another type
# 2.23 - 32662 - 32666 - CARDINAL - Numerals that do not fall under another type
# 2.24.2 - 32669 - 32675 - CARDINAL - Numerals that do not fall under another type
# 2.24.1 - 32798 - 32804 - CARDINAL - Numerals that do not fall under another type
# 2.23 - 32887 - 32891 - CARDINAL - Numerals that do not fall under another type
# 2.25 - 32893 - 32897 - CARDINAL - Numerals that do not fall under another type
# 2.25.1 - 32936 - 32942 - CARDINAL - Numerals that do not fall under another type
# 2.23 - 33120 - 33124 - CARDINAL - Numerals that do not fall under another type
# 2.25.2 - 33127 - 33133 - CARDINAL - Numerals that do not fall under another type
# 2.25.1 - 33254 - 33260 - CARDINAL - Numerals that do not fall under another type
# 2.23 - 33343 - 33347 - CARDINAL - Numerals that do not fall under another type
# 2.26 - 33349 - 33353 - CARDINAL - Numerals that do not fall under another type
# 2.27 - 33440 - 33444 - CARDINAL - Numerals that do not fall under another type
# 2.27.1 - 33546 - 33552 - CARDINAL - Numerals that do not fall under another type
# 2.28 - 33724 - 33728 - CARDINAL - Numerals that do not fall under another type
# 15 2.29 - 33934 - 33941 - CARDINAL - Numerals that do not fall under another type
# 2.29.1 - 33985 - 33991 - CARDINAL - Numerals that do not fall under another type
# w12 green boundary - 34130 - 34148 - ORG - Companies, agencies, institutions, etc.
# 0.150 - 34153 - 34158 - CARDINAL - Numerals that do not fall under another type
# 0.640 - 34161 - 34166 - CARDINAL - Numerals that do not fall under another type
# 0.440 - 34202 - 34207 - CARDINAL - Numerals that do not fall under another type
# 0.500 - 34232 - 34237 - CARDINAL - Numerals that do not fall under another type
# 0.382 - 34270 - 34275 - CARDINAL - Numerals that do not fall under another type
# 0.050 - 34300 - 34305 - CARDINAL - Numerals that do not fall under another type
# 0.750 - 34308 - 34313 - CARDINAL - Numerals that do not fall under another type
# 0.310 - 34338 - 34343 - CARDINAL - Numerals that do not fall under another type
# 0.310 - 34377 - 34382 - CARDINAL - Numerals that do not fall under another type
# 0.453 0.440 - 34392 - 34403 - CARDINAL - Numerals that do not fall under another type
# 0.500 0.440 - 34407 - 34418 - CARDINAL - Numerals that do not fall under another type
# 0.382 - 34428 - 34433 - MONEY - Monetary values, including unit
# 0.310 - 34452 - 34457 - CARDINAL - Numerals that do not fall under another type
# sy12 - 34620 - 34624 - PERSON - People, including fictional
# 1.290 - 34644 - 34649 - CARDINAL - Numerals that do not fall under another type
# 0.100 - 34654 - 34659 - CARDINAL - Numerals that do not fall under another type
# 0.138 - 34706 - 34711 - CARDINAL - Numerals that do not fall under another type
# 0.580 - 34714 - 34719 - CARDINAL - Numerals that do not fall under another type
# 0.440 - 34756 - 34761 - CARDINAL - Numerals that do not fall under another type
# sy51 - 34762 - 34766 - PRODUCT - Objects, vehicles, foods, etc. (not services)
# 0.940 - 34786 - 34791 - CARDINAL - Numerals that do not fall under another type
# 0.454 0.486 - 34830 - 34841 - CARDINAL - Numerals that do not fall under another type
# 0.480 0.519 - 34846 - 34857 - CARDINAL - Numerals that do not fall under another type
# 0.545 0.454 - 34862 - 34873 - CARDINAL - Numerals that do not fall under another type
# 0.521 0.440 - 34878 - 34889 - CARDINAL - Numerals that do not fall under another type
# 0.500 0.440 - 34894 - 34905 - CARDINAL - Numerals that do not fall under another type
# 0.390 - 35128 - 35133 - CARDINAL - Numerals that do not fall under another type
# 0.790 - 0.670 x - 35157 - 35172 - MONEY - Monetary values, including unit
# 0.545 0.425 a2 0.560 - 35206 - 35226 - CARDINAL - Numerals that do not fall under another type
# 0.609 0.390 - 35236 - 35247 - CARDINAL - Numerals that do not fall under another type
# 0.597 - 35251 - 35256 - CARDINAL - Numerals that do not fall under another type
# cie publication - 35265 - 35280 - ORG - Companies, agencies, institutions, etc.
# 15.2, 1986 - 35281 - 35291 - DATE - Absolute or relative dates or periods
# 1931 - 35314 - 35318 - DATE - Absolute or relative dates or periods
# 16 2.29.4 - 35351 - 35360 - CARDINAL - Numerals that do not fall under another type
# 0.335 - 35521 - 35526 - CARDINAL - Numerals that do not fall under another type
# r41 purple - 35692 - 35702 - PERSON - People, including fictional
# 0.980 - 35717 - 35722 - CARDINAL - Numerals that do not fall under another type
# 0.645 0.335 - 35760 - 35771 - CARDINAL - Numerals that do not fall under another type
# 0.665 0.335 - 35775 - 35786 - CARDINAL - Numerals that do not fall under another type
# 0.735 - 35790 - 35795 - CARDINAL - Numerals that do not fall under another type
# 0.265 r4 0.721 0.259 2.30 - 35796 - 35821 - PERCENT - Percentage, including "%"
# night - 35823 - 35828 - TIME - Times smaller than a day
# 88 2.30.1 - 35945 - 35954 - QUANTITY - Measurements, as of weight or distance
# 0.843 - 36118 - 36123 - CARDINAL - Numerals that do not fall under another type
# 0.489 x + 0.146 - 36158 - 36173 - QUANTITY - Measurements, as of weight or distance
# 0.968 - 36198 - 36203 - CARDINAL - Numerals that do not fall under another type
# 1.442 - 36237 - 36242 - CARDINAL - Numerals that do not fall under another type
# 0.373 - 36286 - 36291 - CARDINAL - Numerals that do not fall under another type
# 0.350 - 36307 - 36312 - MONEY - Monetary values, including unit
# 0.548 0.414 - 36316 - 36327 - CARDINAL - Numerals that do not fall under another type
# 0.450 0.513 - 36331 - 36342 - CARDINAL - Numerals that do not fall under another type
# 0.040 - 36518 - 36523 - CARDINAL - Numerals that do not fall under another type
# red boundary - 36551 - 36563 - FAC - Buildings, airports, highways, bridges, etc.
# 0.200 - 36568 - 36573 - CARDINAL - Numerals that do not fall under another type
# 0.970 - x - 36607 - 36616 - QUANTITY - Measurements, as of weight or distance
# 0.505 0.465 y2 0.520 0.480 - 36650 - 36676 - DATE - Absolute or relative dates or periods
# 0.585 - 36695 - 36700 - CARDINAL - Numerals that do not fall under another type
# 0.385 - 36701 - 36706 - ORG - Companies, agencies, institutions, etc.
# 1.417 - 36877 - 36882 - CARDINAL - Numerals that do not fall under another type
# 0.390 - 36937 - 36942 - CARDINAL - Numerals that do not fall under another type
# 0.790 - 0.670 x - 36966 - 36981 - MONEY - Monetary values, including unit
# 17 - 36982 - 36984 - CARDINAL - Numerals that do not fall under another type
# 0.545 0.425 a2 - 37018 - 37032 - CARDINAL - Numerals that do not fall under another type
# 0.557 - 37033 - 37038 - CARDINAL - Numerals that do not fall under another type
# 0.609 0.390 - 37048 - 37059 - CARDINAL - Numerals that do not fall under another type
# 0.597 - 37063 - 37068 - CARDINAL - Numerals that do not fall under another type
# 0.335 - 37244 - 37249 - CARDINAL - Numerals that do not fall under another type
# the purple line - 37277 - 37292 - ORG - Companies, agencies, institutions, etc.
# r41 purple - 37293 - 37303 - PERSON - People, including fictional
# 0.978 - 37317 - 37322 - CARDINAL - Numerals that do not fall under another type
# 0.643 0.335 - 37360 - 37371 - CARDINAL - Numerals that do not fall under another type
# 0.665 0.335 - 37375 - 37386 - CARDINAL - Numerals that do not fall under another type
# 0.735 - 37390 - 37395 - CARDINAL - Numerals that do not fall under another type
# 2.31.1 - 37476 - 37482 - CARDINAL - Numerals that do not fall under another type
# 0.030 - 37651 - 37656 - CARDINAL - Numerals that do not fall under another type
# 0.740 - 37681 - 37686 - CARDINAL - Numerals that do not fall under another type
# 0,050 - 37718 - 37723 - CARDINAL - Numerals that do not fall under another type
# 0.570 - 37746 - 37751 - CARDINAL - Numerals that do not fall under another type
# 0.300 0.270 - 37789 - 37800 - CARDINAL - Numerals that do not fall under another type
# 0.385 - 37804 - 37809 - ORG - Companies, agencies, institutions, etc.
# 0.355 - 37810 - 37815 - PRODUCT - Objects, vehicles, foods, etc. (not services)
# 0.345 0.395 - 37819 - 37830 - PERCENT - Percentage, including "%"
# 0.260 0.310 - 37834 - 37845 - CARDINAL - Numerals that do not fall under another type
# 2.31.2 - 37847 - 37853 - CARDINAL - Numerals that do not fall under another type
# 0.534 x + - 38016 - 38025 - QUANTITY - Measurements, as of weight or distance
# white boundary - 38036 - 38050 - ORG - Companies, agencies, institutions, etc.
# 0.910 - 38055 - 38060 - CARDINAL - Numerals that do not fall under another type
# 1.342 - 38087 - 38092 - CARDINAL - Numerals that do not fall under another type
# 0.545 0.454 y2 0.487 0.423 - 38159 - 38185 - CARDINAL - Numerals that do not fall under another type
# 0.465 0.534 18 - 38204 - 38218 - CARDINAL - Numerals that do not fall under another type
# 0.346 - 38385 - 38390 - CARDINAL - Numerals that do not fall under another type
# 0.053 - 38393 - 38398 - CARDINAL - Numerals that do not fall under another type
# 0.910 - 38425 - 38430 - CARDINAL - Numerals that do not fall under another type
# 0.350 r41 - 38459 - 38468 - QUANTITY - Measurements, as of weight or distance
# 0.690 0.310 - 38521 - 38532 - QUANTITY - Measurements, as of weight or distance
# 0.595 - 38536 - 38541 - CARDINAL - Numerals that do not fall under another type
# 0.315 - 38542 - 38547 - DATE - Absolute or relative dates or periods
# 0.560 - 38551 - 38556 - CARDINAL - Numerals that do not fall under another type
# 2.32 - 38579 - 38583 - CARDINAL - Numerals that do not fall under another type
# day - 38585 - 38588 - DATE - Absolute or relative dates or periods
# 2.32.1 - 38629 - 38635 - CARDINAL - Numerals that do not fall under another type
# 0.346 - 38796 - 38801 - CARDINAL - Numerals that do not fall under another type
# 0.053 - 38804 - 38809 - CARDINAL - Numerals that do not fall under another type
# 0.910 - 38837 - 38842 - CARDINAL - Numerals that do not fall under another type
# 0.315 - 38872 - 38877 - CARDINAL - Numerals that do not fall under another type
# 0.047 - 38880 - 38885 - CARDINAL - Numerals that do not fall under another type
# fr41 - 38888 - 38892 - ORG - Companies, agencies, institutions, etc.
# 0,690 - 38946 - 38951 - CARDINAL - Numerals that do not fall under another type
# 0,310 - 38952 - 38957 - CARDINAL - Numerals that do not fall under another type
# 0,315 - 38968 - 38973 - CARDINAL - Numerals that do not fall under another type
# fr3 - 38974 - 38977 - ORG - Companies, agencies, institutions, etc.
# 0,569 - 38978 - 38983 - CARDINAL - Numerals that do not fall under another type
# 0,341 - 38984 - 38989 - CARDINAL - Numerals that do not fall under another type
# 0,655 - 38994 - 38999 - CARDINAL - Numerals that do not fall under another type
# 0,345 - 39000 - 39005 - CARDINAL - Numerals that do not fall under another type
# 2.33 - 39006 - 39010 - CARDINAL - Numerals that do not fall under another type
# 2.34 - 39224 - 39228 - CARDINAL - Numerals that do not fall under another type
# cie publication - 39466 - 39481 - ORG - Companies, agencies, institutions, etc.
# 70 - 39486 - 39488 - DATE - Absolute or relative dates or periods
# vienna - 39490 - 39496 - GPE - Countries, cities, states
# 1987 - 39497 - 39501 - DATE - Absolute or relative dates or periods
# second - 39615 - 39621 - ORDINAL - "first", "second", etc.
# 14 - 39704 - 39706 - CARDINAL - Numerals that do not fall under another type
# cie publication - 39754 - 39769 - ORG - Companies, agencies, institutions, etc.
# 2.35 - 39894 - 39898 - CARDINAL - Numerals that do not fall under another type
# 19 3 - 39985 - 39989 - CARDINAL - Numerals that do not fall under another type
# 3.1 - 40016 - 40019 - CARDINAL - Numerals that do not fall under another type
# 3.2 - 40223 - 40226 - CARDINAL - Numerals that do not fall under another type
# 3.2.1 - 40310 - 40315 - CARDINAL - Numerals that do not fall under another type
# 2.2.4 - 40410 - 40415 - CARDINAL - Numerals that do not fall under another type
# 3.2.2 - 40522 - 40527 - CARDINAL - Numerals that do not fall under another type
# 3.2.3 - 40904 - 40909 - CARDINAL - Numerals that do not fall under another type
# 3.2.4 - 41047 - 41052 - CARDINAL - Numerals that do not fall under another type
# 2.9 - 41250 - 41253 - CARDINAL - Numerals that do not fall under another type
# 2.8 - 41307 - 41310 - CARDINAL - Numerals that do not fall under another type
# 2.11 - 41359 - 41363 - CARDINAL - Numerals that do not fall under another type
# 2.12 - 41417 - 41421 - CARDINAL - Numerals that do not fall under another type
# 2.7.13 - 41516 - 41522 - CARDINAL - Numerals that do not fall under another type
# 3.2.5 - 41526 - 41531 - DATE - Absolute or relative dates or periods
# 2.10 - 41652 - 41656 - CARDINAL - Numerals that do not fall under another type
# 3.2.6 - 41660 - 41665 - CARDINAL - Numerals that do not fall under another type
# 3.2.6.1 - 41793 - 41800 - CARDINAL - Numerals that do not fall under another type
# 3.2.6.2 - 41872 - 41879 - NORP - Nationalities or religious or political groups
# 10 - 41979 - 41981 - CARDINAL - Numerals that do not fall under another type
# 123 - 42000 - 42003 - CARDINAL - Numerals that do not fall under another type
# 3.2.6.3 - 42005 - 42012 - CARDINAL - Numerals that do not fall under another type
# 6.22.7.4 - 42128 - 42136 - PERSON - People, including fictional
# 3.2.6.4 - 42158 - 42165 - CARDINAL - Numerals that do not fall under another type
# 3.2.6.5 - 42276 - 42283 - DATE - Absolute or relative dates or periods
# 6.22.9.2 - 42322 - 42330 - PERSON - People, including fictional
# 3.2.6.6 - 42352 - 42359 - CARDINAL - Numerals that do not fall under another type
# 3.2.6.7 - 42446 - 42453 - CARDINAL - Numerals that do not fall under another type
# 6.22.5 - 42534 - 42540 - CARDINAL - Numerals that do not fall under another type
# 3.2.7 - 42562 - 42567 - CARDINAL - Numerals that do not fall under another type
# 2.7.9 - 42698 - 42703 - CARDINAL - Numerals that do not fall under another type
# 2.7.10. - 42706 - 42713 - PERCENT - Percentage, including "%"
# 2.7.12 - 42715 - 42721 - CARDINAL - Numerals that do not fall under another type
# 20 3.3 - 42884 - 42890 - CARDINAL - Numerals that do not fall under another type
# 3.2.2 - 43009 - 43014 - CARDINAL - Numerals that do not fall under another type
# 3.4 - 43164 - 43167 - CARDINAL - Numerals that do not fall under another type
# 1 - 43200 - 43201 - CARDINAL - Numerals that do not fall under another type
# 4 - 43275 - 43276 - CARDINAL - Numerals that do not fall under another type
# 4.1 - 43287 - 43290 - CARDINAL - Numerals that do not fall under another type
# 4.2 - 43505 - 43508 - CARDINAL - Numerals that do not fall under another type
# first - 43574 - 43579 - ORDINAL - "first", "second", etc.
# two - 43580 - 43583 - CARDINAL - Numerals that do not fall under another type
# present 06 - 43595 - 43605 - DATE - Absolute or relative dates or periods
# 06 - 43628 - 43630 - CARDINAL - Numerals that do not fall under another type
# 3.2.2 - 43995 - 44000 - CARDINAL - Numerals that do not fall under another type
# 7 - 44048 - 44049 - CARDINAL - Numerals that do not fall under another type
# 4.3 - 44071 - 44074 - CARDINAL - Numerals that do not fall under another type
# 1958 - 44269 - 44273 - DATE - Absolute or relative dates or periods
# 1 - 44362 - 44363 - CARDINAL - Numerals that do not fall under another type
# 4.4 - 44384 - 44387 - CARDINAL - Numerals that do not fall under another type
# 4.4.1 - 44617 - 44622 - CARDINAL - Numerals that do not fall under another type
# 5 4.4.2 - 44741 - 44748 - CARDINAL - Numerals that do not fall under another type
# 4.4.1 - 44891 - 44896 - CARDINAL - Numerals that do not fall under another type
# 4.5 - 44898 - 44901 - CARDINAL - Numerals that do not fall under another type
# 4.4.1 - 45117 - 45122 - CARDINAL - Numerals that do not fall under another type
# 4.4.1 - 45439 - 45444 - CARDINAL - Numerals that do not fall under another type
# 4.6 - 45446 - 45449 - CARDINAL - Numerals that do not fall under another type
# 5 - 45512 - 45513 - CARDINAL - Numerals that do not fall under another type
# 1958 - 45575 - 45579 - DATE - Absolute or relative dates or periods
# 3 - 45614 - 45615 - CARDINAL - Numerals that do not fall under another type
# 3 - 45721 - 45722 - CARDINAL - Numerals that do not fall under another type
# 3 - 45730 - 45731 - CARDINAL - Numerals that do not fall under another type
# 21 - 45801 - 45803 - CARDINAL - Numerals that do not fall under another type
# 4.7 - 45804 - 45807 - CARDINAL - Numerals that do not fall under another type
# 4.8 - 45910 - 45913 - CARDINAL - Numerals that do not fall under another type
# 2 - 45921 - 45922 - CARDINAL - Numerals that do not fall under another type
# 5 - 45992 - 45993 - CARDINAL - Numerals that do not fall under another type
# 5.1 - 46018 - 46021 - CARDINAL - Numerals that do not fall under another type
# 2.24 - 46145 - 46149 - CARDINAL - Numerals that do not fall under another type
# 2.24.1 - 46152 - 46158 - CARDINAL - Numerals that do not fall under another type
# 2.24.2 - 46164 - 46170 - CARDINAL - Numerals that do not fall under another type
# 5.2 - 46463 - 46466 - CARDINAL - Numerals that do not fall under another type
# 2.7.9 - 46515 - 46520 - CARDINAL - Numerals that do not fall under another type
# 2.7.10 - 46523 - 46529 - DATE - Absolute or relative dates or periods
# 2.7.19 - 46535 - 46541 - CARDINAL - Numerals that do not fall under another type
# 5.3 - 47137 - 47140 - CARDINAL - Numerals that do not fall under another type
# 3° - 47600 - 47602 - QUANTITY - Measurements, as of weight or distance
# 5.4 - 47733 - 47736 - CARDINAL - Numerals that do not fall under another type
# 2.24 - 47943 - 47947 - CARDINAL - Numerals that do not fall under another type
# 2.24.1 - 47950 - 47956 - CARDINAL - Numerals that do not fall under another type
# 2.24.2 - 47962 - 47968 - CARDINAL - Numerals that do not fall under another type
# 5 - 48052 - 48053 - CARDINAL - Numerals that do not fall under another type
# 5 - 48055 - 48056 - CARDINAL - Numerals that do not fall under another type
# 5.5.1 - 48131 - 48136 - CARDINAL - Numerals that do not fall under another type
# 2.9 - 48367 - 48370 - CARDINAL - Numerals that do not fall under another type
# 5.5.2 - 48374 - 48379 - CARDINAL - Numerals that do not fall under another type
# one - 48399 - 48402 - CARDINAL - Numerals that do not fall under another type
# 5.5.3 - 48538 - 48543 - CARDINAL - Numerals that do not fall under another type
# 6 - 48718 - 48719 - CARDINAL - Numerals that do not fall under another type
# 22 - 48812 - 48814 - CARDINAL - Numerals that do not fall under another type
# 5.6 - 48880 - 48883 - CARDINAL - Numerals that do not fall under another type
# 5.7 - 48999 - 49002 - CARDINAL - Numerals that do not fall under another type
# 5.7.1 - 49056 - 49061 - CARDINAL - Numerals that do not fall under another type
# one - 49128 - 49131 - CARDINAL - Numerals that do not fall under another type
# one - 49580 - 49583 - CARDINAL - Numerals that do not fall under another type
# 5.7.1.2 - 49840 - 49847 - DATE - Absolute or relative dates or periods
# 5.7.1.3.1 - 50049 - 50058 - CARDINAL - Numerals that do not fall under another type
# more than two - 50245 - 50258 - CARDINAL - Numerals that do not fall under another type
# 5.7.1.3.2 - 50318 - 50327 - CARDINAL - Numerals that do not fall under another type
# 5.7.2 - 50487 - 50492 - CARDINAL - Numerals that do not fall under another type
# two - 50553 - 50556 - CARDINAL - Numerals that do not fall under another type
# two - 50927 - 50930 - CARDINAL - Numerals that do not fall under another type
# 15 mm - 50983 - 50988 - QUANTITY - Measurements, as of weight or distance
# 5.7.2.2 - 51097 - 51104 - CARDINAL - Numerals that do not fall under another type
# 75 mm - 51250 - 51255 - QUANTITY - Measurements, as of weight or distance
# 5.8 - 51309 - 51312 - CARDINAL - Numerals that do not fall under another type
# 23 5.8.1 - 51661 - 51669 - CARDINAL - Numerals that do not fall under another type
# 5.8.3 - 52073 - 52078 - CARDINAL - Numerals that do not fall under another type
# 5.9 - 52593 - 52596 - CARDINAL - Numerals that do not fall under another type
# 5.9.1 - 52809 - 52814 - CARDINAL - Numerals that do not fall under another type
# 6.18.7 - 52928 - 52934 - CARDINAL - Numerals that do not fall under another type
# 5.9 - 52998 - 53001 - CARDINAL - Numerals that do not fall under another type
# 2 - 53003 - 53004 - CARDINAL - Numerals that do not fall under another type
# 5.10 - 53361 - 53365 - CARDINAL - Numerals that do not fall under another type
# 2.7 - 53468 - 53471 - CARDINAL - Numerals that do not fall under another type
# 2.7 - 53604 - 53607 - CARDINAL - Numerals that do not fall under another type
# 5.10.1 - 53794 - 53800 - CARDINAL - Numerals that do not fall under another type
# 1 - 54039 - 54040 - CARDINAL - Numerals that do not fall under another type
# 4 - 54063 - 54064 - CARDINAL - Numerals that do not fall under another type
# 5.10.2 - 54066 - 54072 - CARDINAL - Numerals that do not fall under another type
# 2 - 54343 - 54344 - CARDINAL - Numerals that do not fall under another type
# 25 - 54376 - 54378 - CARDINAL - Numerals that do not fall under another type
# 4 - 54411 - 54412 - CARDINAL - Numerals that do not fall under another type
# 5.10.3 - 54415 - 54421 - CARDINAL - Numerals that do not fall under another type
# 1 - 54461 - 54462 - CARDINAL - Numerals that do not fall under another type
# 2 - 54467 - 54468 - CARDINAL - Numerals that do not fall under another type
# 5.10.3.1 - 54518 - 54526 - CARDINAL - Numerals that do not fall under another type
# two - 54542 - 54545 - CARDINAL - Numerals that do not fall under another type
# 1 m - 54564 - 54567 - MONEY - Monetary values, including unit
# 2.2 m - 54572 - 54577 - MONEY - Monetary values, including unit
# 24 5.10.3.2 - 54609 - 54620 - CARDINAL - Numerals that do not fall under another type
# two - 54635 - 54638 - CARDINAL - Numerals that do not fall under another type
# 15° - 54724 - 54727 - QUANTITY - Measurements, as of weight or distance
# 5.11 - 55069 - 55073 - CARDINAL - Numerals that do not fall under another type
# 5.11 - 55324 - 55328 - CARDINAL - Numerals that do not fall under another type
# 1 - 55330 - 55331 - CARDINAL - Numerals that do not fall under another type
# 5.11.1.1 - 55364 - 55372 - CARDINAL - Numerals that do not fall under another type
# 5.11.1.2 - 55536 - 55544 - CARDINAL - Numerals that do not fall under another type
# 5.11.1.3 - 55620 - 55628 - ORG - Companies, agencies, institutions, etc.
# 6.2.7.6.2 - 55681 - 55690 - CARDINAL - Numerals that do not fall under another type
# 5.11.2 - 55692 - 55698 - CARDINAL - Numerals that do not fall under another type
# 5.12.1 - 55793 - 55799 - CARDINAL - Numerals that do not fall under another type
# 5.12 - 55925 - 55929 - CARDINAL - Numerals that do not fall under another type
# 5.11 - 56105 - 56109 - CARDINAL - Numerals that do not fall under another type
# 5.12.1 - 56499 - 56505 - CARDINAL - Numerals that do not fall under another type
# 5.12.1.1 - 56663 - 56671 - CARDINAL - Numerals that do not fall under another type
# 5.12.1.2 - 56829 - 56837 - CARDINAL - Numerals that do not fall under another type
# 6.9.5 - 57012 - 57017 - CARDINAL - Numerals that do not fall under another type
# 5.12.1.3 - 57109 - 57117 - CARDINAL - Numerals that do not fall under another type
# 5.12.1.2 - 57210 - 57218 - CARDINAL - Numerals that do not fall under another type
# 5.13 - 57284 - 57288 - CARDINAL - Numerals that do not fall under another type
# 25 5.14 - 57414 - 57421 - DATE - Absolute or relative dates or periods
# 5.14.1 - 57441 - 57447 - CARDINAL - Numerals that do not fall under another type
# 5.14.2 - 57642 - 57648 - CARDINAL - Numerals that do not fall under another type
# 5.14.3 - 57883 - 57889 - CARDINAL - Numerals that do not fall under another type
# 5.14.5 - 58564 - 58570 - CARDINAL - Numerals that do not fall under another type
# -30 ° - 58621 - 58626 - QUANTITY - Measurements, as of weight or distance
# three seconds - 58708 - 58721 - TIME - Times smaller than a day
# 5. - 58759 - 58761 - CARDINAL - Numerals that do not fall under another type
# 15 - 58762 - 58764 - CARDINAL - Numerals that do not fall under another type
# 7 - 59398 - 59399 - CARDINAL - Numerals that do not fall under another type
# 26 - 59510 - 59512 - CARDINAL - Numerals that do not fall under another type
# daytime - 59896 - 59903 - TIME - Times smaller than a day
# light8 - 60067 - 60073 - PERSON - People, including fictional
# rear.9 - 60532 - 60538 - ORG - Companies, agencies, institutions, etc.
# white exterior - 60578 - 60592 - ORG - Companies, agencies, institutions, etc.
# 5.16 - 60638 - 60642 - CARDINAL - Numerals that do not fall under another type
# 5.16.1 - 60660 - 60666 - CARDINAL - Numerals that do not fall under another type
# 5.17 - 60803 - 60807 - CARDINAL - Numerals that do not fall under another type
# 5.18 - 60910 - 60914 - CARDINAL - Numerals that do not fall under another type
# 5.19 - 60917 - 60921 - CARDINAL - Numerals that do not fall under another type
# 5.20 - 60927 - 60931 - CARDINAL - Numerals that do not fall under another type
# 5.18 - 60948 - 60952 - CARDINAL - Numerals that do not fall under another type
# 5.18.1 - 61111 - 61117 - CARDINAL - Numerals that do not fall under another type
# 8 - 61311 - 61312 - CARDINAL - Numerals that do not fall under another type
# 9 - 61364 - 61365 - CARDINAL - Numerals that do not fall under another type
# 27 5.18.2 - 61543 - 61552 - CARDINAL - Numerals that do not fall under another type
# 5.18 - 61611 - 61615 - CARDINAL - Numerals that do not fall under another type
# two - 61648 - 61651 - CARDINAL - Numerals that do not fall under another type
# 2.16.1 - 61684 - 61690 - CARDINAL - Numerals that do not fall under another type
# only one - 61694 - 61702 - CARDINAL - Numerals that do not fall under another type
# 5.18.3 - 61863 - 61869 - CARDINAL - Numerals that do not fall under another type
# 5.18.4 - 62179 - 62185 - CARDINAL - Numerals that do not fall under another type
# 5.18 - 62244 - 62248 - CARDINAL - Numerals that do not fall under another type
# 5.18.1 - 62464 - 62470 - CARDINAL - Numerals that do not fall under another type
# this(these - 63327 - 63337 - LANGUAGE - Any named language
# 5.19 - 64157 - 64161 - CARDINAL - Numerals that do not fall under another type
# 5.20 - 64326 - 64330 - CARDINAL - Numerals that do not fall under another type
# 28 - 64547 - 64549 - CARDINAL - Numerals that do not fall under another type
# 10 - 64745 - 64747 - CARDINAL - Numerals that do not fall under another type
# more than 0.15 per cent - 64899 - 64922 - MONEY - Monetary values, including unit
# 10 - 64947 - 64949 - CARDINAL - Numerals that do not fall under another type
# 6.2.6.1.1 - 65027 - 65036 - CARDINAL - Numerals that do not fall under another type
# 6 - 65167 - 65168 - CARDINAL - Numerals that do not fall under another type
# 5.21 - 65170 - 65174 - CARDINAL - Numerals that do not fall under another type
# more than 50 per cent - 65352 - 65373 - MONEY - Monetary values, including unit
# 5.21.1 - 65741 - 65747 - CARDINAL - Numerals that do not fall under another type
# 5.21.2 - 66049 - 66055 - DATE - Absolute or relative dates or periods
# 10.1 - 66098 - 66102 - CARDINAL - Numerals that do not fall under another type
# 1 - 66113 - 66114 - CARDINAL - Numerals that do not fall under another type
# more than 50 per cent - 66156 - 66177 - MONEY - Monetary values, including unit
# 5.21.2 - 66597 - 66603 - DATE - Absolute or relative dates or periods
# 5.22 - 66641 - 66645 - CARDINAL - Numerals that do not fall under another type
# 5.23 - 66844 - 66848 - CARDINAL - Numerals that do not fall under another type
# 37 - 66914 - 66916 - DATE - Absolute or relative dates or periods
# 2.7.1.1.2 - 67017 - 67026 - CARDINAL - Numerals that do not fall under another type
# 5.23.1 - 67395 - 67401 - CARDINAL - Numerals that do not fall under another type
# 5.23 - 67598 - 67602 - CARDINAL - Numerals that do not fall under another type
# 29 - 67924 - 67926 - CARDINAL - Numerals that do not fall under another type
# 2.18 - 68032 - 68036 - CARDINAL - Numerals that do not fall under another type
# 5.25 - 68132 - 68136 - CARDINAL - Numerals that do not fall under another type
# 5.26 - 68343 - 68347 - CARDINAL - Numerals that do not fall under another type
# at least one - 68553 - 68565 - CARDINAL - Numerals that do not fall under another type
# 5.27 - 69160 - 69164 - CARDINAL - Numerals that do not fall under another type
# 2.7.9 - 69379 - 69384 - CARDINAL - Numerals that do not fall under another type
# 2.7.10. - 69387 - 69394 - PERCENT - Percentage, including "%"
# 2.7.12 - 69396 - 69402 - CARDINAL - Numerals that do not fall under another type
# 5.27.1 - 69649 - 69655 - CARDINAL - Numerals that do not fall under another type
# 5.27.2 - 70043 - 70049 - CARDINAL - Numerals that do not fall under another type
# 5.27.1 - 70125 - 70131 - CARDINAL - Numerals that do not fall under another type
# 6.75 - 70212 - 70216 - CARDINAL - Numerals that do not fall under another type
# 6 volt - 70220 - 70226 - QUANTITY - Measurements, as of weight or distance
# 13.5 - 70237 - 70241 - CARDINAL - Numerals that do not fall under another type
# 12 - 70245 - 70247 - CARDINAL - Numerals that do not fall under another type
# 28 - 70265 - 70267 - CARDINAL - Numerals that do not fall under another type
# 24 - 70271 - 70273 - CARDINAL - Numerals that do not fall under another type
# more than 3 per cent - 70291 - 70311 - MONEY - Monetary values, including unit
# 5.27.1 - 70490 - 70496 - CARDINAL - Numerals that do not fall under another type
# 5.27.2 - 70502 - 70508 - CARDINAL - Numerals that do not fall under another type
# 5.27.4 - 70649 - 70655 - CARDINAL - Numerals that do not fall under another type
# 5.28 - 70794 - 70798 - CARDINAL - Numerals that do not fall under another type
# ...
# 5.2 - 238135 - 238138 - CARDINAL - Numerals that do not fall under another type
# 5.5.1 - 238246 - 238251 - CARDINAL - Numerals that do not fall under another type
# 5.5.5 - 238278 - 238283 - DATE - Absolute or relative dates or periods
# only one - 238288 - 238296 - CARDINAL - Numerals that do not fall under another type
# 7 117 - 238511 - 238516 - CARDINAL - Numerals that do not fall under another type
# 7 - 238523 - 238524 - CARDINAL - Numerals that do not fall under another type
# 6.2.6.1.1 - 238626 - 238635 - CARDINAL - Numerals that do not fall under another type
# 6.3.6.1.2 - 238717 - 238726 - CARDINAL - Numerals that do not fall under another type
# 1 - 238755 - 238756 - CARDINAL - Numerals that do not fall under another type
# 2 - 238934 - 238935 - CARDINAL - Numerals that do not fall under another type
# 8 - 239100 - 239101 - CARDINAL - Numerals that do not fall under another type
# 118 - 239102 - 239105 - CARDINAL - Numerals that do not fall under another type
# 8 - 239112 - 239113 - CARDINAL - Numerals that do not fall under another type
# 6.2.6.2.2 - 239187 - 239196 - CARDINAL - Numerals that do not fall under another type
# 1 - 239217 - 239218 - CARDINAL - Numerals that do not fall under another type
# 1.1 - 239235 - 239238 - CARDINAL - Numerals that do not fall under another type
# 1.2 - 239984 - 239987 - CARDINAL - Numerals that do not fall under another type
# 6.2.6.1.1 - 240068 - 240077 - CARDINAL - Numerals that do not fall under another type
# 1.3 - 240099 - 240102 - CARDINAL - Numerals that do not fall under another type
# 6.2.6.2.2 - 240151 - 240160 - CARDINAL - Numerals that do not fall under another type
# 1.4 - 240259 - 240262 - CARDINAL - Numerals that do not fall under another type
# 1 - 240334 - 240335 - CARDINAL - Numerals that do not fall under another type
# 5 - 240337 - 240338 - CARDINAL - Numerals that do not fall under another type
# five - 240423 - 240427 - CARDINAL - Numerals that do not fall under another type
# four - 240445 - 240449 - CARDINAL - Numerals that do not fall under another type
# 1 - 240475 - 240476 - CARDINAL - Numerals that do not fall under another type
# 8 - 240483 - 240484 - CARDINAL - Numerals that do not fall under another type
# 119 - 240485 - 240488 - CARDINAL - Numerals that do not fall under another type
# 2 - 240497 - 240498 - CARDINAL - Numerals that do not fall under another type
# 3 - 240507 - 240508 - CARDINAL - Numerals that do not fall under another type
# 9 120 - 240515 - 240520 - CARDINAL - Numerals that do not fall under another type
# 9 - 240527 - 240528 - CARDINAL - Numerals that do not fall under another type
# 1 - 240565 - 240566 - CARDINAL - Numerals that do not fall under another type
# 1.1 - 240574 - 240577 - CARDINAL - Numerals that do not fall under another type
# 2.7 - 240644 - 240647 - CARDINAL - Numerals that do not fall under another type
# 2.8 - 240786 - 240789 - CARDINAL - Numerals that do not fall under another type
# 2.10 - 240794 - 240798 - CARDINAL - Numerals that do not fall under another type
# 2.14 - 240801 - 240805 - CARDINAL - Numerals that do not fall under another type
# 5.4 - 240811 - 240814 - CARDINAL - Numerals that do not fall under another type
# 1.2 - 240962 - 240965 - CARDINAL - Numerals that do not fall under another type
# 2.13 - 241075 - 241079 - CARDINAL - Numerals that do not fall under another type
# 5.3 - 241340 - 241343 - CARDINAL - Numerals that do not fall under another type
# 5.10 - 241530 - 241534 - CARDINAL - Numerals that do not fall under another type
# 1.3 - 241556 - 241559 - CARDINAL - Numerals that do not fall under another type
# 7 - 241848 - 241849 - CARDINAL - Numerals that do not fall under another type
# 6 - 242090 - 242091 - CARDINAL - Numerals that do not fall under another type
# 4.1 - 242120 - 242123 - CARDINAL - Numerals that do not fall under another type
# 1.3.2 - 242125 - 242130 - CARDINAL - Numerals that do not fall under another type
# 0.2 per cent - 242322 - 242334 - MONEY - Monetary values, including unit
# 2.8 per cent - 242338 - 242350 - MONEY - Monetary values, including unit
# 0.8 - 242384 - 242387 - CARDINAL - Numerals that do not fall under another type
# 0.2 per cent - 242389 - 242401 - MONEY - Monetary values, including unit
# 2.8 per cent - 242405 - 242417 - MONEY - Monetary values, including unit
# 0.8 ≤ h ≤ 1.0 - 242447 - 242460 - TIME - Times smaller than a day
# 0.7 per cent - 242465 - 242477 - MONEY - Monetary values, including unit
# 3.3 per cent - 242481 - 242493 - MONEY - Monetary values, including unit
# 0.7 per cent - 242570 - 242582 - MONEY - Monetary values, including unit
# 3.3 per cent - 242586 - 242598 - MONEY - Monetary values, including unit
# 1.0 - 242628 - 242631 - CARDINAL - Numerals that do not fall under another type
# 1.2 m - 242638 - 242643 - CARDINAL - Numerals that do not fall under another type
# 1.2 per cent - 242645 - 242657 - MONEY - Monetary values, including unit
# 3.8 per cent - 242661 - 242673 - MONEY - Monetary values, including unit
# 1.2 m. - 242707 - 242713 - QUANTITY - Measurements, as of weight or distance
# 9 121 - 242720 - 242725 - DATE - Absolute or relative dates or periods
# 2,000 lumens - 242847 - 242859 - QUANTITY - Measurements, as of weight or distance
# 0.7 per cent - 243004 - 243016 - MONEY - Monetary values, including unit
# 3.3 per cent - 243020 - 243032 - MONEY - Monetary values, including unit
# 0.8 - 243072 - 243075 - CARDINAL - Numerals that do not fall under another type
# 1.2 per cent - 243078 - 243090 - MONEY - Monetary values, including unit
# 3.8 per cent - 243094 - 243106 - MONEY - Monetary values, including unit
# 0.8 m. - 243146 - 243152 - QUANTITY - Measurements, as of weight or distance
# 5 - 243229 - 243230 - CARDINAL - Numerals that do not fall under another type
# 1.3.2 - 243290 - 243295 - CARDINAL - Numerals that do not fall under another type
# 1 - 243297 - 243298 - CARDINAL - Numerals that do not fall under another type
# 2.1.1.6 - 243354 - 243361 - ORG - Companies, agencies, institutions, etc.
# 2.1.2 - 243393 - 243398 - CARDINAL - Numerals that do not fall under another type
# 1.3.2 - 243400 - 243405 - CARDINAL - Numerals that do not fall under another type
# 2 - 243407 - 243408 - CARDINAL - Numerals that do not fall under another type
# m3 - 243438 - 243440 - PERSON - People, including fictional
# 2.2.2 - 243469 - 243474 - CARDINAL - Numerals that do not fall under another type
# 1.3.2 - 243476 - 243481 - CARDINAL - Numerals that do not fall under another type
# 3 - 243483 - 243484 - CARDINAL - Numerals that do not fall under another type
# 2.3.1.1 - 243539 - 243546 - TIME - Times smaller than a day
# 2.3.1.2. 1.3.2. - 243558 - 243573 - DATE - Absolute or relative dates or periods
# 4 - 243574 - 243575 - CARDINAL - Numerals that do not fall under another type
# 1.3.2.4 - 243623 - 243630 - DATE - Absolute or relative dates or periods
# 1 - 243632 - 243633 - CARDINAL - Numerals that do not fall under another type
# 2.4.1.1 - 243681 - 243688 - CARDINAL - Numerals that do not fall under another type
# 2.4.1.2 - 243700 - 243707 - CARDINAL - Numerals that do not fall under another type
# 1.3.2.4 - 243709 - 243716 - DATE - Absolute or relative dates or periods
# 2 - 243718 - 243719 - CARDINAL - Numerals that do not fall under another type
# 2.4.2.1 - 243762 - 243769 - CARDINAL - Numerals that do not fall under another type
# 2.4.2.2 - 243781 - 243788 - CARDINAL - Numerals that do not fall under another type
# 1.4 - 243790 - 243793 - CARDINAL - Numerals that do not fall under another type
# 5.11 - 244050 - 244054 - CARDINAL - Numerals that do not fall under another type
# 5.14 - 244059 - 244063 - DATE - Absolute or relative dates or periods
# 1.5 - 244148 - 244151 - CARDINAL - Numerals that do not fall under another type
# 6.1.9.2 - 244314 - 244321 - CARDINAL - Numerals that do not fall under another type
# 6.1.9.1 - 244410 - 244417 - CARDINAL - Numerals that do not fall under another type
# 9 - 244458 - 244459 - CARDINAL - Numerals that do not fall under another type
# 122 - 244460 - 244463 - CARDINAL - Numerals that do not fall under another type
# 5.15 - 244691 - 244695 - CARDINAL - Numerals that do not fall under another type
# 5.16 - 244701 - 244705 - CARDINAL - Numerals that do not fall under another type
# 10 123 - 244796 - 244802 - QUANTITY - Measurements, as of weight or distance
# 10 - 244809 - 244811 - CARDINAL - Numerals that do not fall under another type
# 11 124 - 244827 - 244833 - CARDINAL - Numerals that do not fall under another type
# 4° 4° - 244852 - 244857 - QUANTITY - Measurements, as of weight or distance
# 4° 4° - 244912 - 244917 - QUANTITY - Measurements, as of weight or distance
# 11 - 244960 - 244962 - CARDINAL - Numerals that do not fall under another type
# 6.21.5 - 245054 - 245060 - CARDINAL - Numerals that do not fall under another type
# 1a - 245089 - 245091 - CARDINAL - Numerals that do not fall under another type
# 25 - 245097 - 245099 - CARDINAL - Numerals that do not fall under another type
# 1b - 245109 - 245111 - CARDINAL - Numerals that do not fall under another type
# 25 m - 245134 - 245138 - QUANTITY - Measurements, as of weight or distance
# 11 - 245145 - 245147 - CARDINAL - Numerals that do not fall under another type
# 4° 4° - 245152 - 245157 - QUANTITY - Measurements, as of weight or distance
# 2 - 245165 - 245166 - CARDINAL - Numerals that do not fall under another type
# 25 m - 245172 - 245176 - QUANTITY - Measurements, as of weight or distance
# 12 - 245201 - 245203 - CARDINAL - Numerals that do not fall under another type
# 126 - 245204 - 245207 - CARDINAL - Numerals that do not fall under another type
# 12 - 245214 - 245216 - CARDINAL - Numerals that do not fall under another type
# 1 - 245228 - 245229 - CARDINAL - Numerals that do not fall under another type
# 1.1 - 245310 - 245313 - CARDINAL - Numerals that do not fall under another type
# atmosphere1 - 245360 - 245371 - PERSON - People, including fictional
# 1.2 - 245399 - 245402 - CARDINAL - Numerals that do not fall under another type
# 1 - 245549 - 245550 - CARDINAL - Numerals that do not fall under another type
# 1 - 245564 - 245565 - CARDINAL - Numerals that do not fall under another type
# 50 ± - 245670 - 245674 - QUANTITY - Measurements, as of weight or distance
# 10 km/h 100 ± - 245675 - 245688 - QUANTITY - Measurements, as of weight or distance
# 20 km - 245689 - 245694 - QUANTITY - Measurements, as of weight or distance
# 20 km - 245702 - 245707 - QUANTITY - Measurements, as of weight or distance
# 10 per cent - 245760 - 245771 - MONEY - Monetary values, including unit
# 6.1.9.3.1.2 - 246189 - 246200 - CARDINAL - Numerals that do not fall under another type
# 1 - 246259 - 246260 - CARDINAL - Numerals that do not fall under another type
# 2,000 m - 246313 - 246320 - MONEY - Monetary values, including unit
# sixth - 246411 - 246416 - ORDINAL - "first", "second", etc.
# isbn - 246426 - 246430 - PERSON - People, including fictional
# 92 - 246432 - 246434 - CARDINAL - Numerals that do not fall under another type
# 1 - 246450 - 246451 - CARDINAL - Numerals that do not fall under another type
# 9 - 246453 - 246454 - CARDINAL - Numerals that do not fall under another type
# 1/ 1 - 246456 - 246460 - CARDINAL - Numerals that do not fall under another type
# 9 - 246462 - 246463 - CARDINAL - Numerals that do not fall under another type
# 11 - 246465 - 246467 - DATE - Absolute or relative dates or periods
# 1996 - 246476 - 246480 - DATE - Absolute or relative dates or periods
# 12 - 246489 - 246491 - CARDINAL - Numerals that do not fall under another type
# 127 - 246492 - 246495 - CARDINAL - Numerals that do not fall under another type
# 1.3 - 246496 - 246499 - CARDINAL - Numerals that do not fall under another type
# 1.4 - 246565 - 246568 - CARDINAL - Numerals that do not fall under another type
# two - 246615 - 246618 - CARDINAL - Numerals that do not fall under another type
# four - 246645 - 246649 - CARDINAL - Numerals that do not fall under another type
# 1.5 - 246738 - 246741 - CARDINAL - Numerals that do not fall under another type
# more than 600 m. - 246864 - 246880 - QUANTITY - Measurements, as of weight or distance
# 1.6 - 246967 - 246970 - CARDINAL - Numerals that do not fall under another type
# 2 - 247027 - 247028 - CARDINAL - Numerals that do not fall under another type
# 2.1 - 247089 - 247092 - CARDINAL - Numerals that do not fall under another type
# atmosphere2 - 247139 - 247150 - GPE - Countries, cities, states
# 2.2 - 247179 - 247182 - CARDINAL - Numerals that do not fall under another type
# 2 - 247329 - 247330 - CARDINAL - Numerals that do not fall under another type
# 2 - 247344 - 247345 - CARDINAL - Numerals that do not fall under another type
# 50 ± - 247450 - 247454 - QUANTITY - Measurements, as of weight or distance
# 20km/h - 247480 - 247486 - QUANTITY - Measurements, as of weight or distance
# 10 per cent - 247537 - 247548 - MONEY - Monetary values, including unit
# 6.22.9.3.1.2 - 248071 - 248083 - CARDINAL - Numerals that do not fall under another type
# 2 - 248142 - 248143 - CARDINAL - Numerals that do not fall under another type
# 2,000 m - 248196 - 248203 - MONEY - Monetary values, including unit
# sixth - 248294 - 248299 - ORDINAL - "first", "second", etc.
# isbn - 248309 - 248313 - PERSON - People, including fictional
# 92 - 248315 - 248317 - CARDINAL - Numerals that do not fall under another type
# 1 - 248333 - 248334 - CARDINAL - Numerals that do not fall under another type
# 9 - 248336 - 248337 - CARDINAL - Numerals that do not fall under another type
# 1/ 1 - 248339 - 248343 - CARDINAL - Numerals that do not fall under another type
# 9 - 248345 - 248346 - CARDINAL - Numerals that do not fall under another type
# 11 - 248348 - 248350 - DATE - Absolute or relative dates or periods
# 1996 - 248359 - 248363 - DATE - Absolute or relative dates or periods
# 12 - 248371 - 248373 - CARDINAL - Numerals that do not fall under another type
# 2.3 - 248378 - 248381 - CARDINAL - Numerals that do not fall under another type
# 2.4 - 248447 - 248450 - CARDINAL - Numerals that do not fall under another type
# two - 248497 - 248500 - CARDINAL - Numerals that do not fall under another type
# four - 248527 - 248531 - CARDINAL - Numerals that do not fall under another type
# 2.5 - 248620 - 248623 - CARDINAL - Numerals that do not fall under another type
# more than 600 m. - 248746 - 248762 - QUANTITY - Measurements, as of weight or distance
# 2.6 - 248852 - 248855 - CARDINAL - Numerals that do not fall under another type
# 2.7 - 248910 - 248913 - CARDINAL - Numerals that do not fall under another type
# 13 - 249290 - 249292 - CARDINAL - Numerals that do not fall under another type
# 129 - 249293 - 249296 - CARDINAL - Numerals that do not fall under another type
# 13 - 249303 - 249305 - CARDINAL - Numerals that do not fall under another type
# headlamps1 - 249402 - 249412 - NORP - Nationalities or religious or political groups
# vehicle2 - 249439 - 249447 - PERSON - People, including fictional
# less than - 249484 - 249493 - CARDINAL - Numerals that do not fall under another type
# no more than 2 seconds - 249507 - 249529 - PERCENT - Percentage, including "%"
# 1,000 lux - 249538 - 249547 - QUANTITY - Measurements, as of weight or distance
# 7,000 lux - 249552 - 249561 - QUANTITY - Measurements, as of weight or distance
# more than 7,000 - 249620 - 249635 - CARDINAL - Numerals that do not fall under another type
# more than 5 seconds - 249644 - 249663 - TIME - Times smaller than a day
# no more than 300 seconds - 249669 - 249693 - PERCENT - Percentage, including "%"
# 2 - 249855 - 249856 - CARDINAL - Numerals that do not fall under another type
# 14 - 250159 - 250161 - CARDINAL - Numerals that do not fall under another type
# 130 - 250162 - 250165 - CARDINAL - Numerals that do not fall under another type
# 14 - 250172 - 250174 - CARDINAL - Numerals that do not fall under another type
# one - 250307 - 250310 - CARDINAL - Numerals that do not fall under another type
# 15 - 250431 - 250433 - CARDINAL - Numerals that do not fall under another type
# 131 - 250434 - 250437 - CARDINAL - Numerals that do not fall under another type
# 15 - 250444 - 250446 - CARDINAL - Numerals that do not fall under another type
# 2.34 - 250534 - 250538 - CARDINAL - Numerals that do not fall under another type

# %% [markdown]
# * After Lunch 30-Jan-2025

# %%
import spacy

# %%
! python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.11/dist-packages (from en-core-web-lg==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
! pip install spacy-transformers
! python -m spacy download en_core_web_trf  # Transformer-based model
# Out:
# Collecting spacy-transformers
#   Downloading spacy_transformers-1.3.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: spacy<4.1.0,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from spacy-transformers) (3.7.5)
# Collecting transformers<4.37.0,>=3.4.0 (from spacy-transformers)
#   Downloading transformers-4.36.2-py3-none-any.whl.metadata (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from spacy-transformers) (2.5.1+cu124)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from spacy-transformers) (2.5.1)
# Collecting spacy-alignments<1.0.0,>=0.7.2 (from spacy-transformers)
#   Downloading spacy_alignments-0.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy-transformers) (1.26.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.1.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->spacy-transformers) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.11/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (0.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (2024.11.6)
# Collecting tokenizers<0.19,>=0.14 (from transformers<4.37.0,>=3.4.0->spacy-transformers)
#   Downloading tokenizers-0.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (0.5.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.1.2)
# Downloading spacy_transformers-1.3.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (197 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.7/197.7 kB 9.9 MB/s eta 0:00:00
# Downloading spacy_alignments-0.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.0/314.0 kB 18.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 62.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 53.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.9 MB/s eta 0:00:00
# Downloading transformers-4.36.2-py3-none-any.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 96.7 MB/s eta 0:00:00
# Downloading tokenizers-0.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 80.0 MB/s eta 0:00:00
# Installing collected packages: spacy-alignments, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, tokenizers, nvidia-cusolver-cu12, transformers, spacy-transformers
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.0
#     Uninstalling tokenizers-0.21.0:
#       Successfully uninstalled tokenizers-0.21.0
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.47.1
#     Uninstalling transformers-4.47.1:
#       Successfully uninstalled transformers-4.47.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.3.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.36.2 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 spacy-alignments-0.9.1 spacy-transformers-1.3.5 tokenizers-0.15.2 transformers-4.36.2
# Collecting en-core-web-trf==3.7.3
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.7.3/en_core_web_trf-3.7.3-py3-none-any.whl (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.11/dist-packages (from en-core-web-trf==3.7.3) (3.7.5)
# Collecting spacy-curated-transformers<0.3.0,>=0.2.0 (from en-core-web-trf==3.7.3)
#   Downloading spacy_curated_transformers-0.2.2-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.26.4)
# Collecting curated-transformers<0.2.0,>=0.1.0 (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading curated_transformers-0.1.1-py2.py3-none-any.whl.metadata (965 bytes)
# Collecting curated-tokenizers<0.1.0,>=0.0.9 (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading curated_tokenizers-0.0.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2.5.1+cu124)
# Requirement already satisfied: regex>=2022 in /usr/local/lib/python3.11/dist-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2024.11.6)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.1.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.1.2)
# Downloading spacy_curated_transformers-0.2.2-py2.py3-none-any.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.3/236.3 kB 6.4 MB/s eta 0:00:00
# Downloading curated_tokenizers-0.0.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (735 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 735.6/735.6 kB 29.3 MB/s eta 0:00:00
# Downloading curated_transformers-0.1.1-py2.py3-none-any.whl (25 kB)
# Installing collected packages: curated-tokenizers, curated-transformers, spacy-curated-transformers, en-core-web-trf
# Successfully installed curated-tokenizers-0.0.9 curated-transformers-0.1.1 en-core-web-trf-3.7.3 spacy-curated-transformers-0.2.2
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from spacy.pipeline import EntityRuler
from spacy.matcher import Matcher

# Load transformer-based spaCy model
nlp = spacy.load("en_core_web_trf")  # More accurate than "en_core_web_sm"

# Define a custom NER Entity Ruler
def add_entity_patterns(nlp):
    ruler = nlp.add_pipe("entity_ruler", before="ner")

    patterns = [
        {"label": "R131_REGULATION", "pattern": "R131 Regulation"},
        {"label": "AEBS_TECHNOLOGY", "pattern": "Advanced Emergency Braking System"},
        {"label": "VEHICLE_TYPE", "pattern": [{"LOWER": "truck"}]},
        {"label": "VEHICLE_TYPE", "pattern": [{"LOWER": "bus"}]},
        {"label": "MANUFACTURER", "pattern": "Volvo"},
        {"label": "MANUFACTURER", "pattern": "Daimler"},
        {"label": "CERTIFICATION_BODY", "pattern": "TÜV Süd"},
        {"label": "CERTIFICATION_BODY", "pattern": "DEKRA"},
        {"label": "TESTING_STANDARD", "pattern": "UNECE Standard"},
        {"label": "GEOGRAPHIC_REGION", "pattern": "EU"},
        {"label": "GEOGRAPHIC_REGION", "pattern": "Japan"},
    ]
    ruler.add_patterns(patterns)

# Function to load text from a saved text file
def load_text_from_file(text_file_path):
    with open(text_file_path, "r", encoding="utf-8") as file:
        return file.read()

# Function for rule-based Relation Extraction
def extract_relationships(doc):
    matcher = Matcher(nlp.vocab)

    relations = [
        ("R131 Regulation", "applies_to", "VEHICLE_TYPE"),
        ("AEBS Technology", "uses", "COMPONENT"),
        ("MANUFACTURER", "must_comply_with", "R131 Regulation"),
        ("CERTIFICATION_BODY", "certifies", "MANUFACTURER"),
        ("AEBS Technology", "tested_via", "TESTING_STANDARD"),
        ("R131 Regulation", "enforced_in", "GEOGRAPHIC_REGION"),
        ("COMPONENT", "integrated_into", "AEBS Technology"),
    ]

    extracted_relations = []

    for ent1, rel, ent2 in relations:
        pattern = [
            {"ENT_TYPE": ent1},
            {"LOWER": rel, "OP": "?"},
            {"ENT_TYPE": ent2}
        ]
        matcher.add(rel, [pattern])

    matches = matcher(doc)
    for match_id, start, end in matches:
        span = doc[start:end]
        relation = nlp.vocab.strings[match_id]
        extracted_relations.append((span[0].text, relation, span[-1].text))

    return extracted_relations
# Out:
# /usr/local/lib/python3.11/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# /usr/local/lib/python3.11/dist-packages/thinc/shims/pytorch.py:253: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(filelike, map_location=device))

# %%
# Load PDF
text_file_path = "/content/drive/MyDrive/KnowledgeGraphResults/cleaned_text1.txt"

text = load_text_from_file(text_file_path)

# Apply spaCy NLP
add_entity_patterns(nlp)
doc = nlp(text)

# Print Named Entities
print("Named Entities:")
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")

# Extract relationships
relations = extract_relationships(doc)
print("\nExtracted Relationships:")
for rel in relations:
    print(rel)
# Out:
# /usr/local/lib/python3.11/dist-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# Named Entities:
# 2 -> CARDINAL
# 16 october 1995 -> DATE
# 47 -> CARDINAL
# 12 -> CARDINAL
# 06 -> DATE
# 1 -> CARDINAL
# 06 -> DATE
# 15 july 2013 -> DATE
# 1 -> CARDINAL
# 1 -> CARDINAL
# 06 -> DATE
# 13 march 2013 -> DATE
# 2 -> CARDINAL
# 06 -> DATE
# 3 november 2013 -> DATE
# 3 -> CARDINAL
# 06 -> DATE
# 10 june 2014 -> DATE
# 4 -> CARDINAL
# 06 -> DATE
# 9 october 2014 -> DATE
# united nations -> GPE
# geneva -> FAC
# 20 march 1958 -> DATE
# 16 october 2014 -> DATE
# 3 -> CARDINAL
# 1 -> CARDINAL
# 2 -> CARDINAL
# 6.2.6.1.1. -> CARDINAL
# 129 14 -> CARDINAL
# 2.34. -> CARDINAL
# 2 -> CARDINAL
# 2.1 -> CARDINAL
# 2.2 -> CARDINAL
# 2.2.1 -> CARDINAL
# 2.2 -> CARDINAL
# 4 -> CARDINAL
# 2.2.1 -> CARDINAL
# 2.2.4. -> CARDINAL
# 2.3 -> CARDINAL
# 2.4 -> CARDINAL
# 2.5 -> CARDINAL
# 5 -> CARDINAL
# 2.6 -> CARDINAL
# one -> CARDINAL
# 2.6.1 -> CARDINAL
# 2.6.2 -> CARDINAL
# 1 -> CARDINAL
# the consolidated resolution on the construction of vehicles -> LAW
# 6 2.7 -> CARDINAL
# regulation no. 107 -> LAW
# m3 -> PRODUCT
# 2.7.1 -> CARDINAL
# one or more -> CARDINAL
# one or more -> CARDINAL
# 2.7.1.1.3 -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# 2.7.1.1.4 -> CARDINAL
# one -> CARDINAL
# 2.7.1.1.5 -> CARDINAL
# 2.7.1.1.6 -> CARDINAL
# one or more -> CARDINAL
# 2.7.1.1.7 -> CARDINAL
# one or more -> CARDINAL
# 2.7.1.2 -> CARDINAL
# one -> CARDINAL
# 2.7.1.2.1 -> CARDINAL
# 2.7.1.2.2 -> CARDINAL
# 2.7.2 -> CARDINAL
# 2.7.3 -> CARDINAL
# 2.7.3.1 -> CARDINAL
# 2.7.4 -> CARDINAL
# 2.7.5 -> CARDINAL
# 2.7.6 -> CARDINAL
# 2.7.7 -> CARDINAL
# 2.7.8 -> CARDINAL
# 2.7.9 -> CARDINAL
# 2.7.10 -> CARDINAL
# 2.7.10.1 -> CARDINAL
# 2 -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 3 -> CARDINAL
# 3 -> CARDINAL
# 7 -> CARDINAL
# regulation no. 97. -> LAW
# 2.7.13 -> CARDINAL
# 2.7.14 -> CARDINAL
# 2.7.15 -> CARDINAL
# 2.7.16 -> CARDINAL
# 2.7.16.2. -> CARDINAL
# european -> NORP
# 2.7.16.3. -> CARDINAL
# 2.7.16.4 -> CARDINAL
# regulation no. 104 -> LAW
# 2.7.17 -> CARDINAL
# 2.7.17.1 -> CARDINAL
# 2.7.17.1.1 -> CARDINAL
# 2.7.17.1.2 -> CARDINAL
# 2.7.17.2 -> CARDINAL
# 2.7.18 -> CARDINAL
# 2.7.19 -> CARDINAL
# 2.7.20 -> CARDINAL
# 2.7.21 -> CARDINAL
# 2.7.22 -> CARDINAL
# 2.7.23 -> CARDINAL
# 2.7.24 -> CARDINAL
# 2.7.25 -> CARDINAL
# daytime -> TIME
# 2.7.26 -> CARDINAL
# 2.7.27 -> CARDINAL
# 2.7.28 -> CARDINAL
# regulation no. 123 -> LAW
# 2.7.28.1 -> CARDINAL
# one or more -> CARDINAL
# 2.7.28.2 -> CARDINAL
# one -> CARDINAL
# 2.7.28.3 -> CARDINAL
# afs -> PRODUCT
# 10 -> CARDINAL
# afs -> PRODUCT
# 2.7.28.5 -> CARDINAL
# 6.22.7.4. -> CARDINAL
# 2.7.28.6 -> CARDINAL
# 2.7.28.7 -> CARDINAL
# 2.7.29 -> CARDINAL
# 2.7.30 -> CARDINAL
# two -> CARDINAL
# three -> CARDINAL
# 2.7.30.1 -> CARDINAL
# 2.7.31 -> CARDINAL
# 2.8 -> CARDINAL
# 3 -> CARDINAL
# 1 -> CARDINAL
# 4 -> CARDINAL
# one -> CARDINAL
# 3 -> CARDINAL
# 5 -> CARDINAL
# 2.8.1 -> CARDINAL
# 2.9 -> CARDINAL
# 3 -> CARDINAL
# 2.9.1 -> CARDINAL
# 2.7.9 -> CARDINAL
# 2.7.10 -> CARDINAL
# 2.7.19 -> CARDINAL
# 2.7.21 -> CARDINAL
# 2.7.26 -> CARDINAL
# paragraph 2.9.2. -> LAW
# afs -> PRODUCT
# two -> CARDINAL
# 6.22.4 -> CARDINAL
# 8 -> CARDINAL
# 9 -> CARDINAL
# 11 -> CARDINAL
# 2.9.2 -> CARDINAL
# 2.7.11 -> CARDINAL
# 2.7.18. -> CARDINAL
# 2.7.20 -> CARDINAL
# 2.7.22. -> CARDINAL
# only 98 per cent -> PERCENT
# two -> CARDINAL
# 3 -> CARDINAL
# 2 -> CARDINAL
# 3 -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 2.9.3 -> CARDINAL
# 2.7.16 -> CARDINAL
# 2.10 -> CARDINAL
# 2.7.1.3. -> CARDINAL
# 12 -> CARDINAL
# 3 -> CARDINAL
# 2.11 -> CARDINAL
# 0 -> CARDINAL
# 2.12 -> CARDINAL
# 2.13 -> CARDINAL
# 2.14 -> CARDINAL
# 2.14.1 -> CARDINAL
# 2.14.2. -> CARDINAL
# 2.14.3. -> CARDINAL
# 2.14.4. -> CARDINAL
# 2.14.5 -> CARDINAL
# 2.14.6 -> CARDINAL
# 2.7 -> CARDINAL
# 2.15 -> CARDINAL
# two -> CARDINAL
# 2.14. -> CARDINAL
# 2.15.1 -> CARDINAL
# two -> CARDINAL
# 2.14. -> CARDINAL
# 2.15.2 -> CARDINAL
# two -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# 60 per cent -> PERCENT
# two -> CARDINAL
# two -> CARDINAL
# 60 per cent -> PERCENT
# two -> CARDINAL
# 15 mm -> QUANTITY
# two -> CARDINAL
# three -> CARDINAL
# 75 mm -> QUANTITY
# 2.16.2 -> CARDINAL
# two -> CARDINAL
# at least 0.4 m -> QUANTITY
# 0.8 m -> QUANTITY
# 60 per cent -> PERCENT
# 2.17 -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# 14 -> CARDINAL
# 2.18 -> CARDINAL
# 2.19 -> CARDINAL
# 2.20 -> CARDINAL
# 2.21 -> CARDINAL
# 2.22 -> CARDINAL
# 2.23 -> CARDINAL
# 2.24 -> CARDINAL
# 2.24.1. -> CARDINAL
# 2.23 -> CARDINAL
# 2.24.2 -> CARDINAL
# 2.24.1. -> CARDINAL
# 2.23 -> CARDINAL
# 2.25 -> CARDINAL
# 2.25.1 -> CARDINAL
# 2.23 -> CARDINAL
# 2.25.2 -> CARDINAL
# 2.25.1 -> CARDINAL
# 2.23 -> CARDINAL
# 2.26 -> CARDINAL
# 2.27 -> CARDINAL
# 2.27.1 -> CARDINAL
# 2.28 -> CARDINAL
# 2.29.1 -> CARDINAL
# 0.150 -> CARDINAL
# 0.440 -> CARDINAL
# 0.500 -> CARDINAL
# 0.382 -> CARDINAL
# 0.050 -> CARDINAL
# 0.310 -> CARDINAL
# 1.290 -> CARDINAL
# 0.138 -> CARDINAL
# 0.440 -> CARDINAL
# 15.2, 1986 -> DATE
# 1931 -> DATE
# 16 2.29.4 -> CARDINAL
# 0.980 -> CARDINAL
# regulation no. 88 -> LAW
# 0.843 -> CARDINAL
# 0.200 x + 0.268 y41 -> QUANTITY
# 17 -> CARDINAL
# 2.31.1 -> CARDINAL
# 0.740 -> CARDINAL
# 0,050 -> CARDINAL
# 0.570 -> CARDINAL
# 2.31.2 -> CARDINAL
# 0.534 -> CARDINAL
# 0.346 -> CARDINAL
# 0.910 -> CARDINAL
# 0.350 -> CARDINAL
# 2.32 -> CARDINAL
# 2.32.1 -> CARDINAL
# 0.346 -> CARDINAL
# 0.053 -> CARDINAL
# 0.910 -> CARDINAL
# 0.315 -> CARDINAL
# 2.34 -> CARDINAL
# cie -> ORG
# second -> ORDINAL
# 14 -> CARDINAL
# cie -> ORG
# 2.35 -> CARDINAL
# 19 3 -> CARDINAL
# 3.1 -> CARDINAL
# 3.2 -> CARDINAL
# 3.2.1 -> CARDINAL
# 2.2.1 -> CARDINAL
# 3.2.2 -> CARDINAL
# 3.2.3. -> CARDINAL
# 3.2.4. -> CARDINAL
# 2.9. -> CARDINAL
# 2.8 -> CARDINAL
# 2.11. -> CARDINAL
# 2.12 -> CARDINAL
# 2.7.13 -> CARDINAL
# 3.2.5 -> CARDINAL
# 2.10 -> CARDINAL
# . -> CARDINAL
# 3.2.6 -> CARDINAL
# afs -> PRODUCT
# afs -> PRODUCT
# afs -> ORG
# regulation no. 123 -> LAW
# 6.22.9.2. -> CARDINAL
# 3.2.6.6. -> CARDINAL
# 6.22.5. -> CARDINAL
# 3.2.7 -> CARDINAL
# 2.7.9 -> CARDINAL
# 2.7.10. -> CARDINAL
# 2.7.12 -> CARDINAL
# 2.7.14 -> CARDINAL
# 2.7.15. -> CARDINAL
# 3.2.2. -> CARDINAL
# 3.4 -> CARDINAL
# 1 -> CARDINAL
# 4 -> CARDINAL
# 4.1 -> CARDINAL
# 4.2 -> CARDINAL
# first -> ORDINAL
# 06 -> DATE
# 06 -> DATE
# 3.2.2. -> CARDINAL
# 7 -> CARDINAL
# 4.3 -> CARDINAL
# 1958 -> DATE
# 1 -> CARDINAL
# 4.4 -> CARDINAL
# 5 4.4.2 -> CARDINAL
# 4.4.1 -> CARDINAL
# 4.5 -> CARDINAL
# one -> CARDINAL
# 4.4.1 -> CARDINAL
# 4.4.1 -> CARDINAL
# 4.6 -> CARDINAL
# 1958 -> DATE
# 3 -> CARDINAL
# the consolidated resolution on the construction of vehicles -> LAW
# 4.8. -> CARDINAL
# 5 -> CARDINAL
# 5.1 -> CARDINAL
# 2.24 -> CARDINAL
# 2.24.1. -> CARDINAL
# 2.24.2 -> CARDINAL
# 5.2 -> CARDINAL
# 2.7.9. -> CARDINAL
# 2.7.10. -> CARDINAL
# 2.7.19 -> CARDINAL
# 5.2.1 -> CARDINAL
# 5.3 -> CARDINAL
#  3° -> QUANTITY
# 5.4 -> CARDINAL
# 2.24 -> CARDINAL
# 2.24.1. -> CARDINAL
# 2.24.2 -> CARDINAL
# 5. -> CARDINAL
# 2.9 -> CARDINAL
# 5.5.2. -> CARDINAL
# 5.5.3 -> CARDINAL
# 22 5.5.4 -> CARDINAL
# 5.6 -> CARDINAL
# 5.7 -> CARDINAL
# 5.7.1 -> CARDINAL
# one -> CARDINAL
# 5.7.1.3.1 -> CARDINAL
# more than two -> CARDINAL
# 5.7.2 -> CARDINAL
# two -> CARDINAL
# 5.7.2.1 -> CARDINAL
# 60 per cent -> PERCENT
# two -> CARDINAL
# 15 mm -> QUANTITY
# 5.7.2.2 -> CARDINAL
# 75 mm -> QUANTITY
# 5.8 -> CARDINAL
# 5.8.2 -> CARDINAL
# 5.8.3 -> CARDINAL
# 5.9 -> CARDINAL
# 5.9.1 -> CARDINAL
# paragraph 6.18.7 -> LAW
# 5.9 -> CARDINAL
# 2 -> CARDINAL
# 5.10 -> CARDINAL
# 2.7. -> CARDINAL
# 2.7 -> CARDINAL
# 1 -> CARDINAL
# 4 -> CARDINAL
# 2 -> CARDINAL
# 25 m -> QUANTITY
# 4 -> CARDINAL
# 1 -> CARDINAL
# 2 -> CARDINAL
# 5.10.3.1 -> CARDINAL
# two -> CARDINAL
# 1 m -> QUANTITY
# 2.2 m -> QUANTITY
# 24 5.10.3.2 -> CARDINAL
# two -> CARDINAL
# 15° -> QUANTITY
# 5.11 -> CARDINAL
# 5.11 -> CARDINAL
# 5.12.1. -> CARDINAL
# 5.11.3 -> CARDINAL
# 5.12 -> CARDINAL
# 5.11. -> CARDINAL
# 6.9.5 -> CARDINAL
# 5.12.1.3. -> CARDINAL
# 5.12.1.2. -> CARDINAL
# 5.14.2 -> CARDINAL
# 5.14.3 -> CARDINAL
# 5.14.4 -> CARDINAL
# 5.14.5 -> CARDINAL
# -30 °c to +50 ° -> QUANTITY
# three seconds -> TIME
# 5 -> CARDINAL
# 7 -> CARDINAL
# 26 -> CARDINAL
# 5.16 -> CARDINAL
# 5.16.1 -> CARDINAL
# 5.17 -> CARDINAL
# 5.18 -> CARDINAL
# 5.19. -> CARDINAL
# 5.20. -> CARDINAL
# 5.18 -> CARDINAL
# 5.18.1 -> CARDINAL
# 5.18. -> CARDINAL
# two -> CARDINAL
# 2.16.1 -> CARDINAL
# only one -> CARDINAL
# 5.18.4 -> CARDINAL
# paragraph 5.18. -> LAW
# 5.18.1. -> CARDINAL
# 5.19 -> CARDINAL
# 5.20 -> CARDINAL
# 28 -> CARDINAL
# 10 -> CARDINAL
# more than 0.15 per cent -> PERCENT
# 10 -> CARDINAL
# paragraph 6.2.6.1.1. -> LAW
# annex 6 -> LAW
# . 5.21 -> CARDINAL
# more than 50 per cent -> PERCENT
# 5.21.1 -> CARDINAL
# more than 50 per cent -> PERCENT
# 10.1 -> CARDINAL
# annex 1 -> LAW
# more than 50 per cent -> PERCENT
# 5.21.3 -> CARDINAL
# 5.21.2. -> CARDINAL
# 5.22 -> CARDINAL
# 5.23 -> CARDINAL
# regulation no. -> LAW
# 5.23.1 -> CARDINAL
# regulation no. 37 -> LAW
# 5.23. -> CARDINAL
# 5.24 -> CARDINAL
# 29 -> CARDINAL
# 2.18 -> CARDINAL
# 5.25 -> CARDINAL
# afs -> PRODUCT
# 5.26 -> CARDINAL
# at least -> CARDINAL
# one -> CARDINAL
# 5.27 -> CARDINAL
# 2.7.9 -> CARDINAL
# 2.7.10 -> CARDINAL
# 2.7.12 -> CARDINAL
# 2.7.14 -> CARDINAL
# 2.7.15 -> CARDINAL
# 5.27.1 -> CARDINAL
# secondary -> ORDINAL
# 5.27.2 -> CARDINAL
# 5.27.1 -> CARDINAL
# 6.75 v -> QUANTITY
# 6 volt -> QUANTITY
# 13.5 v -> QUANTITY
# 12 volt -> QUANTITY
# 28 v -> QUANTITY
# 24 volt -> QUANTITY
# more than 3 per cent -> PERCENT
# 5.27.3 -> CARDINAL
# 5.27.1. -> CARDINAL
# 5.27.2. -> CARDINAL
# 5.27.4 -> CARDINAL
# 5.28 -> CARDINAL
# 5.28.1 -> CARDINAL
# 5.28.2 -> CARDINAL
# 30 -> CARDINAL
# 5.28.4 -> CARDINAL
# less than 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 5º below the horizontal. -> QUANTITY
# 5.28.5 -> CARDINAL
# 5.29 -> CARDINAL
# 6 -> CARDINAL
# 6.1 -> CARDINAL
# regulations nos. 98 -> LAW
# 112 -> CARDINAL
# 6.1.1 -> CARDINAL
# 6.1.2 -> CARDINAL
# two -> CARDINAL
# four -> CARDINAL
# 98 -> CARDINAL
# 112 -> CARDINAL
# two -> CARDINAL
# four -> CARDINAL
# two -> CARDINAL
# 5.12 -> CARDINAL
# 6.1.3 -> CARDINAL
# 6.1.4. -> CARDINAL
# 6.1.4. -> CARDINAL
# 31 -> CARDINAL
# 6.1.7 -> CARDINAL
# 6.1.7.1 -> CARDINAL
# 6.1.7.2 -> CARDINAL
# 6.1.7.3 -> CARDINAL
# 6.1.7.4 -> CARDINAL
# two -> CARDINAL
# paragraph 6.1.2 -> LAW
# no more than two -> CARDINAL
# at least one -> CARDINAL
# 6.1.7.5 -> CARDINAL
# four -> CARDINAL
# 5.12 -> CARDINAL
# . -> CARDINAL
# 6.1.8 -> CARDINAL
# 6.1.8.1 -> CARDINAL
# 6.1.7.1 -> CARDINAL
# 6.1.9 -> CARDINAL
# 6.1.9.1 -> CARDINAL
# 430,000 cd -> QUANTITY
# 100 -> CARDINAL
# 6.1.9.2 -> CARDINAL
# 10 -> CARDINAL
# 6.1.9 -> CARDINAL
# 3 -> CARDINAL
# 6.1.9.3.1 -> CARDINAL
# paragraph 6.1.7.1 -> LAW
# 6.1.9.3.1.1 -> CARDINAL
# 6.1.9.3.1.1 -> CARDINAL
# 1 -> CARDINAL
# 15° -> QUANTITY
# 15° -> QUANTITY
# 5° -> QUANTITY
# less than 2 m -> QUANTITY
# between 1.5 m -> QUANTITY
# 2.5 m -> QUANTITY
# 2° 2° to 5° 5° -> QUANTITY
# at least 400 m -> QUANTITY
# at least 100 m -> QUANTITY
# at least 75 m -> QUANTITY
# 150 cd -> QUANTITY
# 10 cm² ± 3 cm² -> QUANTITY
# 0.8 m. -> QUANTITY
# 6.1.9.3.2 -> CARDINAL
# 6.1.7.1. -> CARDINAL
# 6.1.9.3 -> CARDINAL
# 3 -> CARDINAL
# the type approval authority -> ORG
# 1 -> CARDINAL
# 12 -> CARDINAL
# 6.1.7.1 -> CARDINAL
# 6.1.9.3.1.1 -> CARDINAL
# 6.1.9.3.1.2. -> CARDINAL
# 6.1.9.3.5 -> CARDINAL
# 6.1.9.3.5 -> CARDINAL
# 6.1.7.1 -> CARDINAL
# 6.1.9.3.1.1 -> CARDINAL
# 6.1.9.3.1.2 -> CARDINAL
# 7000 lx -> QUANTITY
# the type approval authority -> ORG
# 6.2. -> CARDINAL
# 98 -> CARDINAL
# 6.2.1 -> CARDINAL
# 6.2.2 -> CARDINAL
# two -> CARDINAL
# 98 -> CARDINAL
# 112 -> CARDINAL
# 6.2.3 -> CARDINAL
# 34 6.2.4 -> CARDINAL
# 6.2.4 -> CARDINAL
# 1 -> CARDINAL
# more than 400 mm -> QUANTITY
# 400 mm -> QUANTITY
# 1,300 mm -> QUANTITY
# 6.2.4 -> CARDINAL
# 500 mm -> QUANTITY
# more than 1,200 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 6.2.4 -> CARDINAL
# 3 -> CARDINAL
# 6.2.5 -> CARDINAL
# 2.13 -> CARDINAL
# 15° -> QUANTITY
# 10° -> QUANTITY
# 45° -> QUANTITY
# 10° -> QUANTITY
# secondary -> ORDINAL
# one -> CARDINAL
# 0.1 per cent -> PERCENT
# 7 -> CARDINAL
# annex 5 -> LAW
# 10 -> CARDINAL
# the consolidated resolution on the construction of vehicles -> LAW
# 35 -> CARDINAL
# 0.8 -> CARDINAL
# between -0.5 per cent and -2.5 per cent -> PERCENT
# between -1.0 per cent and -1.5 per cent -> PERCENT
# 0.8 -> CARDINAL
# 1.0 -> CARDINAL
# between -0.5 per cent and -2.5 per cent -> PERCENT
# between -1.0 per cent and -1.5 per cent -> PERCENT
# between -1.0 per cent and -3.0 per cent -> PERCENT
# between -1.5 per cent and -2.0 per cent -> PERCENT
# two -> CARDINAL
# 1.0 -> CARDINAL
# between -1.0 per cent and -3.0 per cent -> PERCENT
# between -1.5 per cent and -2.0 per cent -> PERCENT
# 1,200 mm -> QUANTITY
# -1.5 per cent and -3.5 per cent -> PERCENT
# between:-2 per cent and -2.5 per cent -> PERCENT
# 36 6.2.6.2 -> CARDINAL
# 6.2.6.1.1 -> CARDINAL
# 6.2.6.1.2. -> CARDINAL
# 6.2.6.2.2 -> CARDINAL
# paragraph 6.2.6.1.1 -> LAW
# 6.2.6.1.2 -> CARDINAL
# 5 -> CARDINAL
# annex 5 -> LAW
# 37 -> CARDINAL
# 6.2.6.2.1 -> CARDINAL
# 6.2.6.2.2. -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# one -> CARDINAL
# 100 -> CARDINAL
# 6.2.7 -> CARDINAL
# 6.2.7.1 -> CARDINAL
# 6.2.7.2 -> CARDINAL
# 6.2.7.3 -> CARDINAL
# regulation no. -> LAW
# 6.2.7.4 -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# 500 m -> QUANTITY
# 6.2.7.5 -> CARDINAL
# 6.2.7.6 -> CARDINAL
# annex 13 -> LAW
# 5.11. -> CARDINAL
# 38 6.2.7.6.3 -> CARDINAL
# two -> CARDINAL
# night -> TIME
# regulation no. 121 -> LAW
# annex 13 -> LAW
# 6.2.7.6.1. -> CARDINAL
# 6.2.8 -> CARDINAL
# 6.2.8.1 -> CARDINAL
# 6.2.8 -> CARDINAL
# 2 -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# 6.2.9 -> CARDINAL
# paragraph 5.5.2 -> LAW
# 39 -> CARDINAL
# 2,000 lumen -> QUANTITY
# regulation no. 45.11 -> LAW
# paragraph 6.2.6.2.2. -> LAW
# 2,000 lumens -> QUANTITY
# regulation nos. 98 -> LAW
# 6.3 -> CARDINAL
# 6.3.1. -> CARDINAL
# 6.3.2. -> CARDINAL
# two -> CARDINAL
# 03 -> DATE
# regulation no. 19 -> LAW
# 6.3.3. -> CARDINAL
# 6.3.4. -> CARDINAL
# 6.3.4. -> CARDINAL
# 1 -> CARDINAL
# more than 400 mm -> QUANTITY
# 6.3.4. -> CARDINAL
# less than 250 mm -> QUANTITY
# m1 -> PRODUCT
# n1 -> PRODUCT
# more than 800 mm -> QUANTITY
# 11 -> CARDINAL
# 40 -> CARDINAL
# more than 1,200 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 6.3.4 -> CARDINAL
# 3 -> CARDINAL
# 6.3.5 -> CARDINAL
# 2.13 -> CARDINAL
# 5° -> QUANTITY
# 45° -> QUANTITY
# 10° -> QUANTITY
# secondary -> ORDINAL
# one -> CARDINAL
# -1.5 per cent -> PERCENT
# 13 -> CARDINAL
# 2 -> CARDINAL
# 2,000 lumens -> QUANTITY
# 6.3.6.1.2.1.1 -> CARDINAL
# one -> CARDINAL
# 1.0 per cent -> PERCENT
# 2,000 lumens -> QUANTITY
# annex 5 -> LAW
# 12 -> CARDINAL
# the consolidated resolution on the construction of vehicles -> LAW
# 13 -> CARDINAL
# 18 months -> DATE
# 4 -> CARDINAL
# 03 -> DATE
# 41 -> CARDINAL
# 0.8 -> CARDINAL
# between -1.0 per cent and -3.0 per cent -> PERCENT
# between -1.5 per cent and -2.0 per cent h > 0.8 limits: between -1.5 per cent and -3.5 per cent -> PERCENT
# between -2.0 per cent and -2.5 per cent -> PERCENT
# 6.3.6.1.2.2.2 -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# 7 -> CARDINAL
# 6.3.6.2 -> CARDINAL
# 6.3.6.2.1 -> CARDINAL
# annex 5 -> LAW
# 6.2.6. -> CARDINAL
# paragraph 6.2.6 -> LAW
# 6.3.6.2.3 -> CARDINAL
# 6.3.6.1.2.2.1. -> CARDINAL
# 6.3.6.2.4 -> CARDINAL
# 6.3.7 -> CARDINAL
# 6.3.8 -> CARDINAL
# 42 6.3.9 -> CARDINAL
# annex 1 -> LAW
# regulation no. 19 -> LAW
# 6.4. -> CARDINAL
# 6.4.1. -> CARDINAL
# 6.4.2 -> CARDINAL
# 6.4.2.1 -> CARDINAL
# one -> CARDINAL
# second -> ORDINAL
# 6,000 mm -> QUANTITY
# 6.4.2.2 -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# 6,000 mm -> QUANTITY
# 6.4.3. -> CARDINAL
# 6.4.4 -> CARDINAL
# 6.4.4 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 1,200 mm -> QUANTITY
# 3 -> CARDINAL
# two -> CARDINAL
# 6.4.2.2. -> CARDINAL
# 6.4.5.2. -> CARDINAL
# 6.4.6.2. -> CARDINAL
# 6.4.5 -> CARDINAL
# 6.4.5 -> CARDINAL
# 1 -> CARDINAL
# 2.13. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 45° -> QUANTITY
# one -> CARDINAL
# 45° -> QUANTITY
# 30° -> QUANTITY
# two -> CARDINAL
# 6.4.5.2 -> CARDINAL
# two -> CARDINAL
# 6.4.2.2 -> CARDINAL
# 15° -> QUANTITY
# two -> CARDINAL
# 6.4.6 -> CARDINAL
# 6.4.6.1 -> CARDINAL
# 43 6.4.6.2 -> CARDINAL
# two -> CARDINAL
# paragraph 6.4.2.2 -> LAW
# 6.4.5.2. -> CARDINAL
# 6.4.7 -> CARDINAL
# 6.4.7.1 -> CARDINAL
# 6.4.7.2 -> CARDINAL
# two -> CARDINAL
# paragraph 6.4.2.2. -> LAW
# 5.11. -> CARDINAL
# 10 km/h -> QUANTITY
# 10 km -> QUANTITY
# 6.4.8 -> CARDINAL
# 6.4.9 -> CARDINAL
# 6.5 -> CARDINAL
# 6 -> CARDINAL
# 6.5.1 -> CARDINAL
# 1 -> CARDINAL
# 2a -> CARDINAL
# 2b -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 6.5.2 -> CARDINAL
# 6.5.3 -> CARDINAL
# two -> CARDINAL
# 1 -> CARDINAL
# at least 40 mm -> QUANTITY
# 44 1a -> QUANTITY
# one -> CARDINAL
# 20 mm -> QUANTITY
# less than 40 mm -> QUANTITY
# 20 mm -> QUANTITY
# two -> CARDINAL
# 2a -> CARDINAL
# 2b -> CARDINAL
# two -> CARDINAL
# 2a -> CARDINAL
# 2b -> CARDINAL
# m3 -> PRODUCT
# n2 -> PRODUCT
# two -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 5 -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# m2 -> PRODUCT
# m3 -> PRODUCT
# 6 metres -> QUANTITY
# 6 -> CARDINAL
# n2 -> PRODUCT
# n3 -> PRODUCT
# n1 -> PRODUCT
# m2 -> PRODUCT
# m3 -> PRODUCT
# 6 metres -> QUANTITY
# 5 -> CARDINAL
# three -> CARDINAL
# 5 -> CARDINAL
# one -> CARDINAL
# 6 -> CARDINAL
# m2 -> PRODUCT
# m3 -> PRODUCT
# n2 -> PRODUCT
# n3 -> PRODUCT
# 9 m -> QUANTITY
# 1 -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# two -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 6.5 -> CARDINAL
# two -> CARDINAL
# 2a -> CARDINAL
# two -> CARDINAL
# 2a -> CARDINAL
# three -> CARDINAL
# 5 -> CARDINAL
# one -> CARDINAL
# 6 -> CARDINAL
# 9 m -> QUANTITY
# afs -> PRODUCT
# 6.5.4. -> CARDINAL
# more than 400 mm -> QUANTITY
# two -> CARDINAL
# less than 600 mm -> QUANTITY
# 400 mm -> QUANTITY
# less than 1,300 mm -> QUANTITY
# 6.5.4 -> CARDINAL
# 6.5.4.2.1 -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# less than: 350 mm -> QUANTITY
# m1 -> PRODUCT
# n1 -> PRODUCT
# 500 mm -> QUANTITY
# more than: 1,500 mm -> QUANTITY
# 6.5.4.2.2 -> CARDINAL
# 1 -> CARDINAL
# 2b -> CARDINAL
# 5.8 -> CARDINAL
# less than 350 mm -> QUANTITY
# more than 1,500 mm -> QUANTITY
# 6.5.4.2.3 -> CARDINAL
# 2,300 mm -> QUANTITY
# 5 -> CARDINAL
# 6 -> CARDINAL
# 2,100 mm -> QUANTITY
# 1 -> CARDINAL
# 6.5.4.2.4 -> CARDINAL
# 600 mm -> QUANTITY
# 6.5.4.3 -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 1,800 mm -> QUANTITY
# 2,500 mm -> QUANTITY
# m1 -> PRODUCT
# n1 -> PRODUCT
# first -> ORDINAL
# 6.5.5 -> CARDINAL
# 6.5.5 -> CARDINAL
# 1 -> CARDINAL
# 15° -> QUANTITY
# 1 -> CARDINAL
# 5. -> CARDINAL
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 2,100 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 30° -> QUANTITY
# 5° -> QUANTITY
# 6 -> CARDINAL
# 6.5 -> CARDINAL
# 5° -> QUANTITY
# 1.80 m -> QUANTITY
# m1 -> PRODUCT
# n1 -> PRODUCT
# 2.50 m -> QUANTITY
# 1 -> CARDINAL
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 45° -> QUANTITY
# 20° -> QUANTITY
# m1 -> PRODUCT
# n1 -> PRODUCT
# 47 -> CARDINAL
# 5° -> QUANTITY
# 2.50 m -> QUANTITY
# 1 -> CARDINAL
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 45° -> QUANTITY
# 20° -> QUANTITY
# 15° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# at least 12.5 square centimetres -> QUANTITY
# 5 -> CARDINAL
# 6 -> CARDINAL
# 6.5.6. -> CARDINAL
# 6.5.7 -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# less than 6 m -> QUANTITY
# 6.5.5.2 -> CARDINAL
# 6.5.8 -> CARDINAL
# 1 -> CARDINAL
# paragraph 6.4.2. -> LAW
# regulation no. -> LAW
# one -> CARDINAL
# 6.5.9 -> CARDINAL
# 90 ± 30 -> CARDINAL
# one and one-half seconds -> TIME
# first -> ORDINAL
# one -> CARDINAL
# 6.6 -> CARDINAL
# 6.6.1 -> CARDINAL
# 6.5. -> CARDINAL
# 6.6.2 -> CARDINAL
# 6.5.2 -> CARDINAL
# 6.5.3 -> CARDINAL
# 6.6.4 -> CARDINAL
# 6.5.4.1 -> CARDINAL
# 6.6.4 -> CARDINAL
# 6.5.4.2 -> CARDINAL
# 6.6.4 -> CARDINAL
# 3 -> CARDINAL
# 6.5.4.3 -> CARDINAL
# 6.6.5 -> CARDINAL
# 6.5.5 -> CARDINAL
# 6.6.6 -> CARDINAL
# 6.5.6 -> CARDINAL
# 6.6.7 -> CARDINAL
# 6.6.7.1 -> CARDINAL
# 6.6.7.2 -> CARDINAL
# 6.23. -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# less than 6 m -> QUANTITY
# 6.5.5.2. -> CARDINAL
# 6.6.8 -> CARDINAL
# 6.5.9. -> CARDINAL
# 6.7 -> CARDINAL
# 6.7.2 -> CARDINAL
# two -> CARDINAL
# one -> CARDINAL
# two -> CARDINAL
# m2 -> PRODUCT
# m3 -> PRODUCT
# n2 -> PRODUCT
# n3 -> PRODUCT
# one -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# one -> CARDINAL
# 6.7.3 -> CARDINAL
# 6.7.4 -> CARDINAL
# m1 -> PRODUCT
# 50 -> CARDINAL
# more than 400 mm -> QUANTITY
# 400 mm -> QUANTITY
# 1,300 mm -> QUANTITY
# two -> CARDINAL
# paragraph 6.7.2. -> LAW
# one -> CARDINAL
# one -> CARDINAL
# 6.7.2. -> CARDINAL
# 150 mm -> QUANTITY
# 6.7.4 -> CARDINAL
# 6.7.4.2 -> CARDINAL
# 1 -> CARDINAL
# less than 350 mm -> QUANTITY
# more than 1,500 mm -> QUANTITY
# 2,100 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# less than 600 mm -> QUANTITY
# more than 150 mm -> QUANTITY
# less than 850 mm -> QUANTITY
# 6.7.4 -> CARDINAL
# 6.7.4 -> CARDINAL
# 4 -> CARDINAL
# 6.7.4 -> CARDINAL
# 6.7.5 -> CARDINAL
# 45° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 45° -> QUANTITY
# 20° -> QUANTITY
# 10° -> QUANTITY
# 15° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 2,100 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 10° -> QUANTITY
# 5° -> QUANTITY
# 6.7.6 -> CARDINAL
# 6.7.7.1 -> CARDINAL
# 13 -> CARDINAL
# 6.7.7.2 -> CARDINAL
# 6.7.8 -> CARDINAL
# 6.7.9 -> CARDINAL
# 6.8 -> CARDINAL
# 4 -> CARDINAL
# 6.8.2 -> CARDINAL
# 6.8.3 -> CARDINAL
# 52 6.8.4 -> CARDINAL
# 6.8.4 -> CARDINAL
# 1 -> CARDINAL
# 6.8.4 -> CARDINAL
# 2 -> CARDINAL
# 6.8.4 -> CARDINAL
# 3 -> CARDINAL
# 6.8.5 -> CARDINAL
# 6.8.6 -> CARDINAL
# 6.8.7 -> CARDINAL
# 5.11 -> CARDINAL
# 6.8.8 -> CARDINAL
# 6.8.9 -> CARDINAL
# 6.9 -> CARDINAL
# 7 -> CARDINAL
# 6.9.1 -> CARDINAL
# over 1,600 mm -> QUANTITY
# more than 1,600 mm -> QUANTITY
# 6.9.2 -> CARDINAL
# two -> CARDINAL
# 6.9.3 -> CARDINAL
# 6.9.4 -> CARDINAL
# 6.9.4. -> CARDINAL
# more than 400 mm -> QUANTITY
# more than 150 mm -> QUANTITY
# two -> CARDINAL
# 53 -> CARDINAL
# less than 600 mm -> QUANTITY
# 400 mm -> QUANTITY
# less than 1,300 mm -> QUANTITY
# 6.9.4 -> CARDINAL
# 2 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 1,500 mm -> QUANTITY
# 2,100 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 6.9.4. 3 -> CARDINAL
# 6.9.4.4 -> CARDINAL
# 6.9.4.1 -> CARDINAL
# 6.9.4.3 -> CARDINAL
# 6.9.5 -> CARDINAL
# 6.9.5 -> CARDINAL
# 1 -> CARDINAL
# 45° -> QUANTITY
# 80° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 45° -> QUANTITY
# 20° -> QUANTITY
# 5° -> QUANTITY
# 15° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 6.9.5.2. -> CARDINAL
# n1 -> PRODUCT
# 45° -> QUANTITY
# 45° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 45° -> QUANTITY
# 20° -> QUANTITY
# 15° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# at least 12.5 cm2 -> QUANTITY
# 6.9.6 -> CARDINAL
# 6.9.7 -> CARDINAL
# 5.11 -> CARDINAL
# 54 -> CARDINAL
# 6.9.8 -> CARDINAL
# 6.9.9 -> CARDINAL
# 6.9.9.1 -> CARDINAL
# one or more -> CARDINAL
# 6.9.9.2 -> CARDINAL
# 6.10 -> CARDINAL
# 7 -> CARDINAL
# 6.10.2 -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# m2 -> PRODUCT
# m3 -> PRODUCT
# n2 -> PRODUCT
# n3 -> PRODUCT
# o2 -> PRODUCT
# o4 -> PRODUCT
# 6.10.3 -> CARDINAL
# 6.10.4 -> CARDINAL
# 6.10.4 -> CARDINAL
# 1 -> CARDINAL
# more than 400 mm -> QUANTITY
# two -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# less than 600 mm -> QUANTITY
# 400 mm -> QUANTITY
# less than 1,300 mm -> QUANTITY
# 6.10.4. -> QUANTITY
# less than 350 mm -> QUANTITY
# more than 1,500 mm -> QUANTITY
# 2,100 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 55 -> CARDINAL
# 600 mm -> QUANTITY
# 6.10.4. -> QUANTITY
# 6.10.5 -> CARDINAL
# 6.10.5 -> CARDINAL
# 1 -> CARDINAL
# 45° -> QUANTITY
# 80° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 45° -> QUANTITY
# 20° -> QUANTITY
# 15° -> QUANTITY
# 750 mm -> QUANTITY
# paragraph 5.8.1 -> LAW
# 15° -> QUANTITY
# 5° -> QUANTITY
# 2,100 mm -> QUANTITY
# 15° -> QUANTITY
# 5° -> QUANTITY
# 6.10.5.2 -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# paragraph 6.10.5.1. -> LAW
# 45° -> QUANTITY
# 45° -> QUANTITY
# 750 mm -> QUANTITY
# paragraph 5.8.1 -> LAW
# 45° -> QUANTITY
# 20° -> QUANTITY
# 15° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# at least 12.5 square centimetres -> QUANTITY
# 6.10.7 -> CARDINAL
# 5.11 -> CARDINAL
# 6.10.8 -> CARDINAL
# 56 -> CARDINAL
# 6.10.9 -> CARDINAL
# 6.11 -> CARDINAL
# 38 -> CARDINAL
# 6.11.2 -> CARDINAL
# one -> CARDINAL
# two -> CARDINAL
# 6.11.3 -> CARDINAL
# 6.11.4 -> CARDINAL
# 6.11.4. -> CARDINAL
# only one -> CARDINAL
# 2 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 1,000 mm -> QUANTITY
# 1,200 mm -> QUANTITY
# 6.11.4 -> CARDINAL
# 3 -> CARDINAL
# 6.11.5 -> CARDINAL
# 2.13 -> CARDINAL
# 5° -> QUANTITY
# 5° -> QUANTITY
# 25° -> QUANTITY
# 6.11.6 -> CARDINAL
# 6.11.7 -> CARDINAL
# 6.11.7.1 -> CARDINAL
# 6.11.7.3.2 -> CARDINAL
# 6.11.8 -> CARDINAL
# 6.11.7.1 -> CARDINAL
# 57 -> CARDINAL
# 6.11.7.1. -> CARDINAL
# 6.11.7.3. -> CARDINAL
# 6.11.7.5. -> CARDINAL
# 6.11.7.5 -> CARDINAL
# 6.11.8 -> CARDINAL
# 6.11.9 -> CARDINAL
# 100 mm -> QUANTITY
# 6.12 -> CARDINAL
# 6.12.1 -> CARDINAL
# 6 m -> QUANTITY
# 2 m -> QUANTITY
# 6.12.2 -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# one -> CARDINAL
# 6.12.4 -> CARDINAL
# more than 400 mm -> QUANTITY
# two -> CARDINAL
# 6.12.4. -> CARDINAL
# 2 -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# less than 350 mm -> QUANTITY
# more than 1,500 mm -> QUANTITY
# 2,100 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 6.12.4. 3. -> QUANTITY
# 6.12.5 -> CARDINAL
# 45° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 45° -> QUANTITY
# 20° -> QUANTITY
# 15° -> QUANTITY
# 58 -> CARDINAL
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 6.12.6 -> CARDINAL
# 6.12.9. -> CARDINAL
# 6.12.8 -> CARDINAL
# 6.12.9 -> CARDINAL
# 6.13 -> CARDINAL
# 7 -> CARDINAL
# 2.10 m -> QUANTITY
# between 1.80 and 2.10 m -> QUANTITY
# 6.13.2 -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# 6.13.3 -> CARDINAL
# 6.13.4 -> CARDINAL
# 6.13.4 -> CARDINAL
# 1 -> CARDINAL
# 59 -> CARDINAL
# more than 400 mm -> QUANTITY
# 6.13.4.3 -> CARDINAL
# paragraph 6.13.4.2 -> LAW
# 400 mm -> QUANTITY
# 6.13.5 -> CARDINAL
# 80° -> QUANTITY
# 5° -> QUANTITY
# 20° -> QUANTITY
# 6.13.6 -> CARDINAL
# 6.13.7 -> CARDINAL
# 5.11 -> CARDINAL
# 6.13.8 -> CARDINAL
# 6.13.9 -> CARDINAL
# one -> CARDINAL
# two -> CARDINAL
# 5.7 -> CARDINAL
# 60 -> CARDINAL
# two -> CARDINAL
# less than 200 mm -> QUANTITY
# 6.14 -> CARDINAL
# 3 -> CARDINAL
# 6.14.1 -> CARDINAL
# 6.14.2 -> CARDINAL
# two -> CARDINAL
# 3 -> CARDINAL
# two -> CARDINAL
# paragraph 6.14.4. -> LAW
# 6.14.3. -> CARDINAL
# 6.14.4 -> CARDINAL
# 6.14.4. -> CARDINAL
# more than 400 mm -> QUANTITY
# two -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# 400 mm -> QUANTITY
# less than 1,300 mm -> QUANTITY
# 6.14.4. -> QUANTITY
# 2 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 900 mm -> QUANTITY
# more than 1,200 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 900 mm -> QUANTITY
# 1200 mm -> QUANTITY
# 6.14.4 -> CARDINAL
# 6.14.5 -> CARDINAL
# 30° -> QUANTITY
# 10° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 10° -> QUANTITY
# 5° -> QUANTITY
# 6.14.6 -> CARDINAL
# 6.14.7 -> CARDINAL
# 61 6.15 -> CARDINAL
# 3 -> CARDINAL
# 6.15.1. -> CARDINAL
# two -> CARDINAL
# 3 -> CARDINAL
# two -> CARDINAL
# 6.15.3 -> CARDINAL
# 6.15.4 -> CARDINAL
# 6.15.4. -> CARDINAL
# more than 400 mm -> QUANTITY
# less than 600 mm -> QUANTITY
# 400 mm -> QUANTITY
# less than 1,300 mm -> QUANTITY
# 6.15.4. -> QUANTITY
# 2 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 900 mm -> QUANTITY
# more than 1,200 mm -> QUANTITY
# 900 mm -> QUANTITY
# 1,200 mm -> QUANTITY
# 6.15.4. -> QUANTITY
# 3 -> CARDINAL
# 6.15.5 -> CARDINAL
# 30° -> QUANTITY
# 15° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 6.15.6 -> CARDINAL
# 6.15.7 -> CARDINAL
# 6.16 -> CARDINAL
# 3 -> CARDINAL
# 6.16.1 -> CARDINAL
# 62 -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# paragraph 6.16.4. -> LAW
# 6.16.3. -> CARDINAL
# 6.16.4 -> CARDINAL
# 6.16.4. -> CARDINAL
# 1 -> CARDINAL
# more than 400 mm -> QUANTITY
# farther than 150 mm -> QUANTITY
# two -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# less than 600 mm -> QUANTITY
# 400 mm -> QUANTITY
# 6.16.4 -> CARDINAL
# 2 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 900 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 900 mm -> QUANTITY
# 6.16.4. -> QUANTITY
# 3 -> CARDINAL
# 6.16.5 -> CARDINAL
# 30° -> QUANTITY
# 10° -> QUANTITY
# 6.16.4.1. -> CARDINAL
# 10° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 10° -> QUANTITY
# 5° -> QUANTITY
# 6.16.6 -> CARDINAL
# 6.16.7 -> CARDINAL
# 63 6.17 -> CARDINAL
# 6.17.1 -> CARDINAL
# 6 m. -> QUANTITY
# 6 m. -> QUANTITY
# 6.17.2 -> CARDINAL
# two -> CARDINAL
# paragraph 6.17.4. -> LAW
# 6.17.3 -> CARDINAL
# 6.17.4 -> CARDINAL
# 6.17.4 -> CARDINAL
# 1 -> CARDINAL
# 250 mm -> QUANTITY
# more than 900 mm -> QUANTITY
# more than 1,200 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 900 mm -> QUANTITY
# 1,200 mm -> QUANTITY
# 6.17.1 -> CARDINAL
# 6.17.4 -> CARDINAL
# 3 -> CARDINAL
# at least one -> CARDINAL
# third -> ORDINAL
# further than 3 m -> QUANTITY
# two -> CARDINAL
# 3 m. -> QUANTITY
# n1 -> PRODUCT
# 4 m. -> QUANTITY
# 1 m. -> QUANTITY
# 6 m -> QUANTITY
# one -> CARDINAL
# first -> ORDINAL
# third -> ORDINAL
# third -> ORDINAL
# 6 m -> QUANTITY
# one -> CARDINAL
# first -> ORDINAL
# third -> ORDINAL
# third -> ORDINAL
# m1 -> PRODUCT
# 6 m -> QUANTITY
# 7 m -> QUANTITY
# one -> CARDINAL
# third -> ORDINAL
# 6.17.5 -> CARDINAL
# 45 -> CARDINAL
# 64 -> CARDINAL
# 10° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 10° -> QUANTITY
# 6.17.6 -> CARDINAL
# 6.17.7 -> CARDINAL
# 6.18 -> CARDINAL
# 91 -> CARDINAL
# 6.18.1 -> CARDINAL
# 6 m -> QUANTITY
# sm2 -> PRODUCT
# m1 -> PRODUCT
# m1 -> PRODUCT
# n1 -> PRODUCT
# less than 6 m -> QUANTITY
# 6.9.5.2 -> CARDINAL
# 6.10.5 -> CARDINAL
# 2 -> CARDINAL
# sm1 -> PRODUCT
# 6.18.2 -> CARDINAL
# 6.18.3 -> CARDINAL
# 6.18.4 -> CARDINAL
# 6.18.4 -> CARDINAL
# 1 -> CARDINAL
# 6.18.4 -> CARDINAL
# 2 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 1,500 mm -> QUANTITY
# 2,100 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 6.18.4 -> CARDINAL
# 3 -> CARDINAL
# third -> ORDINAL
# further than 3 m -> QUANTITY
# two -> CARDINAL
# 3 m. -> QUANTITY
# 4 m. -> QUANTITY
# 1 m. -> QUANTITY
# 6 m -> QUANTITY
# one -> CARDINAL
# first -> ORDINAL
# third -> ORDINAL
# third -> ORDINAL
# 6 m -> QUANTITY
# 7 m -> QUANTITY
# one -> CARDINAL
# further than 3 m -> QUANTITY
# one -> CARDINAL
# third -> ORDINAL
# 6.18.5 -> CARDINAL
# 45° -> QUANTITY
# 30° -> QUANTITY
# 6.5.5.2 -> CARDINAL
# 6.9.5.2 -> CARDINAL
# 6.10.5.2 -> CARDINAL
# 45° -> QUANTITY
# 30° -> QUANTITY
# 6.5.5.2 -> CARDINAL
# 10° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 10° -> QUANTITY
# 5° -> QUANTITY
# 6.18.6 -> CARDINAL
# 6.18.7 -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# less than 6 m -> QUANTITY
# 6.18.8 -> CARDINAL
# 6.18.9 -> CARDINAL
# 6.19 -> CARDINAL
# regulation no. 87 -> LAW
# 5.22. -> CARDINAL
# two -> CARDINAL
# 6.19.3 -> CARDINAL
# 6.19.4 -> CARDINAL
# 6.19.4 -> CARDINAL
# 1 -> CARDINAL
# less than 600 mm -> QUANTITY
# 400 mm -> QUANTITY
# 1,300 mm -> QUANTITY
# 6.19.4 -> CARDINAL
# 2 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 1,500 mm -> QUANTITY
# 6.19.4 -> CARDINAL
# 3 -> CARDINAL
# 6.19.5 -> CARDINAL
# 20° -> QUANTITY
# 20° -> QUANTITY
# 10° -> QUANTITY
# 10° -> QUANTITY
# 6.19.6 -> CARDINAL
# 6.19.7 -> CARDINAL
# 6.19.7.1 -> CARDINAL
# first -> ORDINAL
# 10 km/h -> QUANTITY
# 10 km/h -> QUANTITY
# more than 100 m -> QUANTITY
# 6.19.7.3 -> CARDINAL
# 15 -> CARDINAL
# 18 months -> DATE
# 4 -> CARDINAL
# 67 -> CARDINAL
# 5.11. -> CARDINAL
# 6.19.7.5 -> CARDINAL
# less than 40 mm -> QUANTITY
# 6.19.7.6 -> CARDINAL
# 6.19.8 -> CARDINAL
# 6.19.9 -> CARDINAL
# 6.20 -> CARDINAL
# 119 -> CARDINAL
# 6.20.1 -> CARDINAL
# 6.20.2 -> CARDINAL
# two -> CARDINAL
# 6.20.3 -> CARDINAL
# 6.20.4 -> CARDINAL
# 6.20.4 -> CARDINAL
# 1 -> CARDINAL
# one -> CARDINAL
# 6.20.4. -> CARDINAL
# 2 -> CARDINAL
# further than 1,000 mm -> QUANTITY
# 6.20.4. -> QUANTITY
# 3 -> CARDINAL
# 250 mm -> QUANTITY
# 6.20.5 -> CARDINAL
# 2.13. -> CARDINAL
# 10° -> QUANTITY
# 30° to 60° -> QUANTITY
# 6.20.7 -> CARDINAL
# 6.20.7.1 -> CARDINAL
# 6.20.7.2 -> CARDINAL
# 6.20.8 -> CARDINAL
# 6.20.9 -> CARDINAL
# 6.21 -> CARDINAL
# 6.21.1 -> CARDINAL
# 6.21.1 -> CARDINAL
# 1 -> CARDINAL
# 6.21.1 -> CARDINAL
# 2 -> CARDINAL
# 6.21.1.2 -> CARDINAL
# 1 -> CARDINAL
# 2,100 mm -> QUANTITY
# 7.5 tonnes -> QUANTITY
# o4 -> PRODUCT
# 6.21.1.2.2.1 -> CARDINAL
# 6,000 mm -> QUANTITY
# 7.5 tonnes -> QUANTITY
# 69 6.21.1.2.4 -> CARDINAL
# 6.21. -> CARDINAL
# regulation no. -> LAW
# regulation no. 3 -> LAW
# regulation no. -> LAW
# at least one -> CARDINAL
# 1,500 mm -> QUANTITY
# 6.21.1.1 -> CARDINAL
# 6.21.1.2. -> CARDINAL
# 6.21.2 -> CARDINAL
# 6.21.3 -> CARDINAL
# 70 6.21.4 -> CARDINAL
# 6.21.4.1 -> CARDINAL
# 6.21.4.1.1 -> CARDINAL
# 6.21.4.1.2 -> CARDINAL
# at least 70 per cent -> PERCENT
# 6.21.4.2 -> CARDINAL
# 6.21.4.2.1 -> CARDINAL
# 600 mm -> QUANTITY
# 6.21.4.2.1.1 -> CARDINAL
# 2,400 mm -> QUANTITY
# regulation no. -> LAW
# regulation no. -> LAW
# 25 cm2 -> QUANTITY
# one -> CARDINAL
# more than 600 mm -> QUANTITY
# more than 600 mm -> QUANTITY
# 600 mm -> QUANTITY
# 6.21.4.2.1.2 -> CARDINAL
# 6.21.4.2.2 -> CARDINAL
# at least 70 per cent -> PERCENT
# 6.21.4.2.2.1 -> CARDINAL
# paragraph 6.21.4.2.1.1. -> LAW
# 2,400 mm -> QUANTITY
# 71 a -> QUANTITY
# 2,400 mm -> QUANTITY
# 6.21.4.2.1.1 -> CARDINAL
# 6.21.4.2.2.2 -> CARDINAL
# 6.21.4.3 -> CARDINAL
# 6.21.4.3.1 -> CARDINAL
# more than 1,500 mm -> QUANTITY
# 2,500 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 6.21.4.1.2 -> CARDINAL
# 6.21.4.2.2. -> CARDINAL
# higher than 1,500 mm -> QUANTITY
# 6.21.4.3. -> CARDINAL
# 2. -> CARDINAL
# 400 mm -> QUANTITY
# 6.21.5 -> CARDINAL
# at least 70 per cent -> PERCENT
# 6.21.5.1 -> CARDINAL
# 11 -> CARDINAL
# 1a -> CARDINAL
# 1b -> CARDINAL
# 25 m -> QUANTITY
# 6.21.5.1.1 -> CARDINAL
# two -> CARDINAL
# 1 m -> QUANTITY
# 3.0 m -> QUANTITY
# 6.21.5.1.2 -> CARDINAL
# two -> CARDINAL
# 4° -> QUANTITY
# 72 6.21.5.2 -> CARDINAL
# 11 -> CARDINAL
# 2 -> CARDINAL
# 25 m -> QUANTITY
# 6.21.5.2.1 -> CARDINAL
# two -> CARDINAL
# 1.0 m -> QUANTITY
# 1.5 m -> QUANTITY
# 6.21.5.2.2. -> QUANTITY
# two -> CARDINAL
# 4° -> QUANTITY
# 1 -> CARDINAL
# 2 -> CARDINAL
# 50 per cent -> PERCENT
# the type approval authority -> ORG
# 50 per cent -> PERCENT
# 50 per cent -> PERCENT
# 1,000 mm -> QUANTITY
# 6.21.7.2 -> CARDINAL
# two -> CARDINAL
# 90° -> QUANTITY
# at least 250 mm -> QUANTITY
# 6.21.7.3 -> CARDINAL
# 200 mm -> QUANTITY
# regulation no. 70 -> LAW
# at least 60 mm -> QUANTITY
# 6.22 -> CARDINAL
# 6.1 -> CARDINAL
# . -> CARDINAL
# 6.2 -> CARDINAL
# 73 6.22.1 -> CARDINAL
# 6.22.2 -> CARDINAL
# one -> CARDINAL
# 6.22.3 -> CARDINAL
# 6.22.4 -> CARDINAL
# 6.22.4. -> CARDINAL
# 6.22.4.1.1 -> CARDINAL
# 6.22.4.1.1 -> CARDINAL
# two -> CARDINAL
# 6.1.4 -> CARDINAL
# 6.2.4. -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# one -> CARDINAL
# 50 mm -> QUANTITY
# 6.22.4.1.2 -> CARDINAL
# 140 mm16 -> QUANTITY
# 400 mm -> QUANTITY
# 6.22.4.1.3 -> CARDINAL
# 6.22.4.1.2 -> CARDINAL
# lower than 250 mm -> QUANTITY
# 6.2.4.2. -> CARDINAL
# 6.22.4.1 -> CARDINAL
# more than 400 mm -> QUANTITY
# m1 -> PRODUCT
# n1 -> PRODUCT
# 400 mm -> QUANTITY
# 1,300 mm -> QUANTITY
# two -> CARDINAL
# 200 mm -> QUANTITY
# 74 -> CARDINAL
# 1 -> CARDINAL
# 11 -> CARDINAL
# 3 -> CARDINAL
# 9 -> CARDINAL
# two -> CARDINAL
# 11 -> CARDINAL
# two -> CARDINAL
# 4 -> CARDINAL
# 8 -> CARDINAL
# two -> CARDINAL
# 2 -> CARDINAL
# 10 -> CARDINAL
# two -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 7 -> CARDINAL
# two -> CARDINAL
# 400 -> CARDINAL
# 600 -> CARDINAL
# 400 -> CARDINAL
# 1,300 mm -> QUANTITY
# 140 -> CARDINAL
# 1,200 75 6.22.4 -> QUANTITY
# 2 -> CARDINAL
# 6.22.5 -> CARDINAL
# 6.1.5 -> CARDINAL
# 6.2.5. -> CARDINAL
# at least one -> CARDINAL
# 6.22.6 -> CARDINAL
# 6.22.6 -> CARDINAL
# 1 -> CARDINAL
# 6.22.6.1.1 -> CARDINAL
# one -> CARDINAL
# 0.1 per cent -> PERCENT
# 7 -> CARDINAL
# 0.1 per cent -> PERCENT
# 6.22.6.1.2 -> CARDINAL
# 9.4 -> CARDINAL
# regulation no. -> LAW
# 6.22.6.1.2. -> CARDINAL
# 6.22.6 -> CARDINAL
# 3 -> CARDINAL
# 0.5 degree -> QUANTITY
# annex 10 of regulation no. 123. -> LAW
# 4 -> CARDINAL
# 6.2.6.3.2. -> CARDINAL
# 6.22.7 -> CARDINAL
# afs -> ORG
# 6.22.7.1.1 -> CARDINAL
# at least one -> CARDINAL
# 6.22.7.1.2 -> CARDINAL
# 6.22.9.3. -> CARDINAL
# 6.22.7.1.4 -> CARDINAL
# four -> CARDINAL
# 5.12 -> CARDINAL
# . -> CARDINAL
# 2 -> CARDINAL
# 5.12 -> CARDINAL
# 6.22.7.4 -> CARDINAL
# 6.22.7.4.1 -> CARDINAL
# 6.22.7.4.2 -> CARDINAL
# one -> CARDINAL
# 60 km/h -> QUANTITY
# 60 km/h -> QUANTITY
# 1 cd -> QUANTITY
# 10 lx -> QUANTITY
# 50 km -> QUANTITY
# 6.22.7.4.3 -> CARDINAL
# 60 km/h -> QUANTITY
# one -> CARDINAL
# 110 km/h -> QUANTITY
# 17 -> CARDINAL
# regulation no. 123, annex 3, table 6, only -> LAW
# e1 -> CARDINAL
# 100 km -> QUANTITY
# e2 -> CARDINAL
# 90 km -> QUANTITY
# e3 -> CARDINAL
# 80 km -> QUANTITY
# 6.22.7.4.4 -> CARDINAL
# one -> CARDINAL
# at least two minutes -> TIME
# 6.22.7.4.5 -> CARDINAL
# 6.22.7.4.1 -> CARDINAL
# 100 -> CARDINAL
# ii -> CARDINAL
# one -> CARDINAL
# 500 m -> QUANTITY
# 6.22.7.5 -> CARDINAL
# 6.22 -> CARDINAL
# 6.1.8. -> CARDINAL
# 6.2.8. -> CARDINAL
# 6.22.8.2 -> CARDINAL
# 18 -> CARDINAL
# 79 -> CARDINAL
# regulation no. -> LAW
# 6.22.8.3 -> CARDINAL
# 6.22.8.4 -> CARDINAL
# 5.8 -> CARDINAL
# regulation no. -> LAW
# 6.22.9 -> CARDINAL
# 6.22.9.1 -> CARDINAL
# regulation no. 4519 for at -> LAW
# 9.3. -> CARDINAL
# regulation no. 123 -> LAW
# 2,000 lm -> QUANTITY
# 6.22.9.2 -> CARDINAL
# afs -> ORG
# afs -> ORG
# afs -> ORG
# 6.22.7.4. -> CARDINAL
# afs -> ORG
# 19 -> CARDINAL
# 80 -> CARDINAL
# 6.22.9.2.4. -> CARDINAL
# 2 -> CARDINAL
# 12 -> CARDINAL
# 6.22.9.3 -> CARDINAL
# paragraph 6.22.7.1.2 -> LAW
# 6.1.9.3.1.1 -> CARDINAL
# 6.22.9.3.1.2 -> CARDINAL
# 6.22.9.3.1.3 -> CARDINAL
# 7,000 lx -> QUANTITY
# the type approval authority -> ORG
# the type approval authority -> ORG
# 6.22.9.4 -> CARDINAL
# 430,000 cd -> QUANTITY
# 100 -> CARDINAL
# 81 -> CARDINAL
# regulation no 123 -> LAW
# 6.23 -> CARDINAL
# 6.23.1 -> CARDINAL
# 6.23.7 -> CARDINAL
# 6.23.2 -> CARDINAL
# 6.5.2 -> CARDINAL
# 6.7.2 -> CARDINAL
# 6.23.3 -> CARDINAL
# 6.5.3. -> CARDINAL
# 6.7.3 -> CARDINAL
# 6.23.4 -> CARDINAL
# 6.5.4 -> CARDINAL
# 6.7.4 -> CARDINAL
# 6.23.5 -> CARDINAL
# 6.5.5 -> CARDINAL
# 6.7.5 -> CARDINAL
# 6.23.6 -> CARDINAL
# 6.5.6 -> CARDINAL
# 6.7.6 -> CARDINAL
# 6.23.7 -> CARDINAL
# 6.23.7.1 -> CARDINAL
# 4.0 ± 1.0 hz -> QUANTITY
# 6.23.7.1.1 -> CARDINAL
# 6.23.7.2 -> CARDINAL
# 6.23.7.3 -> CARDINAL
# 50 km/h -> QUANTITY
# regulations nos. 13 and 13 -> LAW
# 6.23.7.3.2 -> CARDINAL
# regulations nos. 13 and 13 -> LAW
# 6.23.8 -> CARDINAL
# 6.23.9 -> CARDINAL
# 6.23.9.1 -> CARDINAL
# 6.23.9.2 -> CARDINAL
# 6.23.9.2 -> CARDINAL
# regulation no.13 -> LAW
# 6.24 -> CARDINAL
# 6.24.1 -> CARDINAL
# 6.24.2 -> CARDINAL
# two -> CARDINAL
# 6.24.3 -> CARDINAL
# 6.24.9.3. -> CARDINAL
# 6.24.4 -> CARDINAL
# 6.24.5 -> CARDINAL
# 6.24.6 -> CARDINAL
# 6.24.7 -> CARDINAL
# 6.24.8 -> CARDINAL
# 6.24.9 -> CARDINAL
# 6.24.9.1 -> CARDINAL
# one -> CARDINAL
# 5.10. -> CARDINAL
# 83 6.24.9.2 -> CARDINAL
# 5.12. -> CARDINAL
# the type approval authority -> ORG
# 10 m -> QUANTITY
# 10 m -> QUANTITY
# two -> CARDINAL
# 10 m -> QUANTITY
# four -> CARDINAL
# 3 m -> QUANTITY
# 14 -> CARDINAL
# the technical service -> ORG
# 6.25 -> CARDINAL
# 6.25.1 -> CARDINAL
# 6.25.7 -> CARDINAL
# 6.25.2 -> CARDINAL
# 6.5.2 -> CARDINAL
# 6.25.3 -> CARDINAL
# 6.5.3 -> CARDINAL
# 6.25.4. -> CARDINAL
# 6.5.4 -> CARDINAL
# 6.25.5 -> CARDINAL
# 6.5.5. -> CARDINAL
# 6.25.6 -> CARDINAL
# 6.5.6 -> CARDINAL
# 6.25.7 -> CARDINAL
# 6.25.7.1 -> CARDINAL
# 4.0 +/- 1.0 -> CARDINAL
# 6.25.7.1.1 -> CARDINAL
# 4.0 +0.0/-1.0 hz -> QUANTITY
# 6.25.7.2 -> CARDINAL
# 6.25.7.3 -> CARDINAL
# 6.25.7.5 -> CARDINAL
# 30 km -> QUANTITY
# 30 km -> QUANTITY
# 6.25.7.6 -> CARDINAL
# more than 3 seconds -> TIME
# 6.25.8 -> CARDINAL
# 23 -> CARDINAL
# 6.26.1 -> CARDINAL
# 6.26.2 -> CARDINAL
# one -> CARDINAL
# two -> CARDINAL
# one -> CARDINAL
# 6.26.3 -> CARDINAL
# 6.26.9. -> CARDINAL
# 6.26.4 -> CARDINAL
# 6.26.5 -> CARDINAL
# 6.26.6 -> CARDINAL
# 6.26.9. -> CARDINAL
# 6.26.7 -> CARDINAL
# one -> CARDINAL
# first -> ORDINAL
# 10 km -> QUANTITY
# 6.26.8 -> CARDINAL
# 6.26.9.1 -> CARDINAL
# 10 m -> QUANTITY
# 10 m -> QUANTITY
# two -> CARDINAL
# 10 m -> QUANTITY
# four -> CARDINAL
# 1 m -> QUANTITY
# 3 m -> QUANTITY
# 14 -> CARDINAL
# regulation no. 23 -> LAW
# 9. -> CARDINAL
# 7.1 -> CARDINAL
# paragraph 3.2.2. -> LAW
# 7.1.2. -> CARDINAL
# 7.2 -> CARDINAL
# 4.3. -> CARDINAL
# 7.3 -> CARDINAL
# 1958 -> DATE
# 1 -> CARDINAL
# 86 8 -> CARDINAL
# 2 -> CARDINAL
# 5 -> CARDINAL
# 6. -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 8.2.2. -> CARDINAL
# 9 -> CARDINAL
# 8.3 -> CARDINAL
# the type approval authority -> ORG
# 8.4 -> CARDINAL
# the type approval authority -> ORG
# the type approval authority -> ORG
# 9 -> CARDINAL
# 9.1 -> CARDINAL
# 9.2 -> CARDINAL
# 1 -> CARDINAL
# 10 -> CARDINAL
# 1958 -> DATE
# united nations -> GPE
# 12 -> CARDINAL
# 12.1 -> CARDINAL
# 12.1.1 -> CARDINAL
# 12.1.2 -> CARDINAL
# 12.1.3 -> CARDINAL
# 12.1.4 -> CARDINAL
# 12.1.5. -> CARDINAL
# 12.1.5 -> CARDINAL
# 12.1.6 -> CARDINAL
# 12.1.4. -> CARDINAL
# 12.1.7 -> CARDINAL
# united nations -> ORG
# japan -> GPE
# japan -> GPE
# n1. 88 12.2. -> LAW
# 03 series of amendments -> DATE
# 10 october 2007 -> DATE
# 12 months -> DATE
# 03 -> DATE
# up to 09 october 2009 -> DATE
# 36 months -> DATE
# 10 october 2009 -> DATE
# 36 months -> DATE
# first -> ORDINAL
# 7.5 tonnes -> QUANTITY
# 2,100 mm -> QUANTITY
# 6,000 mm -> QUANTITY
# 03 -> CARDINAL
# 12.1.4. -> CARDINAL
# 10 october 2011 -> DATE
# 60 months -> DATE
# 7.5 tons -> QUANTITY
# 2,100 mm -> QUANTITY
# 6,000 mm -> QUANTITY
# 12 june 2010 -> DATE
# 36 months -> DATE
# 3 -> CARDINAL
# 03 -> DATE
# 3 -> CARDINAL
# 03 -> DATE
# up to 11 january 2010 -> DATE
# 18 months -> DATE
# 4 -> CARDINAL
# 03 -> DATE
# 6.3.6.1.1 -> CARDINAL
# 6.5.8 -> CARDINAL
# 6.19.7.3 -> CARDINAL
# up to 10 october 2011 -> DATE
# 60 month -> DATE
# 6.21.4.1.3 -> CARDINAL
# 6.21.4.1.3. -> CARDINAL
# 03 -> DATE
# 89 12.3 -> CARDINAL
# 04 series -> DATE
# 07 february 2011 -> DATE
# 07 august 2012 -> DATE
# 30 and 48 months -> DATE
# 04 -> DATE
# 22 july 2009 -> DATE
# 2 -> CARDINAL
# 04 -> DATE
# 5.2.1. -> CARDINAL
# 9 -> CARDINAL
# regulation no. -> LAW
# 24 october 2012 -> DATE
# 36 months -> DATE
# 3 -> CARDINAL
# 04 -> DATE
# 3.2.7 -> CARDINAL
# 5.27 to 5.27.4 -> CARDINAL
# 3 -> CARDINAL
# 04 -> DATE
# up to 07 february 2011 -> DATE
# 07 august 2012 -> DATE
# 30 and 48 months -> DATE
# 04 -> DATE
# 6.19.7.6 -> CARDINAL
# 12.3.1 -> CARDINAL
# regulation no. 112 -> LAW
# 07 august 2008 -> DATE
# 04 -> DATE
# 6.2.2. -> CARDINAL
# 04 -> DATE
# 112. 12.4 -> CARDINAL
# 05 -> DATE
# 30 january 2015 -> DATE
# 48 months -> DATE
# 05 -> DATE
# 30 july 2016 -> DATE
# 30 january 2018 -> DATE
# 66 and 84 months -> DATE
# one -> CARDINAL
# 05 -> DATE
# 90 12.5 -> CARDINAL
# 06 series of amendments -> DATE
# 18 november 2017 -> DATE
# 60 month -> DATE
# annex 1 91 -> LAW
# 210 x 297 mm -> QUANTITY
# 2 -> CARDINAL
# regulation no. -> LAW
# 1 -> CARDINAL
# 2 -> CARDINAL
# 1 92 -> CARDINAL
# 9. -> CARDINAL
# 3.2.6 -> CARDINAL
# 10.5 -> CARDINAL
# 70 per cent -> PERCENT
# 6.21.4.1.2 -> CARDINAL
# 6.21.4.2.2. -> CARDINAL
# 10.6. -> CARDINAL
# 3.2.7 -> CARDINAL
# 5.27 -> CARDINAL
# 10.7. -> CARDINAL
# 6.21.1.2.5 -> CARDINAL
# 10.8 -> CARDINAL
# 6.21.1.2.1 -> CARDINAL
# 6.21.1.2.1.1. -> CARDINAL
# 1 94 -> CARDINAL
# 17 -> CARDINAL
# 2 -> CARDINAL
# 4.4. -> CARDINAL
# 8 mm min -> QUANTITY
# netherlands -> LOC
# regulation no. 48 -> LAW
# regulation no. 48 -> LAW
# 4.5 -> CARDINAL
# 8 mm min -> QUANTITY
# netherlands -> LOC
# 4 -> CARDINAL
# regulation no. -> LAW
# regulation no. -> LAW
# regulation no. 48 -> LAW
# 06 -> DATE
# regulation no. -> LAW
# second -> ORDINAL
# 06 06 -> DATE
# 3 -> CARDINAL
# 3. -> CARDINAL
# 2.8. -> CARDINAL
# 2.8. -> CARDINAL
# two -> CARDINAL
# 1 -> CARDINAL
# 3 97 -> CARDINAL
# 2 -> CARDINAL
# 3 98 -> CARDINAL
# 3 -> CARDINAL
# 3 -> CARDINAL
# 4 -> CARDINAL
# 3 -> CARDINAL
# 5 -> CARDINAL
# 2.8 -> CARDINAL
# 2.9 -> CARDINAL
# 1 -> CARDINAL
# 2 -> CARDINAL
# 3 -> CARDINAL
# 4 -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 3 101 -> CARDINAL
# 7 -> CARDINAL
# 8 -> CARDINAL
# 2.8. -> CARDINAL
# 2.8. -> CARDINAL
# 3 102 -> CARDINAL
# 9 -> CARDINAL
# 6 -> CARDINAL
# 2.8 -> CARDINAL
# 2.9. -> CARDINAL
# 2.8 -> CARDINAL
# 7b -> CARDINAL
# 2.8. -> CARDINAL
# 3 103 -> CARDINAL
# 2.8. -> CARDINAL
# 2.8. -> CARDINAL
# 3 105 -> CARDINAL
# 7 -> CARDINAL
# two -> CARDINAL
# annex 3 106 -> LAW
# annex 3 107 -> LAW
# 3 108 -> CARDINAL
# 7b -> WORK_OF_ART
# 2.8 -> CARDINAL
# annex 4 109 annex 4 -> LAW
# 5.10.1 -> CARDINAL
# 5.10.2. -> CARDINAL
# 1 -> CARDINAL
# 2 -> CARDINAL
# 6.2.6.1 -> CARDINAL
# 6.2.6.3.1 -> CARDINAL
# 75 kg -> QUANTITY
# one -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# 2.1.1.5 -> CARDINAL
# one -> CARDINAL
# 2.1.1.6 -> CARDINAL
# 2.1.2 -> CARDINAL
# 2.2 -> CARDINAL
# one -> CARDINAL
# the consolidated resolution on the construction of vehicles -> LAW
# 5 111 -> CARDINAL
# first -> ORDINAL
# 2. -> CARDINAL
# one -> CARDINAL
# 25 per cent -> PERCENT
# 2. -> CARDINAL
# 2.4 -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# 6 -> CARDINAL
# 6 -> CARDINAL
# 1 -> CARDINAL
# 2 -> CARDINAL
# 2.1. -> CARDINAL
# 2.1.1. -> CARDINAL
# 2.1.2 -> CARDINAL
# 5 -> CARDINAL
# 2.2 -> CARDINAL
# 1 per cent -> QUANTITY
# 10 mrad -> QUANTITY
# 100 x -> QUANTITY
# 1 -> CARDINAL
# 6 113 -> CARDINAL
# 1 -> CARDINAL
# 1 -> CARDINAL
# m1 -> PRODUCT
# 1 -> CARDINAL
# 2 -> CARDINAL
# 3 -> CARDINAL
# 3.1 -> CARDINAL
# 1 -> CARDINAL
# at least 10 m. -> QUANTITY
# 3.2 -> CARDINAL
#  0.5 mrad -> MONEY
# ±0.05 per cent -> PERCENT
# 3.3 -> CARDINAL
# 0.5 mrad -> QUANTITY
# 0.05 per cent -> PERCENT
# 3.4 -> CARDINAL
# between 10 and 30 ° -> QUANTITY
# 4 -> CARDINAL
# 4.1 -> CARDINAL
# between 1,000 km and 10,000 km -> QUANTITY
# 5,000 km -> QUANTITY
# 4.2 -> CARDINAL
# less than 90 per cent -> PERCENT
# 4.3 -> CARDINAL
# 6 114 4.4 -> CARDINAL
# at least 8 h -> DATE
# 3.4. -> CARDINAL
# 4.5 -> CARDINAL
# 5 -> CARDINAL
# 5.1 -> CARDINAL
# 5 -> CARDINAL
# 5.5. -> CARDINAL
# 5.1.1 -> CARDINAL
# 5.2 -> CARDINAL
# 4 -> CARDINAL
# 5 -> CARDINAL
# first -> ORDINAL
# 5.4. -> CARDINAL
# three -> CARDINAL
# 5.2.1 -> CARDINAL
# three -> CARDINAL
# more than 2 mrad -> QUANTITY
# 0.2 per cent -> PERCENT
# 5.2.2 -> CARDINAL
# 2 mrad -> QUANTITY
# 0.2 per cent -> PERCENT
# 10 -> CARDINAL
# 5.3 -> CARDINAL
# ±0.2 mrad -> QUANTITY
# ±0.02 per cent -> PERCENT
# 5.4 -> CARDINAL
# 5.4.1. -> CARDINAL
# at least three -> CARDINAL
# first -> ORDINAL
# 6 115 -> CARDINAL
# m2 -> PRODUCT
# m3 -> PRODUCT
# n -> PRODUCT
# 5.4.2.1 -> CARDINAL
# 5.4.1. -> CARDINAL
# 5.4.2.2. -> CARDINAL
# 5.4.2.3. -> CARDINAL
# 5.4.2.2 -> CARDINAL
# 5.4.2.3 -> CARDINAL
# 5.4.3 -> CARDINAL
# 5.5 -> CARDINAL
# 5.2. -> CARDINAL
# 5 -> CARDINAL
# 5.5.1 -> CARDINAL
# 4 mrad -> QUANTITY
# 0.4 per cent -> PERCENT
# 5.5.2 -> CARDINAL
# 5.5.1 -> CARDINAL
# three -> CARDINAL
# 5.5.3 -> CARDINAL
# 5.5 -> CARDINAL
# 5.5.3.1 -> CARDINAL
# three -> CARDINAL
# more than 2 mrad -> QUANTITY
# 0.2 per cent -> PERCENT
# 5.5.3.2 -> CARDINAL
# more than 2 mrad -> QUANTITY
# 0.2 per cent -> PERCENT
# 10 -> CARDINAL
# 6 116 -> CARDINAL
# 5.5.3.3 -> CARDINAL
# 5.5.3.1. -> CARDINAL
# 5.5.3.2 -> CARDINAL
# 5.5.4 -> CARDINAL
# 5.2 -> CARDINAL
# 5.5.1 -> CARDINAL
# 5.5.5 -> CARDINAL
# one -> CARDINAL
# annex 7 117 annex 7 -> LAW
# 6.2.6.1.1. -> CARDINAL
# 1 -> CARDINAL
# 2 -> CARDINAL
# 1. -> CARDINAL
# 1.1. -> CARDINAL
# one -> CARDINAL
# 1.1.1 -> CARDINAL
# 1.2 -> CARDINAL
# 1.3 -> CARDINAL
# 1.4 -> CARDINAL
# 1 -> CARDINAL
# five -> CARDINAL
# four -> CARDINAL
# 2 -> CARDINAL
# 1 -> CARDINAL
# 1.1. -> CARDINAL
# 2.7. -> CARDINAL
# 2.8 -> CARDINAL
# 2.10. -> CARDINAL
# 2.14. -> CARDINAL
# 5.4. -> CARDINAL
# 1.2.1 -> CARDINAL
# 2.13. -> CARDINAL
# 5.3 -> CARDINAL
# 1.2.2 -> CARDINAL
# 1.3 -> CARDINAL
# 7 -> CARDINAL
# 6 -> CARDINAL
# paragraph 4.1. 1.3.2. -> LAW
# 0.2 per cent to 2.8 per -> PERCENT
# 0.8 -> CARDINAL
# 0.2 per cent to 2.8 per cent -> PERCENT
# 0.8 -> CARDINAL
# 1.0 -> CARDINAL
# 0.7 per cent to 3.3 per -> PERCENT
# 0.7 per cent to 3.3 per -> PERCENT
# 1.0 -> CARDINAL
# 1.2 m -> QUANTITY
# 1.2 per cent to 3.8 per -> PERCENT
# 1.2 m. -> QUANTITY
# 9 121 -> CARDINAL
# 2,000 lumens -> QUANTITY
# 0.7 per cent to 3.3 per -> PERCENT
# 0.8 -> CARDINAL
# 1.2 per cent to 3.8 per -> PERCENT
# 0.8 m. -> QUANTITY
# 5 -> CARDINAL
# 2.1.1.1 -> CARDINAL
# 2.1.1.6. -> CARDINAL
# 2.1.2. -> CARDINAL
# 1.3.2 -> CARDINAL
# 2.2.1 -> CARDINAL
# 2.2.2 -> CARDINAL
# 1.3.2 -> CARDINAL
# 2.3.1.1 -> CARDINAL
# 2.3.1.2. -> CARDINAL
# 4 -> CARDINAL
# 1.3.2.4 -> CARDINAL
# 1 -> CARDINAL
# 2.4.1.1 -> CARDINAL
# 2.4.1.2 -> CARDINAL
# 1.3.2.4 -> CARDINAL
# 2 -> CARDINAL
# 2.4.2.1 -> CARDINAL
# 2.4.2.2. -> CARDINAL
# 5.14. -> CARDINAL
# 9 122 1.6 -> CARDINAL
# 5.15 -> CARDINAL
# 5.16. -> CARDINAL
# 11 124 -> CARDINAL
# 4° -> QUANTITY
# 4° -> QUANTITY
# 11 -> CARDINAL
# 6.21.5. -> CARDINAL
# 25 m -> QUANTITY
# 25 m -> QUANTITY
# 11 125 -> CARDINAL
# 4° -> QUANTITY
# 2 -> CARDINAL
# 25 m -> QUANTITY
# 12 -> CARDINAL
# 12 -> CARDINAL
# 1 -> CARDINAL
# 1.1 -> CARDINAL
# 1.2 -> CARDINAL
# 1 -> CARDINAL
# 1 -> CARDINAL
# 50 ± 10 km/h -> QUANTITY
# 100 ± 20 km/h -> QUANTITY
# 80 ± 20 km/h -> QUANTITY
# 10 per cent -> PERCENT
# 20 per cent -> PERCENT
# 70 per -> PERCENT
# 6.1.9.3.1.2 -> CARDINAL
# 1 -> CARDINAL
# > 2,000 m -> QUANTITY
# wmo -> ORG
# sixth -> ORDINAL
# 92-63-16008- -> CARDINAL
# 1. 9. 1/ -> CARDINAL
# geneva -> ORG
# 12 127 1.3 -> CARDINAL
# 1.4 -> CARDINAL
# two -> CARDINAL
# four or more -> CARDINAL
# 1.5 -> CARDINAL
# more than 600 m. -> QUANTITY
# 2 -> CARDINAL
# 2.2 -> CARDINAL
# 2 -> CARDINAL
# 2 -> CARDINAL
# 50 ± 10km/h 100 ± 20km/h 80 ± 20km/h average percentage of the full test course length -> QUANTITY
# 10 per cent -> PERCENT
# 20 per cent -> PERCENT
# 70 per cent -> PERCENT
# 6.22.9.3.1.2 -> CARDINAL
# 2 -> CARDINAL
# > 2,000 m -> QUANTITY
# wmo -> ORG
# sixth -> ORDINAL
# 92-63-16008 -> CARDINAL
# 1. 9 -> CARDINAL
# 1996 -> DATE
# 12 128 -> CARDINAL
# 2.4 -> CARDINAL
# two -> CARDINAL
# four or more -> CARDINAL
# 2.5 -> CARDINAL
# more than 600 m. -> QUANTITY
# 2.6 -> CARDINAL
# 2.7 -> CARDINAL
# annex 13 129 -> LAW
# less than 1,000 lux -> QUANTITY
# between 1,000 lux -> TIME
# 7,000 lux -> QUANTITY
# 7,000 lux -> QUANTITY
# more than 5 seconds -> TIME
# 2 -> CARDINAL
# the type approval authority -> ORG
# annex 14 130 annex 14 -> LAW
# 2.34. -> CARDINAL
#
# Extracted Relationships:

# %%
import spacy
from spacy.pipeline import EntityRuler
from spacy.matcher import Matcher

# Load a transformer-based model for better NER
nlp = spacy.load("en_core_web_trf")  # More accurate than en_core_web_sm

# Add an entity ruler to improve NER
def add_entity_patterns(nlp):
    ruler = nlp.add_pipe("entity_ruler", before="ner")

    patterns = [
        {"label": "REGULATION", "pattern": "Regulation No. 48"},
        {"label": "REGULATION", "pattern": "Regulation No. 107"},
        {"label": "VEHICLE_TYPE", "pattern": "M3"},
        {"label": "VEHICLE_TYPE", "pattern": "N2"},
        {"label": "VEHICLE_TYPE", "pattern": "trailers"},
        {"label": "COMPONENT", "pattern": "headlamps"},
        {"label": "COMPONENT", "pattern": "rear fog lamps"},
        {"label": "TECHNOLOGY", "pattern": "adaptive front-lighting system"},
        {"label": "CERTIFICATION_BODY", "pattern": "UNECE"},
        {"label": "CERTIFICATION_BODY", "pattern": "Geneva agreement"},
        {"label": "TESTING_STANDARD", "pattern": "photometric measurements"},
        {"label": "GEOGRAPHIC_REGION", "pattern": "European Union"},
        {"label": "GEOGRAPHIC_REGION", "pattern": "United Nations"},
    ]
    ruler.add_patterns(patterns)

# Function to load text from a saved file
def load_text_from_file(text_file_path):
    with open(text_file_path, "r", encoding="utf-8") as file:
        return file.read()

# Function for rule-based Relation Extraction
def extract_relationships(doc):
    matcher = Matcher(nlp.vocab)

    relations = [
        ("REGULATION", "applies_to", "VEHICLE_TYPE"),
        ("TECHNOLOGY", "uses", "COMPONENT"),
        ("CERTIFICATION_BODY", "certifies", "REGULATION"),
        ("REGULATION", "enforced_in", "GEOGRAPHIC_REGION"),
        ("TESTING_STANDARD", "evaluates", "TECHNOLOGY"),
        ("COMPONENT", "integrated_into", "TECHNOLOGY"),
    ]

    extracted_relations = []

    for ent1, rel, ent2 in relations:
        pattern = [
            {"ENT_TYPE": ent1},
            {"LOWER": rel, "OP": "?"},
            {"ENT_TYPE": ent2}
        ]
        matcher.add(rel, [pattern])

    matches = matcher(doc)
    for match_id, start, end in matches:
        span = doc[start:end]
        relation = nlp.vocab.strings[match_id]
        extracted_relations.append((span[0].text, relation, span[-1].text))

    return extracted_relations

# %%
# Load text from the provided file
text_file_path = "/content/drive/MyDrive/KnowledgeGraphResults/cleaned_text1.txt"
text = load_text_from_file(text_file_path)

# Apply enhanced spaCy NLP
add_entity_patterns(nlp)
doc = nlp(text)
# Out:
# /usr/local/lib/python3.11/dist-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):

# %%
# Print improved Named Entities
print("🔹 Improved Named Entities:")
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# 🔹 Improved Named Entities:
# 2 -> CARDINAL
# 16 october 1995 -> DATE
# 47 -> CARDINAL
# 12 -> CARDINAL
# 06 -> DATE
# 1 -> CARDINAL
# 06 -> DATE
# 15 july 2013 -> DATE
# 1 -> CARDINAL
# 1 -> CARDINAL
# 06 -> DATE
# 13 march 2013 -> DATE
# 2 -> CARDINAL
# 06 -> DATE
# 3 november 2013 -> DATE
# 3 -> CARDINAL
# 06 -> DATE
# 10 june 2014 -> DATE
# 4 -> CARDINAL
# 06 -> DATE
# 9 october 2014 -> DATE
# united nations -> GPE
# geneva -> FAC
# 20 march 1958 -> DATE
# 16 october 2014 -> DATE
# 3 -> CARDINAL
# 1 -> CARDINAL
# 2 -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 6.2.6.1.1. -> CARDINAL
# headlamps -> COMPONENT
# 129 14 -> CARDINAL
# photometric measurements -> TESTING_STANDARD
# 2.34. -> CARDINAL
# trailers -> VEHICLE_TYPE
# 2 -> CARDINAL
# 2.1 -> CARDINAL
# 2.2 -> CARDINAL
# 2.2.1 -> CARDINAL
# 2.2 -> CARDINAL
# 4 -> CARDINAL
# 2.2.1 -> CARDINAL
# 2.2.4. -> CARDINAL
# 2.3 -> CARDINAL
# 2.4 -> CARDINAL
# 2.5 -> CARDINAL
# 5 -> CARDINAL
# 2.6 -> CARDINAL
# one -> CARDINAL
# 2.6.1 -> CARDINAL
# 2.6.2 -> CARDINAL
# 1 -> CARDINAL
# the consolidated resolution on the construction of vehicles -> LAW
# 6 2.7 -> CARDINAL
# regulation no. 107 -> LAW
# m3 -> PRODUCT
# 2.7.1 -> CARDINAL
# one or more -> CARDINAL
# one or more -> CARDINAL
# 2.7.1.1.3 -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# 2.7.1.1.4 -> CARDINAL
# one -> CARDINAL
# 2.7.1.1.5 -> CARDINAL
# 2.7.1.1.6 -> CARDINAL
# one or more -> CARDINAL
# 2.7.1.1.7 -> CARDINAL
# one or more -> CARDINAL
# 2.7.1.2 -> CARDINAL
# one -> CARDINAL
# 2.7.1.2.1 -> CARDINAL
# 2.7.1.2.2 -> CARDINAL
# 2.7.2 -> CARDINAL
# 2.7.3 -> CARDINAL
# 2.7.3.1 -> CARDINAL
# 2.7.4 -> CARDINAL
# 2.7.5 -> CARDINAL
# 2.7.6 -> CARDINAL
# 2.7.7 -> CARDINAL
# 2.7.8 -> CARDINAL
# 2.7.9 -> CARDINAL
# 2.7.10 -> CARDINAL
# 2.7.10.1 -> CARDINAL
# 2 -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 3 -> CARDINAL
# 3 -> CARDINAL
# 7 -> CARDINAL
# regulation no. 97. -> LAW
# 2.7.13 -> CARDINAL
# 2.7.14 -> CARDINAL
# 2.7.15 -> CARDINAL
# 2.7.16 -> CARDINAL
# 2.7.16.2. -> CARDINAL
# european -> NORP
# 2.7.16.3. -> CARDINAL
# 2.7.16.4 -> CARDINAL
# regulation no. 104 -> LAW
# 2.7.17 -> CARDINAL
# trailers -> VEHICLE_TYPE
# 2.7.17.1 -> CARDINAL
# 2.7.17.1.1 -> CARDINAL
# 2.7.17.1.2 -> CARDINAL
# 2.7.17.2 -> CARDINAL
# 2.7.18 -> CARDINAL
# 2.7.19 -> CARDINAL
# 2.7.20 -> CARDINAL
# 2.7.21 -> CARDINAL
# 2.7.22 -> CARDINAL
# 2.7.23 -> CARDINAL
# trailers -> VEHICLE_TYPE
# 2.7.24 -> CARDINAL
# 2.7.25 -> CARDINAL
# daytime -> TIME
# 2.7.26 -> CARDINAL
# 2.7.27 -> CARDINAL
# 2.7.28 -> CARDINAL
# regulation no. 123 -> LAW
# 2.7.28.1 -> CARDINAL
# one or more -> CARDINAL
# 2.7.28.2 -> CARDINAL
# one -> CARDINAL
# 2.7.28.3 -> CARDINAL
# afs -> PRODUCT
# 10 -> CARDINAL
# afs -> PRODUCT
# 2.7.28.5 -> CARDINAL
# 6.22.7.4. -> CARDINAL
# 2.7.28.6 -> CARDINAL
# 2.7.28.7 -> CARDINAL
# 2.7.29 -> CARDINAL
# 2.7.30 -> CARDINAL
# two -> CARDINAL
# three -> CARDINAL
# 2.7.30.1 -> CARDINAL
# 2.7.31 -> CARDINAL
# 2.8 -> CARDINAL
# 3 -> CARDINAL
# 1 -> CARDINAL
# 4 -> CARDINAL
# one -> CARDINAL
# 3 -> CARDINAL
# 5 -> CARDINAL
# 2.8.1 -> CARDINAL
# 2.9 -> CARDINAL
# 3 -> CARDINAL
# 2.9.1 -> CARDINAL
# 2.7.9 -> CARDINAL
# 2.7.10 -> CARDINAL
# 2.7.19 -> CARDINAL
# 2.7.21 -> CARDINAL
# 2.7.26 -> CARDINAL
# headlamps -> COMPONENT
# paragraph 2.9.2. -> LAW
# afs -> PRODUCT
# two -> CARDINAL
# 6.22.4 -> CARDINAL
# 8 -> CARDINAL
# 9 -> CARDINAL
# 11 -> CARDINAL
# 2.9.2 -> CARDINAL
# 2.7.11 -> CARDINAL
# 2.7.18. -> CARDINAL
# 2.7.20 -> CARDINAL
# 2.7.22. -> CARDINAL
# only 98 per cent -> PERCENT
# two -> CARDINAL
# 3 -> CARDINAL
# 2 -> CARDINAL
# 3 -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 2.9.3 -> CARDINAL
# 2.7.16 -> CARDINAL
# 2.10 -> CARDINAL
# 2.7.1.3. -> CARDINAL
# 12 -> CARDINAL
# 3 -> CARDINAL
# 2.11 -> CARDINAL
# 0 -> CARDINAL
# photometric measurements -> TESTING_STANDARD
# 2.12 -> CARDINAL
# 2.13 -> CARDINAL
# 2.14 -> CARDINAL
# 2.14.1 -> CARDINAL
# 2.14.2. -> CARDINAL
# 2.14.3. -> CARDINAL
# 2.14.4. -> CARDINAL
# 2.14.5 -> CARDINAL
# 2.14.6 -> CARDINAL
# 2.7 -> CARDINAL
# 2.15 -> CARDINAL
# two -> CARDINAL
# 2.14. -> CARDINAL
# 2.15.1 -> CARDINAL
# two -> CARDINAL
# 2.14. -> CARDINAL
# 2.15.2 -> CARDINAL
# two -> CARDINAL
# trailers -> VEHICLE_TYPE
# one -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# 60 per cent -> PERCENT
# two -> CARDINAL
# two -> CARDINAL
# 60 per cent -> PERCENT
# two -> CARDINAL
# 15 mm -> QUANTITY
# two -> CARDINAL
# three -> CARDINAL
# 75 mm -> QUANTITY
# 2.16.2 -> CARDINAL
# two -> CARDINAL
# at least 0.4 m -> QUANTITY
# 0.8 m -> QUANTITY
# 60 per cent -> PERCENT
# 2.17 -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# 14 -> CARDINAL
# 2.18 -> CARDINAL
# 2.19 -> CARDINAL
# 2.20 -> CARDINAL
# 2.21 -> CARDINAL
# 2.22 -> CARDINAL
# 2.23 -> CARDINAL
# 2.24 -> CARDINAL
# 2.24.1. -> CARDINAL
# 2.23 -> CARDINAL
# 2.24.2 -> CARDINAL
# 2.24.1. -> CARDINAL
# 2.23 -> CARDINAL
# 2.25 -> CARDINAL
# 2.25.1 -> CARDINAL
# 2.23 -> CARDINAL
# 2.25.2 -> CARDINAL
# 2.25.1 -> CARDINAL
# 2.23 -> CARDINAL
# 2.26 -> CARDINAL
# 2.27 -> CARDINAL
# 2.27.1 -> CARDINAL
# 2.28 -> CARDINAL
# 2.29.1 -> CARDINAL
# 0.150 -> CARDINAL
# 0.440 -> CARDINAL
# 0.500 -> CARDINAL
# 0.382 -> CARDINAL
# 0.050 -> CARDINAL
# 0.310 -> CARDINAL
# 1.290 -> CARDINAL
# 0.138 -> CARDINAL
# 0.440 -> CARDINAL
# 15.2, 1986 -> DATE
# 1931 -> DATE
# 16 2.29.4 -> CARDINAL
# 0.980 -> CARDINAL
# regulation no. 88 -> LAW
# 0.843 -> CARDINAL
# 0.200 x + 0.268 y41 -> QUANTITY
# 17 -> CARDINAL
# 2.31.1 -> CARDINAL
# 0.740 -> CARDINAL
# 0,050 -> CARDINAL
# 0.570 -> CARDINAL
# 2.31.2 -> CARDINAL
# 0.534 -> CARDINAL
# 0.346 -> CARDINAL
# 0.910 -> CARDINAL
# 0.350 -> CARDINAL
# 2.32 -> CARDINAL
# 2.32.1 -> CARDINAL
# 0.346 -> CARDINAL
# 0.053 -> CARDINAL
# 0.910 -> CARDINAL
# 0.315 -> CARDINAL
# 2.34 -> CARDINAL
# photometric measurements -> TESTING_STANDARD
# cie -> ORG
# second -> ORDINAL
# 14 -> CARDINAL
# cie -> ORG
# 2.35 -> CARDINAL
# 19 3 -> CARDINAL
# 3.1 -> CARDINAL
# 3.2 -> CARDINAL
# 3.2.1 -> CARDINAL
# 2.2.1 -> CARDINAL
# 3.2.2 -> CARDINAL
# 3.2.3. -> CARDINAL
# 3.2.4. -> CARDINAL
# 2.9. -> CARDINAL
# 2.8 -> CARDINAL
# 2.11. -> CARDINAL
# 2.12 -> CARDINAL
# 2.7.13 -> CARDINAL
# 3.2.5 -> CARDINAL
# 2.10 -> CARDINAL
# . -> CARDINAL
# 3.2.6 -> CARDINAL
# afs -> PRODUCT
# afs -> PRODUCT
# afs -> ORG
# regulation no. 123 -> LAW
# 6.22.9.2. -> CARDINAL
# 3.2.6.6. -> CARDINAL
# 6.22.5. -> CARDINAL
# 3.2.7 -> CARDINAL
# 2.7.9 -> CARDINAL
# 2.7.10. -> CARDINAL
# 2.7.12 -> CARDINAL
# 2.7.14 -> CARDINAL
# 2.7.15. -> CARDINAL
# 3.2.2. -> CARDINAL
# 3.4 -> CARDINAL
# 1 -> CARDINAL
# 4 -> CARDINAL
# 4.1 -> CARDINAL
# 4.2 -> CARDINAL
# first -> ORDINAL
# 06 -> DATE
# 06 -> DATE
# 3.2.2. -> CARDINAL
# 7 -> CARDINAL
# 4.3 -> CARDINAL
# 1958 -> DATE
# 1 -> CARDINAL
# 4.4 -> CARDINAL
# 5 4.4.2 -> CARDINAL
# 4.4.1 -> CARDINAL
# 4.5 -> CARDINAL
# one -> CARDINAL
# 4.4.1 -> CARDINAL
# 4.4.1 -> CARDINAL
# 4.6 -> CARDINAL
# 1958 -> DATE
# 3 -> CARDINAL
# the consolidated resolution on the construction of vehicles -> LAW
# 4.8. -> CARDINAL
# 5 -> CARDINAL
# 5.1 -> CARDINAL
# 2.24 -> CARDINAL
# 2.24.1. -> CARDINAL
# 2.24.2 -> CARDINAL
# 5.2 -> CARDINAL
# 2.7.9. -> CARDINAL
# 2.7.10. -> CARDINAL
# 2.7.19 -> CARDINAL
# 5.2.1 -> CARDINAL
# headlamps -> COMPONENT
# 5.3 -> CARDINAL
#  3° -> QUANTITY
# 5.4 -> CARDINAL
# 2.24 -> CARDINAL
# 2.24.1. -> CARDINAL
# 2.24.2 -> CARDINAL
# 5. -> CARDINAL
# 2.9 -> CARDINAL
# 5.5.2. -> CARDINAL
# 5.5.3 -> CARDINAL
# 22 5.5.4 -> CARDINAL
# 5.6 -> CARDINAL
# 5.7 -> CARDINAL
# 5.7.1 -> CARDINAL
# one -> CARDINAL
# 5.7.1.3.1 -> CARDINAL
# more than two -> CARDINAL
# 5.7.2 -> CARDINAL
# two -> CARDINAL
# 5.7.2.1 -> CARDINAL
# 60 per cent -> PERCENT
# two -> CARDINAL
# 15 mm -> QUANTITY
# 5.7.2.2 -> CARDINAL
# 75 mm -> QUANTITY
# 5.8 -> CARDINAL
# 5.8.2 -> CARDINAL
# 5.8.3 -> CARDINAL
# 5.9 -> CARDINAL
# 5.9.1 -> CARDINAL
# paragraph 6.18.7 -> LAW
# 5.9 -> CARDINAL
# 2 -> CARDINAL
# 5.10 -> CARDINAL
# 2.7. -> CARDINAL
# 2.7 -> CARDINAL
# 1 -> CARDINAL
# 4 -> CARDINAL
# 2 -> CARDINAL
# 25 m -> QUANTITY
# 4 -> CARDINAL
# 1 -> CARDINAL
# 2 -> CARDINAL
# 5.10.3.1 -> CARDINAL
# two -> CARDINAL
# 1 m -> QUANTITY
# 2.2 m -> QUANTITY
# 24 5.10.3.2 -> CARDINAL
# two -> CARDINAL
# 15° -> QUANTITY
# 5.11 -> CARDINAL
# 5.11 -> CARDINAL
# 5.12.1. -> CARDINAL
# 5.11.3 -> CARDINAL
# 5.12 -> CARDINAL
# headlamps -> COMPONENT
# 5.11. -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 6.9.5 -> CARDINAL
# 5.12.1.3. -> CARDINAL
# 5.12.1.2. -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 5.14.2 -> CARDINAL
# 5.14.3 -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 5.14.4 -> CARDINAL
# 5.14.5 -> CARDINAL
# -30 °c to +50 ° -> QUANTITY
# headlamps -> COMPONENT
# three seconds -> TIME
# 5 -> CARDINAL
# 7 -> CARDINAL
# 26 -> CARDINAL
# 5.16 -> CARDINAL
# 5.16.1 -> CARDINAL
# 5.17 -> CARDINAL
# 5.18 -> CARDINAL
# 5.19. -> CARDINAL
# 5.20. -> CARDINAL
# 5.18 -> CARDINAL
# 5.18.1 -> CARDINAL
# 5.18. -> CARDINAL
# two -> CARDINAL
# 2.16.1 -> CARDINAL
# only one -> CARDINAL
# 5.18.4 -> CARDINAL
# paragraph 5.18. -> LAW
# 5.18.1. -> CARDINAL
# 5.19 -> CARDINAL
# 5.20 -> CARDINAL
# 28 -> CARDINAL
# headlamps -> COMPONENT
# 10 -> CARDINAL
# more than 0.15 per cent -> PERCENT
# 10 -> CARDINAL
# paragraph 6.2.6.1.1. -> LAW
# annex 6 -> LAW
# . 5.21 -> CARDINAL
# more than 50 per cent -> PERCENT
# 5.21.1 -> CARDINAL
# more than 50 per cent -> PERCENT
# 10.1 -> CARDINAL
# annex 1 -> LAW
# more than 50 per cent -> PERCENT
# 5.21.3 -> CARDINAL
# 5.21.2. -> CARDINAL
# 5.22 -> CARDINAL
# 5.23 -> CARDINAL
# regulation no. -> LAW
# 5.23.1 -> CARDINAL
# regulation no. 37 -> LAW
# 5.23. -> CARDINAL
# 5.24 -> CARDINAL
# 29 -> CARDINAL
# 2.18 -> CARDINAL
# 5.25 -> CARDINAL
# afs -> PRODUCT
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 5.26 -> CARDINAL
# rear fog lamps -> COMPONENT
# at least -> CARDINAL
# one -> CARDINAL
# 5.27 -> CARDINAL
# 2.7.9 -> CARDINAL
# 2.7.10 -> CARDINAL
# 2.7.12 -> CARDINAL
# 2.7.14 -> CARDINAL
# 2.7.15 -> CARDINAL
# 5.27.1 -> CARDINAL
# secondary -> ORDINAL
# 5.27.2 -> CARDINAL
# 5.27.1 -> CARDINAL
# 6.75 v -> QUANTITY
# 6 volt -> QUANTITY
# 13.5 v -> QUANTITY
# 12 volt -> QUANTITY
# 28 v -> QUANTITY
# 24 volt -> QUANTITY
# more than 3 per cent -> PERCENT
# 5.27.3 -> CARDINAL
# 5.27.1. -> CARDINAL
# 5.27.2. -> CARDINAL
# 5.27.4 -> CARDINAL
# 5.28 -> CARDINAL
# 5.28.1 -> CARDINAL
# 5.28.2 -> CARDINAL
# 30 -> CARDINAL
# 5.28.4 -> CARDINAL
# less than 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 5º below the horizontal. -> QUANTITY
# 5.28.5 -> CARDINAL
# 5.29 -> CARDINAL
# 6 -> CARDINAL
# 6.1 -> CARDINAL
# regulations nos. 98 -> LAW
# 112 -> CARDINAL
# 6.1.1 -> CARDINAL
# trailers -> VEHICLE_TYPE
# 6.1.2 -> CARDINAL
# two -> CARDINAL
# four -> CARDINAL
# 98 -> CARDINAL
# 112 -> CARDINAL
# two -> CARDINAL
# headlamps -> COMPONENT
# four -> CARDINAL
# headlamps -> COMPONENT
# two -> CARDINAL
# headlamps -> COMPONENT
# 5.12 -> CARDINAL
# 6.1.3 -> CARDINAL
# 6.1.4. -> CARDINAL
# 6.1.4. -> CARDINAL
# 31 -> CARDINAL
# 6.1.7 -> CARDINAL
# 6.1.7.1 -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 6.1.7.2 -> CARDINAL
# headlamps -> COMPONENT
# 6.1.7.3 -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 6.1.7.4 -> CARDINAL
# headlamps -> COMPONENT
# two -> CARDINAL
# headlamps -> COMPONENT
# paragraph 6.1.2 -> LAW
# no more than two -> CARDINAL
# at least one -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 6.1.7.5 -> CARDINAL
# four -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 5.12 -> CARDINAL
# . -> CARDINAL
# 6.1.8 -> CARDINAL
# 6.1.8.1 -> CARDINAL
# headlamps -> COMPONENT
# 6.1.7.1 -> CARDINAL
# 6.1.9 -> CARDINAL
# 6.1.9.1 -> CARDINAL
# headlamps -> COMPONENT
# 430,000 cd -> QUANTITY
# 100 -> CARDINAL
# 6.1.9.2 -> CARDINAL
# 10 -> CARDINAL
# headlamps -> COMPONENT
# 6.1.9 -> CARDINAL
# 3 -> CARDINAL
# headlamps -> COMPONENT
# 6.1.9.3.1 -> CARDINAL
# headlamps -> COMPONENT
# paragraph 6.1.7.1 -> LAW
# 6.1.9.3.1.1 -> CARDINAL
# 6.1.9.3.1.1 -> CARDINAL
# 1 -> CARDINAL
# 15° -> QUANTITY
# 15° -> QUANTITY
# 5° -> QUANTITY
# less than 2 m -> QUANTITY
# between 1.5 m -> QUANTITY
# 2.5 m -> QUANTITY
# 2° 2° to 5° 5° -> QUANTITY
# at least 400 m -> QUANTITY
# trailers -> VEHICLE_TYPE
# at least 100 m -> QUANTITY
# at least 75 m -> QUANTITY
# 150 cd -> QUANTITY
# 10 cm² ± 3 cm² -> QUANTITY
# 0.8 m. -> QUANTITY
# headlamps -> COMPONENT
# 6.1.9.3.2 -> CARDINAL
# 6.1.7.1. -> CARDINAL
# 6.1.9.3 -> CARDINAL
# 3 -> CARDINAL
# the type approval authority -> ORG
# 1 -> CARDINAL
# 12 -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 6.1.7.1 -> CARDINAL
# 6.1.9.3.1.1 -> CARDINAL
# 6.1.9.3.1.2. -> CARDINAL
# 6.1.9.3.5 -> CARDINAL
# 6.1.9.3.5 -> CARDINAL
# headlamps -> COMPONENT
# 6.1.7.1 -> CARDINAL
# 6.1.9.3.1.1 -> CARDINAL
# 6.1.9.3.1.2 -> CARDINAL
# 7000 lx -> QUANTITY
# the type approval authority -> ORG
# 6.2. -> CARDINAL
# 98 -> CARDINAL
# 6.2.1 -> CARDINAL
# trailers -> VEHICLE_TYPE
# 6.2.2 -> CARDINAL
# two -> CARDINAL
# 98 -> CARDINAL
# 112 -> CARDINAL
# 6.2.3 -> CARDINAL
# 34 6.2.4 -> CARDINAL
# 6.2.4 -> CARDINAL
# 1 -> CARDINAL
# more than 400 mm -> QUANTITY
# 400 mm -> QUANTITY
# 1,300 mm -> QUANTITY
# 6.2.4 -> CARDINAL
# 500 mm -> QUANTITY
# more than 1,200 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 6.2.4 -> CARDINAL
# 3 -> CARDINAL
# 6.2.5 -> CARDINAL
# 2.13 -> CARDINAL
# 15° -> QUANTITY
# 10° -> QUANTITY
# 45° -> QUANTITY
# 10° -> QUANTITY
# secondary -> ORDINAL
# one -> CARDINAL
# 0.1 per cent -> PERCENT
# 7 -> CARDINAL
# annex 5 -> LAW
# 10 -> CARDINAL
# the consolidated resolution on the construction of vehicles -> LAW
# 35 -> CARDINAL
# 0.8 -> CARDINAL
# between -0.5 per cent and -2.5 per cent -> PERCENT
# between -1.0 per cent and -1.5 per cent -> PERCENT
# 0.8 -> CARDINAL
# 1.0 -> CARDINAL
# between -0.5 per cent and -2.5 per cent -> PERCENT
# between -1.0 per cent and -1.5 per cent -> PERCENT
# between -1.0 per cent and -3.0 per cent -> PERCENT
# between -1.5 per cent and -2.0 per cent -> PERCENT
# two -> CARDINAL
# 1.0 -> CARDINAL
# between -1.0 per cent and -3.0 per cent -> PERCENT
# between -1.5 per cent and -2.0 per cent -> PERCENT
# headlamps -> COMPONENT
# 1,200 mm -> QUANTITY
# -1.5 per cent and -3.5 per cent -> PERCENT
# between:-2 per cent and -2.5 per cent -> PERCENT
# 36 6.2.6.2 -> CARDINAL
# 6.2.6.1.1 -> CARDINAL
# 6.2.6.1.2. -> CARDINAL
# 6.2.6.2.2 -> CARDINAL
# paragraph 6.2.6.1.1 -> LAW
# 6.2.6.1.2 -> CARDINAL
# 5 -> CARDINAL
# annex 5 -> LAW
# 37 -> CARDINAL
# 6.2.6.2.1 -> CARDINAL
# 6.2.6.2.2. -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# one -> CARDINAL
# headlamps -> COMPONENT
# 100 -> CARDINAL
# headlamps -> COMPONENT
# 6.2.7 -> CARDINAL
# 6.2.7.1 -> CARDINAL
# headlamps -> COMPONENT
# 6.2.7.2 -> CARDINAL
# 6.2.7.3 -> CARDINAL
# headlamps -> COMPONENT
# regulation no. -> LAW
# 6.2.7.4 -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 500 m -> QUANTITY
# 6.2.7.5 -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 6.2.7.6 -> CARDINAL
# headlamps -> COMPONENT
# annex 13 -> LAW
# 5.11. -> CARDINAL
# 38 6.2.7.6.3 -> CARDINAL
# headlamps -> COMPONENT
# two -> CARDINAL
# night -> TIME
# headlamps -> COMPONENT
# regulation no. 121 -> LAW
# headlamps -> COMPONENT
# annex 13 -> LAW
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 6.2.7.6.1. -> CARDINAL
# headlamps -> COMPONENT
# 6.2.8 -> CARDINAL
# 6.2.8.1 -> CARDINAL
# 6.2.8 -> CARDINAL
# 2 -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# 6.2.9 -> CARDINAL
# paragraph 5.5.2 -> LAW
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 39 -> CARDINAL
# 2,000 lumen -> QUANTITY
# regulation no. 45.11 -> LAW
# paragraph 6.2.6.2.2. -> LAW
# headlamps -> COMPONENT
# 2,000 lumens -> QUANTITY
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# regulation nos. 98 -> LAW
# 6.3 -> CARDINAL
# 6.3.1. -> CARDINAL
# trailers -> VEHICLE_TYPE
# 6.3.2. -> CARDINAL
# two -> CARDINAL
# 03 -> DATE
# regulation no. 19 -> LAW
# 6.3.3. -> CARDINAL
# 6.3.4. -> CARDINAL
# 6.3.4. -> CARDINAL
# 1 -> CARDINAL
# more than 400 mm -> QUANTITY
# 6.3.4. -> CARDINAL
# less than 250 mm -> QUANTITY
# m1 -> PRODUCT
# n1 -> PRODUCT
# more than 800 mm -> QUANTITY
# 11 -> CARDINAL
# headlamps -> COMPONENT
# 40 -> CARDINAL
# more than 1,200 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 6.3.4 -> CARDINAL
# 3 -> CARDINAL
# 6.3.5 -> CARDINAL
# 2.13 -> CARDINAL
# 5° -> QUANTITY
# 45° -> QUANTITY
# 10° -> QUANTITY
# secondary -> ORDINAL
# one -> CARDINAL
# -1.5 per cent -> PERCENT
# 13 -> CARDINAL
# 2 -> CARDINAL
# 2,000 lumens -> QUANTITY
# 6.3.6.1.2.1.1 -> CARDINAL
# one -> CARDINAL
# 1.0 per cent -> PERCENT
# 2,000 lumens -> QUANTITY
# annex 5 -> LAW
# 12 -> CARDINAL
# the consolidated resolution on the construction of vehicles -> LAW
# 13 -> CARDINAL
# 18 months -> DATE
# 4 -> CARDINAL
# 03 -> DATE
# 41 -> CARDINAL
# 0.8 -> CARDINAL
# between -1.0 per cent and -3.0 per cent -> PERCENT
# between -1.5 per cent and -2.0 per cent h > 0.8 limits: between -1.5 per cent and -3.5 per cent -> PERCENT
# between -2.0 per cent and -2.5 per cent -> PERCENT
# 6.3.6.1.2.2.2 -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# 7 -> CARDINAL
# 6.3.6.2 -> CARDINAL
# 6.3.6.2.1 -> CARDINAL
# annex 5 -> LAW
# 6.2.6. -> CARDINAL
# paragraph 6.2.6 -> LAW
# 6.3.6.2.3 -> CARDINAL
# 6.3.6.1.2.2.1. -> CARDINAL
# 6.3.6.2.4 -> CARDINAL
# 6.3.7 -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 6.3.8 -> CARDINAL
# 42 6.3.9 -> CARDINAL
# annex 1 -> LAW
# regulation no. 19 -> LAW
# 6.4. -> CARDINAL
# 6.4.1. -> CARDINAL
# trailers -> VEHICLE_TYPE
# trailers -> VEHICLE_TYPE
# 6.4.2 -> CARDINAL
# 6.4.2.1 -> CARDINAL
# one -> CARDINAL
# second -> ORDINAL
# 6,000 mm -> QUANTITY
# 6.4.2.2 -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# 6,000 mm -> QUANTITY
# 6.4.3. -> CARDINAL
# 6.4.4 -> CARDINAL
# 6.4.4 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 1,200 mm -> QUANTITY
# 3 -> CARDINAL
# two -> CARDINAL
# 6.4.2.2. -> CARDINAL
# 6.4.5.2. -> CARDINAL
# 6.4.6.2. -> CARDINAL
# 6.4.5 -> CARDINAL
# 6.4.5 -> CARDINAL
# 1 -> CARDINAL
# 2.13. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 45° -> QUANTITY
# one -> CARDINAL
# 45° -> QUANTITY
# 30° -> QUANTITY
# two -> CARDINAL
# 6.4.5.2 -> CARDINAL
# two -> CARDINAL
# 6.4.2.2 -> CARDINAL
# 15° -> QUANTITY
# two -> CARDINAL
# 6.4.6 -> CARDINAL
# 6.4.6.1 -> CARDINAL
# 43 6.4.6.2 -> CARDINAL
# two -> CARDINAL
# paragraph 6.4.2.2 -> LAW
# 6.4.5.2. -> CARDINAL
# 6.4.7 -> CARDINAL
# 6.4.7.1 -> CARDINAL
# 6.4.7.2 -> CARDINAL
# two -> CARDINAL
# paragraph 6.4.2.2. -> LAW
# 5.11. -> CARDINAL
# 10 km/h -> QUANTITY
# 10 km -> QUANTITY
# 6.4.8 -> CARDINAL
# 6.4.9 -> CARDINAL
# 6.5 -> CARDINAL
# 6 -> CARDINAL
# 6.5.1 -> CARDINAL
# 1 -> CARDINAL
# 2a -> CARDINAL
# 2b -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# trailers -> VEHICLE_TYPE
# 6.5.2 -> CARDINAL
# 6.5.3 -> CARDINAL
# two -> CARDINAL
# 1 -> CARDINAL
# at least 40 mm -> QUANTITY
# 44 1a -> QUANTITY
# one -> CARDINAL
# 20 mm -> QUANTITY
# less than 40 mm -> QUANTITY
# 20 mm -> QUANTITY
# two -> CARDINAL
# 2a -> CARDINAL
# 2b -> CARDINAL
# two -> CARDINAL
# 2a -> CARDINAL
# 2b -> CARDINAL
# m3 -> PRODUCT
# n2 -> PRODUCT
# two -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 5 -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# m2 -> PRODUCT
# m3 -> PRODUCT
# 6 metres -> QUANTITY
# 6 -> CARDINAL
# n2 -> PRODUCT
# n3 -> PRODUCT
# n1 -> PRODUCT
# m2 -> PRODUCT
# m3 -> PRODUCT
# 6 metres -> QUANTITY
# 5 -> CARDINAL
# three -> CARDINAL
# 5 -> CARDINAL
# one -> CARDINAL
# 6 -> CARDINAL
# m2 -> PRODUCT
# m3 -> PRODUCT
# n2 -> PRODUCT
# n3 -> PRODUCT
# 9 m -> QUANTITY
# 1 -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# two -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 6.5 -> CARDINAL
# two -> CARDINAL
# 2a -> CARDINAL
# two -> CARDINAL
# 2a -> CARDINAL
# three -> CARDINAL
# 5 -> CARDINAL
# one -> CARDINAL
# 6 -> CARDINAL
# 9 m -> QUANTITY
# afs -> PRODUCT
# 6.5.4. -> CARDINAL
# more than 400 mm -> QUANTITY
# two -> CARDINAL
# less than 600 mm -> QUANTITY
# 400 mm -> QUANTITY
# less than 1,300 mm -> QUANTITY
# 6.5.4 -> CARDINAL
# 6.5.4.2.1 -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# less than: 350 mm -> QUANTITY
# m1 -> PRODUCT
# n1 -> PRODUCT
# 500 mm -> QUANTITY
# more than: 1,500 mm -> QUANTITY
# 6.5.4.2.2 -> CARDINAL
# 1 -> CARDINAL
# 2b -> CARDINAL
# 5.8 -> CARDINAL
# less than 350 mm -> QUANTITY
# more than 1,500 mm -> QUANTITY
# 6.5.4.2.3 -> CARDINAL
# 2,300 mm -> QUANTITY
# 5 -> CARDINAL
# 6 -> CARDINAL
# 2,100 mm -> QUANTITY
# 1 -> CARDINAL
# 6.5.4.2.4 -> CARDINAL
# 600 mm -> QUANTITY
# 6.5.4.3 -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 1,800 mm -> QUANTITY
# 2,500 mm -> QUANTITY
# m1 -> PRODUCT
# n1 -> PRODUCT
# first -> ORDINAL
# 6.5.5 -> CARDINAL
# 6.5.5 -> CARDINAL
# 1 -> CARDINAL
# 15° -> QUANTITY
# 1 -> CARDINAL
# 5. -> CARDINAL
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 2,100 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 30° -> QUANTITY
# 5° -> QUANTITY
# 6 -> CARDINAL
# 6.5 -> CARDINAL
# 5° -> QUANTITY
# 1.80 m -> QUANTITY
# m1 -> PRODUCT
# n1 -> PRODUCT
# 2.50 m -> QUANTITY
# 1 -> CARDINAL
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 45° -> QUANTITY
# 20° -> QUANTITY
# m1 -> PRODUCT
# n1 -> PRODUCT
# 47 -> CARDINAL
# 5° -> QUANTITY
# 2.50 m -> QUANTITY
# 1 -> CARDINAL
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 45° -> QUANTITY
# 20° -> QUANTITY
# 15° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# at least 12.5 square centimetres -> QUANTITY
# 5 -> CARDINAL
# 6 -> CARDINAL
# 6.5.6. -> CARDINAL
# 6.5.7 -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# less than 6 m -> QUANTITY
# 6.5.5.2 -> CARDINAL
# 6.5.8 -> CARDINAL
# 1 -> CARDINAL
# paragraph 6.4.2. -> LAW
# regulation no. -> LAW
# one -> CARDINAL
# trailers -> VEHICLE_TYPE
# 6.5.9 -> CARDINAL
# 90 ± 30 -> CARDINAL
# one and one-half seconds -> TIME
# first -> ORDINAL
# one -> CARDINAL
# 6.6 -> CARDINAL
# 6.6.1 -> CARDINAL
# 6.5. -> CARDINAL
# 6.6.2 -> CARDINAL
# 6.5.2 -> CARDINAL
# 6.5.3 -> CARDINAL
# 6.6.4 -> CARDINAL
# 6.5.4.1 -> CARDINAL
# 6.6.4 -> CARDINAL
# 6.5.4.2 -> CARDINAL
# 6.6.4 -> CARDINAL
# 3 -> CARDINAL
# 6.5.4.3 -> CARDINAL
# 6.6.5 -> CARDINAL
# 6.5.5 -> CARDINAL
# 6.6.6 -> CARDINAL
# 6.5.6 -> CARDINAL
# 6.6.7 -> CARDINAL
# 6.6.7.1 -> CARDINAL
# 6.6.7.2 -> CARDINAL
# 6.23. -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# less than 6 m -> QUANTITY
# 6.5.5.2. -> CARDINAL
# 6.6.8 -> CARDINAL
# 6.5.9. -> CARDINAL
# 6.7 -> CARDINAL
# 6.7.2 -> CARDINAL
# two -> CARDINAL
# one -> CARDINAL
# two -> CARDINAL
# m2 -> PRODUCT
# m3 -> PRODUCT
# n2 -> PRODUCT
# n3 -> PRODUCT
# one -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# one -> CARDINAL
# 6.7.3 -> CARDINAL
# 6.7.4 -> CARDINAL
# m1 -> PRODUCT
# 50 -> CARDINAL
# more than 400 mm -> QUANTITY
# 400 mm -> QUANTITY
# 1,300 mm -> QUANTITY
# two -> CARDINAL
# paragraph 6.7.2. -> LAW
# one -> CARDINAL
# one -> CARDINAL
# 6.7.2. -> CARDINAL
# 150 mm -> QUANTITY
# 6.7.4 -> CARDINAL
# 6.7.4.2 -> CARDINAL
# 1 -> CARDINAL
# less than 350 mm -> QUANTITY
# more than 1,500 mm -> QUANTITY
# 2,100 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# less than 600 mm -> QUANTITY
# more than 150 mm -> QUANTITY
# less than 850 mm -> QUANTITY
# 6.7.4 -> CARDINAL
# 6.7.4 -> CARDINAL
# 4 -> CARDINAL
# 6.7.4 -> CARDINAL
# 6.7.5 -> CARDINAL
# 45° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 45° -> QUANTITY
# 20° -> QUANTITY
# 10° -> QUANTITY
# 15° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 2,100 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 10° -> QUANTITY
# 5° -> QUANTITY
# 6.7.6 -> CARDINAL
# 6.7.7.1 -> CARDINAL
# 13 -> CARDINAL
# 6.7.7.2 -> CARDINAL
# 6.7.8 -> CARDINAL
# 6.7.9 -> CARDINAL
# 6.8 -> CARDINAL
# 4 -> CARDINAL
# 6.8.2 -> CARDINAL
# 6.8.3 -> CARDINAL
# 52 6.8.4 -> CARDINAL
# 6.8.4 -> CARDINAL
# 1 -> CARDINAL
# 6.8.4 -> CARDINAL
# 2 -> CARDINAL
# 6.8.4 -> CARDINAL
# 3 -> CARDINAL
# 6.8.5 -> CARDINAL
# 6.8.6 -> CARDINAL
# 6.8.7 -> CARDINAL
# 5.11 -> CARDINAL
# 6.8.8 -> CARDINAL
# 6.8.9 -> CARDINAL
# 6.9 -> CARDINAL
# 7 -> CARDINAL
# 6.9.1 -> CARDINAL
# trailers -> VEHICLE_TYPE
# over 1,600 mm -> QUANTITY
# trailers -> VEHICLE_TYPE
# more than 1,600 mm -> QUANTITY
# 6.9.2 -> CARDINAL
# two -> CARDINAL
# 6.9.3 -> CARDINAL
# 6.9.4 -> CARDINAL
# 6.9.4. -> CARDINAL
# more than 400 mm -> QUANTITY
# more than 150 mm -> QUANTITY
# two -> CARDINAL
# 53 -> CARDINAL
# less than 600 mm -> QUANTITY
# 400 mm -> QUANTITY
# less than 1,300 mm -> QUANTITY
# 6.9.4 -> CARDINAL
# 2 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 1,500 mm -> QUANTITY
# 2,100 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 6.9.4. 3 -> CARDINAL
# 6.9.4.4 -> CARDINAL
# 6.9.4.1 -> CARDINAL
# 6.9.4.3 -> CARDINAL
# 6.9.5 -> CARDINAL
# 6.9.5 -> CARDINAL
# 1 -> CARDINAL
# 45° -> QUANTITY
# 80° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 45° -> QUANTITY
# 20° -> QUANTITY
# trailers -> VEHICLE_TYPE
# 5° -> QUANTITY
# 15° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 6.9.5.2. -> CARDINAL
# n1 -> PRODUCT
# 45° -> QUANTITY
# 45° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 45° -> QUANTITY
# 20° -> QUANTITY
# 15° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# at least 12.5 cm2 -> QUANTITY
# 6.9.6 -> CARDINAL
# 6.9.7 -> CARDINAL
# 5.11 -> CARDINAL
# 54 -> CARDINAL
# 6.9.8 -> CARDINAL
# 6.9.9 -> CARDINAL
# 6.9.9.1 -> CARDINAL
# one or more -> CARDINAL
# 6.9.9.2 -> CARDINAL
# 6.10 -> CARDINAL
# 7 -> CARDINAL
# 6.10.2 -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# m2 -> PRODUCT
# m3 -> PRODUCT
# n2 -> PRODUCT
# n3 -> PRODUCT
# o2 -> PRODUCT
# o4 -> PRODUCT
# 6.10.3 -> CARDINAL
# 6.10.4 -> CARDINAL
# 6.10.4 -> CARDINAL
# 1 -> CARDINAL
# more than 400 mm -> QUANTITY
# two -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# less than 600 mm -> QUANTITY
# 400 mm -> QUANTITY
# less than 1,300 mm -> QUANTITY
# 6.10.4. -> QUANTITY
# less than 350 mm -> QUANTITY
# more than 1,500 mm -> QUANTITY
# 2,100 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 55 -> CARDINAL
# 600 mm -> QUANTITY
# 6.10.4. -> QUANTITY
# 6.10.5 -> CARDINAL
# 6.10.5 -> CARDINAL
# 1 -> CARDINAL
# 45° -> QUANTITY
# 80° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 45° -> QUANTITY
# 20° -> QUANTITY
# 15° -> QUANTITY
# 750 mm -> QUANTITY
# paragraph 5.8.1 -> LAW
# 15° -> QUANTITY
# 5° -> QUANTITY
# 2,100 mm -> QUANTITY
# 15° -> QUANTITY
# 5° -> QUANTITY
# 6.10.5.2 -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# paragraph 6.10.5.1. -> LAW
# 45° -> QUANTITY
# 45° -> QUANTITY
# 750 mm -> QUANTITY
# paragraph 5.8.1 -> LAW
# 45° -> QUANTITY
# 20° -> QUANTITY
# 15° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# at least 12.5 square centimetres -> QUANTITY
# 6.10.7 -> CARDINAL
# 5.11 -> CARDINAL
# 6.10.8 -> CARDINAL
# 56 -> CARDINAL
# 6.10.9 -> CARDINAL
# 6.11 -> CARDINAL
# 38 -> CARDINAL
# 6.11.2 -> CARDINAL
# one -> CARDINAL
# two -> CARDINAL
# 6.11.3 -> CARDINAL
# 6.11.4 -> CARDINAL
# 6.11.4. -> CARDINAL
# only one -> CARDINAL
# 2 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 1,000 mm -> QUANTITY
# rear fog lamps -> COMPONENT
# 1,200 mm -> QUANTITY
# 6.11.4 -> CARDINAL
# 3 -> CARDINAL
# 6.11.5 -> CARDINAL
# 2.13 -> CARDINAL
# 5° -> QUANTITY
# 5° -> QUANTITY
# 25° -> QUANTITY
# 6.11.6 -> CARDINAL
# 6.11.7 -> CARDINAL
# 6.11.7.1 -> CARDINAL
# 6.11.7.3.2 -> CARDINAL
# 6.11.8 -> CARDINAL
# 6.11.7.1 -> CARDINAL
# 57 -> CARDINAL
# 6.11.7.1. -> CARDINAL
# 6.11.7.3. -> CARDINAL
# 6.11.7.5. -> CARDINAL
# 6.11.7.5 -> CARDINAL
# 6.11.8 -> CARDINAL
# 6.11.9 -> CARDINAL
# 100 mm -> QUANTITY
# 6.12 -> CARDINAL
# 6.12.1 -> CARDINAL
# 6 m -> QUANTITY
# 2 m -> QUANTITY
# 6.12.2 -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# one -> CARDINAL
# 6.12.4 -> CARDINAL
# more than 400 mm -> QUANTITY
# two -> CARDINAL
# 6.12.4. -> CARDINAL
# 2 -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# less than 350 mm -> QUANTITY
# more than 1,500 mm -> QUANTITY
# 2,100 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 6.12.4. 3. -> QUANTITY
# 6.12.5 -> CARDINAL
# 45° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 45° -> QUANTITY
# 20° -> QUANTITY
# 15° -> QUANTITY
# 58 -> CARDINAL
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 6.12.6 -> CARDINAL
# 6.12.9. -> CARDINAL
# 6.12.8 -> CARDINAL
# 6.12.9 -> CARDINAL
# 6.13 -> CARDINAL
# 7 -> CARDINAL
# 2.10 m -> QUANTITY
# between 1.80 and 2.10 m -> QUANTITY
# 6.13.2 -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# 6.13.3 -> CARDINAL
# 6.13.4 -> CARDINAL
# 6.13.4 -> CARDINAL
# 1 -> CARDINAL
# 59 -> CARDINAL
# more than 400 mm -> QUANTITY
# trailers -> VEHICLE_TYPE
# trailers -> VEHICLE_TYPE
# 6.13.4.3 -> CARDINAL
# paragraph 6.13.4.2 -> LAW
# 400 mm -> QUANTITY
# 6.13.5 -> CARDINAL
# 80° -> QUANTITY
# 5° -> QUANTITY
# 20° -> QUANTITY
# 6.13.6 -> CARDINAL
# 6.13.7 -> CARDINAL
# 5.11 -> CARDINAL
# 6.13.8 -> CARDINAL
# 6.13.9 -> CARDINAL
# one -> CARDINAL
# two -> CARDINAL
# 5.7 -> CARDINAL
# 60 -> CARDINAL
# two -> CARDINAL
# less than 200 mm -> QUANTITY
# 6.14 -> CARDINAL
# 3 -> CARDINAL
# 6.14.1 -> CARDINAL
# trailers -> VEHICLE_TYPE
# 6.14.2 -> CARDINAL
# two -> CARDINAL
# 3 -> CARDINAL
# two -> CARDINAL
# paragraph 6.14.4. -> LAW
# 6.14.3. -> CARDINAL
# 6.14.4 -> CARDINAL
# 6.14.4. -> CARDINAL
# more than 400 mm -> QUANTITY
# two -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# 400 mm -> QUANTITY
# less than 1,300 mm -> QUANTITY
# 6.14.4. -> QUANTITY
# 2 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 900 mm -> QUANTITY
# more than 1,200 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 900 mm -> QUANTITY
# 1200 mm -> QUANTITY
# 6.14.4 -> CARDINAL
# 6.14.5 -> CARDINAL
# 30° -> QUANTITY
# 10° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1. -> CARDINAL
# 10° -> QUANTITY
# 5° -> QUANTITY
# 6.14.6 -> CARDINAL
# 6.14.7 -> CARDINAL
# 61 6.15 -> CARDINAL
# 3 -> CARDINAL
# 6.15.1. -> CARDINAL
# trailers -> VEHICLE_TYPE
# two -> CARDINAL
# 3 -> CARDINAL
# two -> CARDINAL
# 6.15.3 -> CARDINAL
# 6.15.4 -> CARDINAL
# 6.15.4. -> CARDINAL
# more than 400 mm -> QUANTITY
# less than 600 mm -> QUANTITY
# 400 mm -> QUANTITY
# less than 1,300 mm -> QUANTITY
# 6.15.4. -> QUANTITY
# 2 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 900 mm -> QUANTITY
# more than 1,200 mm -> QUANTITY
# 900 mm -> QUANTITY
# 1,200 mm -> QUANTITY
# 6.15.4. -> QUANTITY
# 3 -> CARDINAL
# 6.15.5 -> CARDINAL
# 30° -> QUANTITY
# 15° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 15° -> QUANTITY
# 5° -> QUANTITY
# 6.15.6 -> CARDINAL
# 6.15.7 -> CARDINAL
# 6.16 -> CARDINAL
# 3 -> CARDINAL
# 6.16.1 -> CARDINAL
# trailers -> VEHICLE_TYPE
# 62 -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# paragraph 6.16.4. -> LAW
# 6.16.3. -> CARDINAL
# 6.16.4 -> CARDINAL
# 6.16.4. -> CARDINAL
# 1 -> CARDINAL
# more than 400 mm -> QUANTITY
# farther than 150 mm -> QUANTITY
# two -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# less than 600 mm -> QUANTITY
# 400 mm -> QUANTITY
# 6.16.4 -> CARDINAL
# 2 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 900 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 900 mm -> QUANTITY
# 6.16.4. -> QUANTITY
# 3 -> CARDINAL
# 6.16.5 -> CARDINAL
# 30° -> QUANTITY
# trailers -> VEHICLE_TYPE
# 10° -> QUANTITY
# trailers -> VEHICLE_TYPE
# 6.16.4.1. -> CARDINAL
# 10° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 10° -> QUANTITY
# 5° -> QUANTITY
# 6.16.6 -> CARDINAL
# 6.16.7 -> CARDINAL
# 63 6.17 -> CARDINAL
# 6.17.1 -> CARDINAL
# 6 m. -> QUANTITY
# trailers -> VEHICLE_TYPE
# 6 m. -> QUANTITY
# 6.17.2 -> CARDINAL
# two -> CARDINAL
# paragraph 6.17.4. -> LAW
# 6.17.3 -> CARDINAL
# 6.17.4 -> CARDINAL
# 6.17.4 -> CARDINAL
# 1 -> CARDINAL
# 250 mm -> QUANTITY
# more than 900 mm -> QUANTITY
# more than 1,200 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 900 mm -> QUANTITY
# 1,200 mm -> QUANTITY
# 6.17.1 -> CARDINAL
# 6.17.4 -> CARDINAL
# 3 -> CARDINAL
# at least one -> CARDINAL
# third -> ORDINAL
# further than 3 m -> QUANTITY
# two -> CARDINAL
# 3 m. -> QUANTITY
# n1 -> PRODUCT
# 4 m. -> QUANTITY
# 1 m. -> QUANTITY
# 6 m -> QUANTITY
# one -> CARDINAL
# first -> ORDINAL
# third -> ORDINAL
# third -> ORDINAL
# 6 m -> QUANTITY
# one -> CARDINAL
# first -> ORDINAL
# third -> ORDINAL
# third -> ORDINAL
# m1 -> PRODUCT
# 6 m -> QUANTITY
# 7 m -> QUANTITY
# one -> CARDINAL
# third -> ORDINAL
# 6.17.5 -> CARDINAL
# 45 -> CARDINAL
# 64 -> CARDINAL
# 10° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 10° -> QUANTITY
# 6.17.6 -> CARDINAL
# 6.17.7 -> CARDINAL
# 6.18 -> CARDINAL
# 91 -> CARDINAL
# 6.18.1 -> CARDINAL
# 6 m -> QUANTITY
# sm2 -> PRODUCT
# m1 -> PRODUCT
# m1 -> PRODUCT
# n1 -> PRODUCT
# less than 6 m -> QUANTITY
# 6.9.5.2 -> CARDINAL
# 6.10.5 -> CARDINAL
# 2 -> CARDINAL
# sm1 -> PRODUCT
# 6.18.2 -> CARDINAL
# 6.18.3 -> CARDINAL
# 6.18.4 -> CARDINAL
# 6.18.4 -> CARDINAL
# 1 -> CARDINAL
# 6.18.4 -> CARDINAL
# 2 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 1,500 mm -> QUANTITY
# 2,100 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 6.18.4 -> CARDINAL
# 3 -> CARDINAL
# third -> ORDINAL
# further than 3 m -> QUANTITY
# two -> CARDINAL
# 3 m. -> QUANTITY
# 4 m. -> QUANTITY
# 1 m. -> QUANTITY
# 6 m -> QUANTITY
# one -> CARDINAL
# first -> ORDINAL
# third -> ORDINAL
# third -> ORDINAL
# 6 m -> QUANTITY
# 7 m -> QUANTITY
# one -> CARDINAL
# further than 3 m -> QUANTITY
# one -> CARDINAL
# third -> ORDINAL
# 6.18.5 -> CARDINAL
# 45° -> QUANTITY
# 30° -> QUANTITY
# 6.5.5.2 -> CARDINAL
# 6.9.5.2 -> CARDINAL
# 6.10.5.2 -> CARDINAL
# 45° -> QUANTITY
# 30° -> QUANTITY
# 6.5.5.2 -> CARDINAL
# 10° -> QUANTITY
# 750 mm -> QUANTITY
# 5.8.1 -> CARDINAL
# 10° -> QUANTITY
# 5° -> QUANTITY
# 6.18.6 -> CARDINAL
# 6.18.7 -> CARDINAL
# m1 -> PRODUCT
# n1 -> PRODUCT
# less than 6 m -> QUANTITY
# 6.18.8 -> CARDINAL
# 6.18.9 -> CARDINAL
# 6.19 -> CARDINAL
# trailers -> VEHICLE_TYPE
# regulation no. 87 -> LAW
# 5.22. -> CARDINAL
# two -> CARDINAL
# 6.19.3 -> CARDINAL
# 6.19.4 -> CARDINAL
# 6.19.4 -> CARDINAL
# 1 -> CARDINAL
# less than 600 mm -> QUANTITY
# 400 mm -> QUANTITY
# 1,300 mm -> QUANTITY
# 6.19.4 -> CARDINAL
# 2 -> CARDINAL
# less than 250 mm -> QUANTITY
# more than 1,500 mm -> QUANTITY
# 6.19.4 -> CARDINAL
# 3 -> CARDINAL
# 6.19.5 -> CARDINAL
# 20° -> QUANTITY
# 20° -> QUANTITY
# 10° -> QUANTITY
# 10° -> QUANTITY
# 6.19.6 -> CARDINAL
# 6.19.7 -> CARDINAL
# 6.19.7.1 -> CARDINAL
# first -> ORDINAL
# 10 km/h -> QUANTITY
# 10 km/h -> QUANTITY
# more than 100 m -> QUANTITY
# 6.19.7.3 -> CARDINAL
# headlamps -> COMPONENT
# 15 -> CARDINAL
# 18 months -> DATE
# 4 -> CARDINAL
# 67 -> CARDINAL
# 5.11. -> CARDINAL
# 6.19.7.5 -> CARDINAL
# less than 40 mm -> QUANTITY
# 6.19.7.6 -> CARDINAL
# 6.19.8 -> CARDINAL
# 6.19.9 -> CARDINAL
# 6.20 -> CARDINAL
# 119 -> CARDINAL
# 6.20.1 -> CARDINAL
# 6.20.2 -> CARDINAL
# two -> CARDINAL
# 6.20.3 -> CARDINAL
# 6.20.4 -> CARDINAL
# 6.20.4 -> CARDINAL
# 1 -> CARDINAL
# one -> CARDINAL
# 6.20.4. -> CARDINAL
# 2 -> CARDINAL
# further than 1,000 mm -> QUANTITY
# 6.20.4. -> QUANTITY
# 3 -> CARDINAL
# 250 mm -> QUANTITY
# 6.20.5 -> CARDINAL
# 2.13. -> CARDINAL
# 10° -> QUANTITY
# 30° to 60° -> QUANTITY
# 6.20.7 -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 6.20.7.1 -> CARDINAL
# 6.20.7.2 -> CARDINAL
# 6.20.8 -> CARDINAL
# 6.20.9 -> CARDINAL
# 6.21 -> CARDINAL
# 6.21.1 -> CARDINAL
# 6.21.1 -> CARDINAL
# 1 -> CARDINAL
# 6.21.1 -> CARDINAL
# 2 -> CARDINAL
# 6.21.1.2 -> CARDINAL
# 1 -> CARDINAL
# 2,100 mm -> QUANTITY
# 7.5 tonnes -> QUANTITY
# trailers -> VEHICLE_TYPE
# o4 -> PRODUCT
# 6.21.1.2.2.1 -> CARDINAL
# 6,000 mm -> QUANTITY
# trailers -> VEHICLE_TYPE
# 7.5 tonnes -> QUANTITY
# trailers -> VEHICLE_TYPE
# 69 6.21.1.2.4 -> CARDINAL
# 6.21. -> CARDINAL
# regulation no. -> LAW
# regulation no. 3 -> LAW
# regulation no. -> LAW
# at least one -> CARDINAL
# 1,500 mm -> QUANTITY
# 6.21.1.1 -> CARDINAL
# 6.21.1.2. -> CARDINAL
# trailers -> VEHICLE_TYPE
# 6.21.2 -> CARDINAL
# 6.21.3 -> CARDINAL
# 70 6.21.4 -> CARDINAL
# 6.21.4.1 -> CARDINAL
# 6.21.4.1.1 -> CARDINAL
# 6.21.4.1.2 -> CARDINAL
# at least 70 per cent -> PERCENT
# 6.21.4.2 -> CARDINAL
# 6.21.4.2.1 -> CARDINAL
# 600 mm -> QUANTITY
# 6.21.4.2.1.1 -> CARDINAL
# trailers -> VEHICLE_TYPE
# 2,400 mm -> QUANTITY
# regulation no. -> LAW
# regulation no. -> LAW
# 25 cm2 -> QUANTITY
# one -> CARDINAL
# more than 600 mm -> QUANTITY
# more than 600 mm -> QUANTITY
# 600 mm -> QUANTITY
# 6.21.4.2.1.2 -> CARDINAL
# trailers -> VEHICLE_TYPE
# 6.21.4.2.2 -> CARDINAL
# at least 70 per cent -> PERCENT
# 6.21.4.2.2.1 -> CARDINAL
# trailers -> VEHICLE_TYPE
# paragraph 6.21.4.2.1.1. -> LAW
# 2,400 mm -> QUANTITY
# 71 a -> QUANTITY
# 2,400 mm -> QUANTITY
# 6.21.4.2.1.1 -> CARDINAL
# 6.21.4.2.2.2 -> CARDINAL
# trailers -> VEHICLE_TYPE
# 6.21.4.3 -> CARDINAL
# 6.21.4.3.1 -> CARDINAL
# more than 1,500 mm -> QUANTITY
# 2,500 mm -> QUANTITY
# 1,500 mm -> QUANTITY
# 6.21.4.1.2 -> CARDINAL
# 6.21.4.2.2. -> CARDINAL
# higher than 1,500 mm -> QUANTITY
# 6.21.4.3. -> CARDINAL
# 2. -> CARDINAL
# 400 mm -> QUANTITY
# 6.21.5 -> CARDINAL
# at least 70 per cent -> PERCENT
# 6.21.5.1 -> CARDINAL
# 11 -> CARDINAL
# 1a -> CARDINAL
# 1b -> CARDINAL
# 25 m -> QUANTITY
# 6.21.5.1.1 -> CARDINAL
# two -> CARDINAL
# 1 m -> QUANTITY
# 3.0 m -> QUANTITY
# 6.21.5.1.2 -> CARDINAL
# two -> CARDINAL
# 4° -> QUANTITY
# 72 6.21.5.2 -> CARDINAL
# 11 -> CARDINAL
# 2 -> CARDINAL
# 25 m -> QUANTITY
# 6.21.5.2.1 -> CARDINAL
# two -> CARDINAL
# 1.0 m -> QUANTITY
# 1.5 m -> QUANTITY
# 6.21.5.2.2. -> QUANTITY
# two -> CARDINAL
# 4° -> QUANTITY
# 1 -> CARDINAL
# 2 -> CARDINAL
# 50 per cent -> PERCENT
# the type approval authority -> ORG
# 50 per cent -> PERCENT
# 50 per cent -> PERCENT
# 1,000 mm -> QUANTITY
# 6.21.7.2 -> CARDINAL
# two -> CARDINAL
# 90° -> QUANTITY
# at least 250 mm -> QUANTITY
# 6.21.7.3 -> CARDINAL
# 200 mm -> QUANTITY
# regulation no. 70 -> LAW
# at least 60 mm -> QUANTITY
# 6.22 -> CARDINAL
# headlamps -> COMPONENT
# 6.1 -> CARDINAL
# . -> CARDINAL
# headlamps -> COMPONENT
# 6.2 -> CARDINAL
# 73 6.22.1 -> CARDINAL
# trailers -> VEHICLE_TYPE
# 6.22.2 -> CARDINAL
# one -> CARDINAL
# 6.22.3 -> CARDINAL
# 6.22.4 -> CARDINAL
# 6.22.4. -> CARDINAL
# 6.22.4.1.1 -> CARDINAL
# 6.22.4.1.1 -> CARDINAL
# two -> CARDINAL
# 6.1.4 -> CARDINAL
# 6.2.4. -> CARDINAL
# two -> CARDINAL
# two -> CARDINAL
# one -> CARDINAL
# 50 mm -> QUANTITY
# 6.22.4.1.2 -> CARDINAL
# 140 mm16 -> QUANTITY
# 400 mm -> QUANTITY
# 6.22.4.1.3 -> CARDINAL
# 6.22.4.1.2 -> CARDINAL
# lower than 250 mm -> QUANTITY
# 6.2.4.2. -> CARDINAL
# 6.22.4.1 -> CARDINAL
# more than 400 mm -> QUANTITY
# m1 -> PRODUCT
# n1 -> PRODUCT
# 400 mm -> QUANTITY
# 1,300 mm -> QUANTITY
# two -> CARDINAL
# 200 mm -> QUANTITY
# 74 -> CARDINAL
# 1 -> CARDINAL
# 11 -> CARDINAL
# 3 -> CARDINAL
# 9 -> CARDINAL
# two -> CARDINAL
# 11 -> CARDINAL
# two -> CARDINAL
# 4 -> CARDINAL
# 8 -> CARDINAL
# two -> CARDINAL
# 2 -> CARDINAL
# 10 -> CARDINAL
# two -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 7 -> CARDINAL
# two -> CARDINAL
# 400 -> CARDINAL
# 600 -> CARDINAL
# 400 -> CARDINAL
# 1,300 mm -> QUANTITY
# 140 -> CARDINAL
# 1,200 75 6.22.4 -> QUANTITY
# 2 -> CARDINAL
# 6.22.5 -> CARDINAL
# 6.1.5 -> CARDINAL
# 6.2.5. -> CARDINAL
# at least one -> CARDINAL
# 6.22.6 -> CARDINAL
# 6.22.6 -> CARDINAL
# 1 -> CARDINAL
# 6.22.6.1.1 -> CARDINAL
# one -> CARDINAL
# 0.1 per cent -> PERCENT
# 7 -> CARDINAL
# 0.1 per cent -> PERCENT
# 6.22.6.1.2 -> CARDINAL
# 9.4 -> CARDINAL
# regulation no. -> LAW
# 6.22.6.1.2. -> CARDINAL
# 6.22.6 -> CARDINAL
# 3 -> CARDINAL
# 0.5 degree -> QUANTITY
# annex 10 of regulation no. 123. -> LAW
# 4 -> CARDINAL
# 6.2.6.3.2. -> CARDINAL
# 6.22.7 -> CARDINAL
# afs -> ORG
# 6.22.7.1.1 -> CARDINAL
# at least one -> CARDINAL
# 6.22.7.1.2 -> CARDINAL
# 6.22.9.3. -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 6.22.7.1.4 -> CARDINAL
# four -> CARDINAL
# headlamps -> COMPONENT
# 5.12 -> CARDINAL
# . -> CARDINAL
# 2 -> CARDINAL
# headlamps -> COMPONENT
# 5.12 -> CARDINAL
# 6.22.7.4 -> CARDINAL
# 6.22.7.4.1 -> CARDINAL
# 6.22.7.4.2 -> CARDINAL
# one -> CARDINAL
# 60 km/h -> QUANTITY
# 60 km/h -> QUANTITY
# 1 cd -> QUANTITY
# 10 lx -> QUANTITY
# 50 km -> QUANTITY
# 6.22.7.4.3 -> CARDINAL
# 60 km/h -> QUANTITY
# one -> CARDINAL
# 110 km/h -> QUANTITY
# 17 -> CARDINAL
# headlamps -> COMPONENT
# regulation no. 123, annex 3, table 6, only -> LAW
# e1 -> CARDINAL
# 100 km -> QUANTITY
# e2 -> CARDINAL
# 90 km -> QUANTITY
# e3 -> CARDINAL
# 80 km -> QUANTITY
# 6.22.7.4.4 -> CARDINAL
# one -> CARDINAL
# at least two minutes -> TIME
# 6.22.7.4.5 -> CARDINAL
# 6.22.7.4.1 -> CARDINAL
# 100 -> CARDINAL
# ii -> CARDINAL
# one -> CARDINAL
# 500 m -> QUANTITY
# 6.22.7.5 -> CARDINAL
# 6.22 -> CARDINAL
# 6.1.8. -> CARDINAL
# 6.2.8. -> CARDINAL
# 6.22.8.2 -> CARDINAL
# 18 -> CARDINAL
# 79 -> CARDINAL
# regulation no. -> LAW
# 6.22.8.3 -> CARDINAL
# 6.22.8.4 -> CARDINAL
# 5.8 -> CARDINAL
# regulation no. -> LAW
# 6.22.9 -> CARDINAL
# 6.22.9.1 -> CARDINAL
# regulation no. 4519 for at -> LAW
# 9.3. -> CARDINAL
# regulation no. 123 -> LAW
# 2,000 lm -> QUANTITY
# 6.22.9.2 -> CARDINAL
# afs -> ORG
# afs -> ORG
# afs -> ORG
# 6.22.7.4. -> CARDINAL
# afs -> ORG
# 19 -> CARDINAL
# headlamps -> COMPONENT
# 80 -> CARDINAL
# 6.22.9.2.4. -> CARDINAL
# 2 -> CARDINAL
# 12 -> CARDINAL
# 6.22.9.3 -> CARDINAL
# paragraph 6.22.7.1.2 -> LAW
# 6.1.9.3.1.1 -> CARDINAL
# 6.22.9.3.1.2 -> CARDINAL
# 6.22.9.3.1.3 -> CARDINAL
# 7,000 lx -> QUANTITY
# the type approval authority -> ORG
# the type approval authority -> ORG
# 6.22.9.4 -> CARDINAL
# 430,000 cd -> QUANTITY
# 100 -> CARDINAL
# 81 -> CARDINAL
# regulation no 123 -> LAW
# 6.23 -> CARDINAL
# 6.23.1 -> CARDINAL
# 6.23.7 -> CARDINAL
# 6.23.2 -> CARDINAL
# 6.5.2 -> CARDINAL
# 6.7.2 -> CARDINAL
# 6.23.3 -> CARDINAL
# 6.5.3. -> CARDINAL
# 6.7.3 -> CARDINAL
# 6.23.4 -> CARDINAL
# 6.5.4 -> CARDINAL
# 6.7.4 -> CARDINAL
# 6.23.5 -> CARDINAL
# 6.5.5 -> CARDINAL
# 6.7.5 -> CARDINAL
# 6.23.6 -> CARDINAL
# 6.5.6 -> CARDINAL
# 6.7.6 -> CARDINAL
# 6.23.7 -> CARDINAL
# 6.23.7.1 -> CARDINAL
# 4.0 ± 1.0 hz -> QUANTITY
# 6.23.7.1.1 -> CARDINAL
# 6.23.7.2 -> CARDINAL
# 6.23.7.3 -> CARDINAL
# 50 km/h -> QUANTITY
# regulations nos. 13 and 13 -> LAW
# 6.23.7.3.2 -> CARDINAL
# regulations nos. 13 and 13 -> LAW
# 6.23.8 -> CARDINAL
# 6.23.9 -> CARDINAL
# 6.23.9.1 -> CARDINAL
# 6.23.9.2 -> CARDINAL
# 6.23.9.2 -> CARDINAL
# regulation no.13 -> LAW
# trailers -> VEHICLE_TYPE
# 6.24 -> CARDINAL
# 6.24.1 -> CARDINAL
# 6.24.2 -> CARDINAL
# two -> CARDINAL
# 6.24.3 -> CARDINAL
# 6.24.9.3. -> CARDINAL
# 6.24.4 -> CARDINAL
# 6.24.5 -> CARDINAL
# 6.24.6 -> CARDINAL
# 6.24.7 -> CARDINAL
# 6.24.8 -> CARDINAL
# 6.24.9 -> CARDINAL
# 6.24.9.1 -> CARDINAL
# one -> CARDINAL
# 5.10. -> CARDINAL
# 83 6.24.9.2 -> CARDINAL
# 5.12. -> CARDINAL
# the type approval authority -> ORG
# 10 m -> QUANTITY
# 10 m -> QUANTITY
# two -> CARDINAL
# 10 m -> QUANTITY
# four -> CARDINAL
# 3 m -> QUANTITY
# 14 -> CARDINAL
# the technical service -> ORG
# 6.25 -> CARDINAL
# 6.25.1 -> CARDINAL
# 6.25.7 -> CARDINAL
# 6.25.2 -> CARDINAL
# 6.5.2 -> CARDINAL
# 6.25.3 -> CARDINAL
# 6.5.3 -> CARDINAL
# 6.25.4. -> CARDINAL
# 6.5.4 -> CARDINAL
# 6.25.5 -> CARDINAL
# 6.5.5. -> CARDINAL
# 6.25.6 -> CARDINAL
# 6.5.6 -> CARDINAL
# 6.25.7 -> CARDINAL
# 6.25.7.1 -> CARDINAL
# 4.0 +/- 1.0 -> CARDINAL
# 6.25.7.1.1 -> CARDINAL
# 4.0 +0.0/-1.0 hz -> QUANTITY
# 6.25.7.2 -> CARDINAL
# 6.25.7.3 -> CARDINAL
# 6.25.7.5 -> CARDINAL
# 30 km -> QUANTITY
# 30 km -> QUANTITY
# 6.25.7.6 -> CARDINAL
# more than 3 seconds -> TIME
# 6.25.8 -> CARDINAL
# 23 -> CARDINAL
# 6.26.1 -> CARDINAL
# 6.26.2 -> CARDINAL
# one -> CARDINAL
# two -> CARDINAL
# one -> CARDINAL
# 6.26.3 -> CARDINAL
# 6.26.9. -> CARDINAL
# 6.26.4 -> CARDINAL
# 6.26.5 -> CARDINAL
# 6.26.6 -> CARDINAL
# 6.26.9. -> CARDINAL
# 6.26.7 -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# one -> CARDINAL
# first -> ORDINAL
# 10 km -> QUANTITY
# 6.26.8 -> CARDINAL
# 6.26.9.1 -> CARDINAL
# 10 m -> QUANTITY
# 10 m -> QUANTITY
# two -> CARDINAL
# 10 m -> QUANTITY
# four -> CARDINAL
# 1 m -> QUANTITY
# 3 m -> QUANTITY
# 14 -> CARDINAL
# regulation no. 23 -> LAW
# 9. -> CARDINAL
# 7.1 -> CARDINAL
# paragraph 3.2.2. -> LAW
# 7.1.2. -> CARDINAL
# 7.2 -> CARDINAL
# 4.3. -> CARDINAL
# 7.3 -> CARDINAL
# 1958 -> DATE
# 1 -> CARDINAL
# 86 8 -> CARDINAL
# 2 -> CARDINAL
# 5 -> CARDINAL
# 6. -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 8.2.2. -> CARDINAL
# 9 -> CARDINAL
# 8.3 -> CARDINAL
# the type approval authority -> ORG
# 8.4 -> CARDINAL
# the type approval authority -> ORG
# the type approval authority -> ORG
# 9 -> CARDINAL
# 9.1 -> CARDINAL
# 9.2 -> CARDINAL
# 1 -> CARDINAL
# 10 -> CARDINAL
# 1958 -> DATE
# united nations -> GPE
# 12 -> CARDINAL
# 12.1 -> CARDINAL
# 12.1.1 -> CARDINAL
# 12.1.2 -> CARDINAL
# 12.1.3 -> CARDINAL
# 12.1.4 -> CARDINAL
# 12.1.5. -> CARDINAL
# 12.1.5 -> CARDINAL
# 12.1.6 -> CARDINAL
# 12.1.4. -> CARDINAL
# 12.1.7 -> CARDINAL
# united nations -> ORG
# japan -> GPE
# japan -> GPE
# n1. 88 12.2. -> LAW
# 03 series of amendments -> DATE
# 10 october 2007 -> DATE
# 12 months -> DATE
# 03 -> DATE
# up to 09 october 2009 -> DATE
# 36 months -> DATE
# 10 october 2009 -> DATE
# 36 months -> DATE
# first -> ORDINAL
# 7.5 tonnes -> QUANTITY
# 2,100 mm -> QUANTITY
# 6,000 mm -> QUANTITY
# trailers -> VEHICLE_TYPE
# 03 -> CARDINAL
# 12.1.4. -> CARDINAL
# 10 october 2011 -> DATE
# 60 months -> DATE
# 7.5 tons -> QUANTITY
# 2,100 mm -> QUANTITY
# 6,000 mm -> QUANTITY
# trailers -> VEHICLE_TYPE
# 12 june 2010 -> DATE
# 36 months -> DATE
# 3 -> CARDINAL
# 03 -> DATE
# 3 -> CARDINAL
# 03 -> DATE
# up to 11 january 2010 -> DATE
# 18 months -> DATE
# 4 -> CARDINAL
# 03 -> DATE
# 6.3.6.1.1 -> CARDINAL
# 6.5.8 -> CARDINAL
# 6.19.7.3 -> CARDINAL
# up to 10 october 2011 -> DATE
# 60 month -> DATE
# 6.21.4.1.3 -> CARDINAL
# 6.21.4.1.3. -> CARDINAL
# 03 -> DATE
# 89 12.3 -> CARDINAL
# 04 series -> DATE
# 07 february 2011 -> DATE
# 07 august 2012 -> DATE
# 30 and 48 months -> DATE
# 04 -> DATE
# 22 july 2009 -> DATE
# 2 -> CARDINAL
# 04 -> DATE
# 5.2.1. -> CARDINAL
# headlamps -> COMPONENT
# 9 -> CARDINAL
# regulation no. -> LAW
# 24 october 2012 -> DATE
# 36 months -> DATE
# 3 -> CARDINAL
# 04 -> DATE
# 3.2.7 -> CARDINAL
# 5.27 to 5.27.4 -> CARDINAL
# 3 -> CARDINAL
# 04 -> DATE
# up to 07 february 2011 -> DATE
# 07 august 2012 -> DATE
# 30 and 48 months -> DATE
# 04 -> DATE
# 6.19.7.6 -> CARDINAL
# 12.3.1 -> CARDINAL
# regulation no. 112 -> LAW
# 07 august 2008 -> DATE
# 04 -> DATE
# 6.2.2. -> CARDINAL
# 04 -> DATE
# 112. 12.4 -> CARDINAL
# 05 -> DATE
# 30 january 2015 -> DATE
# 48 months -> DATE
# 05 -> DATE
# 30 july 2016 -> DATE
# 30 january 2018 -> DATE
# 66 and 84 months -> DATE
# one -> CARDINAL
# 05 -> DATE
# 90 12.5 -> CARDINAL
# 06 series of amendments -> DATE
# 18 november 2017 -> DATE
# 60 month -> DATE
# annex 1 91 -> LAW
# 210 x 297 mm -> QUANTITY
# 2 -> CARDINAL
# regulation no. -> LAW
# 1 -> CARDINAL
# 2 -> CARDINAL
# 1 92 -> CARDINAL
# 9. -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 3.2.6 -> CARDINAL
# 10.5 -> CARDINAL
# 70 per cent -> PERCENT
# 6.21.4.1.2 -> CARDINAL
# 6.21.4.2.2. -> CARDINAL
# 10.6. -> CARDINAL
# 3.2.7 -> CARDINAL
# 5.27 -> CARDINAL
# 10.7. -> CARDINAL
# 6.21.1.2.5 -> CARDINAL
# 10.8 -> CARDINAL
# 6.21.1.2.1 -> CARDINAL
# 6.21.1.2.1.1. -> CARDINAL
# 1 94 -> CARDINAL
# 17 -> CARDINAL
# 2 -> CARDINAL
# 4.4. -> CARDINAL
# 8 mm min -> QUANTITY
# netherlands -> LOC
# regulation no. 48 -> LAW
# regulation no. 48 -> LAW
# 4.5 -> CARDINAL
# 8 mm min -> QUANTITY
# netherlands -> LOC
# 4 -> CARDINAL
# regulation no. -> LAW
# regulation no. -> LAW
# regulation no. 48 -> LAW
# 06 -> DATE
# regulation no. -> LAW
# second -> ORDINAL
# 06 06 -> DATE
# 3 -> CARDINAL
# 3. -> CARDINAL
# 2.8. -> CARDINAL
# 2.8. -> CARDINAL
# two -> CARDINAL
# 1 -> CARDINAL
# 3 97 -> CARDINAL
# 2 -> CARDINAL
# 3 98 -> CARDINAL
# 3 -> CARDINAL
# 3 -> CARDINAL
# 4 -> CARDINAL
# 3 -> CARDINAL
# 5 -> CARDINAL
# 2.8 -> CARDINAL
# 2.9 -> CARDINAL
# 1 -> CARDINAL
# 2 -> CARDINAL
# 3 -> CARDINAL
# 4 -> CARDINAL
# 5 -> CARDINAL
# 6 -> CARDINAL
# 3 101 -> CARDINAL
# 7 -> CARDINAL
# 8 -> CARDINAL
# 2.8. -> CARDINAL
# 2.8. -> CARDINAL
# 3 102 -> CARDINAL
# 9 -> CARDINAL
# 6 -> CARDINAL
# 2.8 -> CARDINAL
# 2.9. -> CARDINAL
# 2.8 -> CARDINAL
# 7b -> CARDINAL
# 2.8. -> CARDINAL
# 3 103 -> CARDINAL
# 2.8. -> CARDINAL
# 2.8. -> CARDINAL
# 3 105 -> CARDINAL
# 7 -> CARDINAL
# two -> CARDINAL
# annex 3 106 -> LAW
# annex 3 107 -> LAW
# 3 108 -> CARDINAL
# 7b -> WORK_OF_ART
# 2.8 -> CARDINAL
# annex 4 109 annex 4 -> LAW
# 5.10.1 -> CARDINAL
# 5.10.2. -> CARDINAL
# 1 -> CARDINAL
# 2 -> CARDINAL
# headlamps -> COMPONENT
# 6.2.6.1 -> CARDINAL
# 6.2.6.3.1 -> CARDINAL
# 75 kg -> QUANTITY
# headlamps -> COMPONENT
# one -> CARDINAL
# one -> CARDINAL
# one -> CARDINAL
# 2.1.1.5 -> CARDINAL
# one -> CARDINAL
# 2.1.1.6 -> CARDINAL
# 2.1.2 -> CARDINAL
# 2.2 -> CARDINAL
# headlamps -> COMPONENT
# one -> CARDINAL
# the consolidated resolution on the construction of vehicles -> LAW
# 5 111 -> CARDINAL
# first -> ORDINAL
# 2. -> CARDINAL
# headlamps -> COMPONENT
# one -> CARDINAL
# 25 per cent -> PERCENT
# 2. -> CARDINAL
# 2.4 -> CARDINAL
# trailers -> VEHICLE_TYPE
# one -> CARDINAL
# one -> CARDINAL
# trailers -> VEHICLE_TYPE
# one -> CARDINAL
# one -> CARDINAL
# 6 -> CARDINAL
# 6 -> CARDINAL
# 1 -> CARDINAL
# 2 -> CARDINAL
# 2.1. -> CARDINAL
# 2.1.1. -> CARDINAL
# 2.1.2 -> CARDINAL
# 5 -> CARDINAL
# 2.2 -> CARDINAL
# 1 per cent -> QUANTITY
# 10 mrad -> QUANTITY
# 100 x -> QUANTITY
# 1 -> CARDINAL
# 6 113 -> CARDINAL
# 1 -> CARDINAL
# 1 -> CARDINAL
# m1 -> PRODUCT
# 1 -> CARDINAL
# 2 -> CARDINAL
# 3 -> CARDINAL
# 3.1 -> CARDINAL
# 1 -> CARDINAL
# at least 10 m. -> QUANTITY
# 3.2 -> CARDINAL
#  0.5 mrad -> MONEY
# ±0.05 per cent -> PERCENT
# 3.3 -> CARDINAL
# 0.5 mrad -> QUANTITY
# 0.05 per cent -> PERCENT
# 3.4 -> CARDINAL
# between 10 and 30 ° -> QUANTITY
# 4 -> CARDINAL
# 4.1 -> CARDINAL
# between 1,000 km and 10,000 km -> QUANTITY
# 5,000 km -> QUANTITY
# 4.2 -> CARDINAL
# less than 90 per cent -> PERCENT
# 4.3 -> CARDINAL
# 6 114 4.4 -> CARDINAL
# at least 8 h -> DATE
# 3.4. -> CARDINAL
# 4.5 -> CARDINAL
# headlamps -> COMPONENT
# 5 -> CARDINAL
# 5.1 -> CARDINAL
# headlamps -> COMPONENT
# 5 -> CARDINAL
# 5.5. -> CARDINAL
# 5.1.1 -> CARDINAL
# 5.2 -> CARDINAL
# 4 -> CARDINAL
# 5 -> CARDINAL
# first -> ORDINAL
# 5.4. -> CARDINAL
# three -> CARDINAL
# 5.2.1 -> CARDINAL
# three -> CARDINAL
# more than 2 mrad -> QUANTITY
# 0.2 per cent -> PERCENT
# 5.2.2 -> CARDINAL
# 2 mrad -> QUANTITY
# 0.2 per cent -> PERCENT
# 10 -> CARDINAL
# 5.3 -> CARDINAL
# ±0.2 mrad -> QUANTITY
# ±0.02 per cent -> PERCENT
# 5.4 -> CARDINAL
# 5.4.1. -> CARDINAL
# at least three -> CARDINAL
# first -> ORDINAL
# 6 115 -> CARDINAL
# m2 -> PRODUCT
# m3 -> PRODUCT
# n -> PRODUCT
# 5.4.2.1 -> CARDINAL
# 5.4.1. -> CARDINAL
# 5.4.2.2. -> CARDINAL
# 5.4.2.3. -> CARDINAL
# 5.4.2.2 -> CARDINAL
# 5.4.2.3 -> CARDINAL
# 5.4.3 -> CARDINAL
# 5.5 -> CARDINAL
# 5.2. -> CARDINAL
# 5 -> CARDINAL
# 5.5.1 -> CARDINAL
# 4 mrad -> QUANTITY
# 0.4 per cent -> PERCENT
# 5.5.2 -> CARDINAL
# 5.5.1 -> CARDINAL
# three -> CARDINAL
# 5.5.3 -> CARDINAL
# 5.5 -> CARDINAL
# 5.5.3.1 -> CARDINAL
# three -> CARDINAL
# more than 2 mrad -> QUANTITY
# 0.2 per cent -> PERCENT
# 5.5.3.2 -> CARDINAL
# more than 2 mrad -> QUANTITY
# 0.2 per cent -> PERCENT
# 10 -> CARDINAL
# 6 116 -> CARDINAL
# 5.5.3.3 -> CARDINAL
# 5.5.3.1. -> CARDINAL
# 5.5.3.2 -> CARDINAL
# 5.5.4 -> CARDINAL
# 5.2 -> CARDINAL
# 5.5.1 -> CARDINAL
# 5.5.5 -> CARDINAL
# one -> CARDINAL
# annex 7 117 annex 7 -> LAW
# headlamps -> COMPONENT
# 6.2.6.1.1. -> CARDINAL
# 1 -> CARDINAL
# 2 -> CARDINAL
# 1. -> CARDINAL
# 1.1. -> CARDINAL
# one -> CARDINAL
# 1.1.1 -> CARDINAL
# 1.2 -> CARDINAL
# 1.3 -> CARDINAL
# 1.4 -> CARDINAL
# 1 -> CARDINAL
# five -> CARDINAL
# four -> CARDINAL
# 2 -> CARDINAL
# 1 -> CARDINAL
# 1.1. -> CARDINAL
# 2.7. -> CARDINAL
# 2.8 -> CARDINAL
# 2.10. -> CARDINAL
# 2.14. -> CARDINAL
# 5.4. -> CARDINAL
# 1.2.1 -> CARDINAL
# 2.13. -> CARDINAL
# 5.3 -> CARDINAL
# 1.2.2 -> CARDINAL
# 1.3 -> CARDINAL
# headlamps -> COMPONENT
# 7 -> CARDINAL
# 6 -> CARDINAL
# paragraph 4.1. 1.3.2. -> LAW
# 0.2 per cent to 2.8 per -> PERCENT
# 0.8 -> CARDINAL
# 0.2 per cent to 2.8 per cent -> PERCENT
# 0.8 -> CARDINAL
# 1.0 -> CARDINAL
# 0.7 per cent to 3.3 per -> PERCENT
# 0.7 per cent to 3.3 per -> PERCENT
# 1.0 -> CARDINAL
# 1.2 m -> QUANTITY
# 1.2 per cent to 3.8 per -> PERCENT
# 1.2 m. -> QUANTITY
# 9 121 -> CARDINAL
# 2,000 lumens -> QUANTITY
# 0.7 per cent to 3.3 per -> PERCENT
# 0.8 -> CARDINAL
# 1.2 per cent to 3.8 per -> PERCENT
# 0.8 m. -> QUANTITY
# 5 -> CARDINAL
# 2.1.1.1 -> CARDINAL
# 2.1.1.6. -> CARDINAL
# 2.1.2. -> CARDINAL
# 1.3.2 -> CARDINAL
# 2.2.1 -> CARDINAL
# 2.2.2 -> CARDINAL
# 1.3.2 -> CARDINAL
# 2.3.1.1 -> CARDINAL
# 2.3.1.2. -> CARDINAL
# 4 -> CARDINAL
# 1.3.2.4 -> CARDINAL
# 1 -> CARDINAL
# trailers -> VEHICLE_TYPE
# 2.4.1.1 -> CARDINAL
# 2.4.1.2 -> CARDINAL
# 1.3.2.4 -> CARDINAL
# 2 -> CARDINAL
# trailers -> VEHICLE_TYPE
# 2.4.2.1 -> CARDINAL
# 2.4.2.2. -> CARDINAL
# 5.14. -> CARDINAL
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# 9 122 1.6 -> CARDINAL
# 5.15 -> CARDINAL
# 5.16. -> CARDINAL
# 11 124 -> CARDINAL
# 4° -> QUANTITY
# 4° -> QUANTITY
# 11 -> CARDINAL
# 6.21.5. -> CARDINAL
# 25 m -> QUANTITY
# trailers -> VEHICLE_TYPE
# 25 m -> QUANTITY
# 11 125 -> CARDINAL
# 4° -> QUANTITY
# 2 -> CARDINAL
# 25 m -> QUANTITY
# 12 -> CARDINAL
# 12 -> CARDINAL
# 1 -> CARDINAL
# headlamps -> COMPONENT
# 1.1 -> CARDINAL
# 1.2 -> CARDINAL
# 1 -> CARDINAL
# 1 -> CARDINAL
# 50 ± 10 km/h -> QUANTITY
# 100 ± 20 km/h -> QUANTITY
# 80 ± 20 km/h -> QUANTITY
# 10 per cent -> PERCENT
# 20 per cent -> PERCENT
# 70 per -> PERCENT
# 6.1.9.3.1.2 -> CARDINAL
# 1 -> CARDINAL
# > 2,000 m -> QUANTITY
# wmo -> ORG
# sixth -> ORDINAL
# 92-63-16008- -> CARDINAL
# 1. 9. 1/ -> CARDINAL
# geneva -> ORG
# 12 127 1.3 -> CARDINAL
# 1.4 -> CARDINAL
# two -> CARDINAL
# four or more -> CARDINAL
# 1.5 -> CARDINAL
# more than 600 m. -> QUANTITY
# 2 -> CARDINAL
# headlamps -> COMPONENT
# 2.2 -> CARDINAL
# 2 -> CARDINAL
# 2 -> CARDINAL
# 50 ± 10km/h 100 ± 20km/h 80 ± 20km/h average percentage of the full test course length -> QUANTITY
# 10 per cent -> PERCENT
# 20 per cent -> PERCENT
# 70 per cent -> PERCENT
# 6.22.9.3.1.2 -> CARDINAL
# 2 -> CARDINAL
# > 2,000 m -> QUANTITY
# wmo -> ORG
# sixth -> ORDINAL
# 92-63-16008 -> CARDINAL
# 1. 9 -> CARDINAL
# 1996 -> DATE
# 12 128 -> CARDINAL
# 2.4 -> CARDINAL
# two -> CARDINAL
# four or more -> CARDINAL
# 2.5 -> CARDINAL
# more than 600 m. -> QUANTITY
# 2.6 -> CARDINAL
# 2.7 -> CARDINAL
# annex 13 129 -> LAW
# headlamps -> COMPONENT
# headlamps -> COMPONENT
# less than 1,000 lux -> QUANTITY
# between 1,000 lux -> TIME
# 7,000 lux -> QUANTITY
# 7,000 lux -> QUANTITY
# more than 5 seconds -> TIME
# 2 -> CARDINAL
# the type approval authority -> ORG
# annex 14 130 annex 14 -> LAW
# photometric measurements -> TESTING_STANDARD
# 2.34. -> CARDINAL

# %%
# Extract improved relationships
relations = extract_relationships(doc)
print("\n🔹 Extracted Relationships:")
for rel in relations:
    print(rel)
# Out:
# 🔹 Extracted Relationships:

# %%
import spacy
from spacy.pipeline import EntityRuler
from spacy.matcher import Matcher
import re
from spacy.language import Language

# Load transformer-based model for better NER
nlp = spacy.load("en_core_web_trf")  # More accurate than en_core_web_sm

# Add an entity ruler to improve NER
def add_entity_patterns(nlp):
    ruler = nlp.add_pipe("entity_ruler", before="ner", config={"overwrite_ents": True})

    patterns = [
        # Regulations
        {"label": "REGULATION", "pattern": [{"LOWER": "regulation"}, {"LOWER": "no."}, {"IS_DIGIT": True}]},
        {"label": "REGULATION", "pattern": [{"LOWER": "regulation"}, {"LOWER": "no"}, {"IS_DIGIT": True}]},
        {"label": "REGULATION", "pattern": [{"LOWER": "regulation"}, {"LOWER": "n"}, {"IS_DIGIT": True}]},

        # Vehicle Types
        {"label": "VEHICLE_TYPE", "pattern": "M3"},
        {"label": "VEHICLE_TYPE", "pattern": "N2"},
        {"label": "VEHICLE_TYPE", "pattern": "trailers"},

        # Components
        {"label": "COMPONENT", "pattern": "headlamps"},
        {"label": "COMPONENT", "pattern": "rear fog lamps"},

        # Technologies
        {"label": "TECHNOLOGY", "pattern": "adaptive front-lighting system"},

        # Certification Bodies
        {"label": "CERTIFICATION_BODY", "pattern": "UNECE"},
        {"label": "CERTIFICATION_BODY", "pattern": "Geneva agreement"},

        # Testing Standards
        {"label": "TESTING_STANDARD", "pattern": "photometric measurements"},

        # Geographic Regions
        {"label": "GEOGRAPHIC_REGION", "pattern": "European Union"},
        {"label": "GEOGRAPHIC_REGION", "pattern": "United Nations"},
    ]
    ruler.add_patterns(patterns)

# Add entity patterns
add_entity_patterns(nlp)

# Function to identify section numbers (e.g., 2.7.16.3) as ENTITY_TYPE "SECTION_NUMBER"
def custom_tokenizer(doc):
    section_regex = re.compile(r'\b\d+(\.\d+)+\b')  # Matches patterns like "2.7.16.3"
    entities = []
    for match in section_regex.finditer(doc.text):
        start, end = match.span()
        entities.append((start, end, "SECTION_NUMBER"))

    return entities

# Register the custom component
@Language.component("section_number_ner")
def add_section_number_entities(doc):
    section_entities = custom_tokenizer(doc)
    for start, end, label in section_entities:
        span = doc.char_span(start, end, label=label)
        if span:
            doc.ents = list(doc.ents) + [span]
    return doc

# Add the registered component after the "ner" pipeline
nlp.add_pipe("section_number_ner", after="ner")

# Function for rule-based Relation Extraction
def extract_relationships(doc):
    matcher = Matcher(nlp.vocab)

    relations = [
        ("REGULATION", "applies_to", "VEHICLE_TYPE"),
        ("TECHNOLOGY", "uses", "COMPONENT"),
        ("CERTIFICATION_BODY", "certifies", "REGULATION"),
        ("REGULATION", "enforced_in", "GEOGRAPHIC_REGION"),
        ("TESTING_STANDARD", "evaluates", "TECHNOLOGY"),
        ("COMPONENT", "integrated_into", "TECHNOLOGY"),
    ]

    extracted_relations = []

    for ent1, rel, ent2 in relations:
        pattern = [
            {"ENT_TYPE": ent1},
            {"LOWER": rel, "OP": "?"},
            {"ENT_TYPE": ent2}
        ]
        matcher.add(rel, [pattern])

    matches = matcher(doc)
    for match_id, start, end in matches:
        span = doc[start:end]
        relation = nlp.vocab.strings[match_id]
        extracted_relations.append((span[0].text, relation, span[-1].text))

    return extracted_relations

# Process the text and extract entities
def process_text(text):
    doc = nlp(text)

    print("\nExtracted Entities:")
    for ent in doc.ents:
        print(f"{ent.text} -> {ent.label_}")

    print("\nExtracted Relations:")
    relations = extract_relationships(doc)
    for rel in relations:
        print(rel)

    return doc

# Example Usage
# Example Usage
if __name__ == "__main__":
    text_file_path = "/content/drive/MyDrive/KnowledgeGraphResults/cleaned_text1.txt"
    sample_text = load_text_from_file(text_file_path)
    process_text(sample_text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-6aff2cb3c32b> in <cell line: 0>()
#     120     text_file_path = "/content/drive/MyDrive/KnowledgeGraphResults/cleaned_text1.txt"
#     121     sample_text = load_text_from_file(text_file_path)
# --> 122     process_text(sample_text)
#
# <ipython-input-11-6aff2cb3c32b> in process_text(text)
#     102 # Process the text and extract entities
#     103 def process_text(text):
# --> 104     doc = nlp(text)
#     105
#     106     print("\nExtracted Entities:")
#
# /usr/local/lib/python3.11/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1052                 raise ValueError(Errors.E109.format(name=name)) from e
#    1053             except Exception as e:
# -> 1054                 error_handler(name, proc, [doc], e)
#    1055             if not isinstance(doc, Doc):
#    1056                 raise ValueError(Errors.E005.format(name=name, returned_type=type(doc)))
#
# /usr/local/lib/python3.11/dist-packages/spacy/util.py in raise_error(proc_name, proc, docs, e)
#    1720
#    1721 def raise_error(proc_name, proc, docs, e):
# -> 1722     raise e
#    1723
#    1724
#
# /usr/local/lib/python3.11/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1047                 error_handler = proc.get_error_handler()
#    1048             try:
# -> 1049                 doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1050             except KeyError as e:
#    1051                 # This typically happens if a component is not initialized
#
# <ipython-input-11-6aff2cb3c32b> in add_section_number_entities(doc)
#      63         span = doc.char_span(start, end, label=label)
#      64         if span:
# ---> 65             doc.ents = list(doc.ents) + [span]
#      66     return doc
#      67
#
# /usr/local/lib/python3.11/dist-packages/spacy/tokens/doc.pyx in spacy.tokens.doc.Doc.ents.__set__()
#
# /usr/local/lib/python3.11/dist-packages/spacy/tokens/doc.pyx in spacy.tokens.doc.Doc.set_ents()
#
# ValueError: [E1010] Unable to set entity information for token 493 which is included in more than one span in entities, blocked, missing or outside.

# %%
import re
import spacy

# Load a high-accuracy NLP model
nlp = spacy.load("en_core_web_trf")

# Function to preprocess text
def preprocess_text(file_path):
    # Read the file
    with open(file_path, "r", encoding="utf-8") as file:
        text = file.read()

    # Remove unwanted characters and extra spaces
    text = re.sub(r"\n+", "\n", text)  # Remove excessive newlines
    text = re.sub(r"\s{2,}", " ", text)  # Remove extra spaces
    text = re.sub(r"[^\x00-\x7F]+", " ", text)  # Remove non-ASCII characters

    # Standardize regulation references
    text = re.sub(r"Regulation No\.? (\d+)", r"R\1", text)

    # Standardize AEBS variations
    text = text.replace("Advanced Emergency Braking System", "AEBS")

    # Sentence Segmentation using Spacy
    doc = nlp(text)
    sentences = [sent.text.strip() for sent in doc.sents]

    return sentences  # Return cleaned sentences for further processing

# Apply preprocessing
file_path = "/content/drive/MyDrive/KnowledgeGraphResults/cleaned_text1.txt"
processed_sentences = preprocess_text(file_path)

# Save cleaned text to a new file
output_path = "/content/drive/MyDrive/KnowledgeGraphResults/preprocessed_text.txt"
with open(output_path, "w", encoding="utf-8") as file:
    for sentence in processed_sentences:
        file.write(sentence + "\n")

print(f"Preprocessed text saved to: {output_path}")
# Out:
# /usr/local/lib/python3.11/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# /usr/local/lib/python3.11/dist-packages/thinc/shims/pytorch.py:253: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(filelike, map_location=device))
# /usr/local/lib/python3.11/dist-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# Preprocessed text saved to: /content/drive/MyDrive/KnowledgeGraphResults/preprocessed_text.txt

# %%
import re
import spacy

# Load Spacy transformer model
nlp = spacy.load("en_core_web_trf")

# Function to clean and refine text
def refine_text(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        text = file.read()

    # Remove headers, table of contents, and unwanted formatting
    text = re.sub(r"\n+", "\n", text)  # Normalize new lines
    text = re.sub(r"(^|\s)[0-9]+\s*\.\s*", "", text)  # Remove numbered sections
    text = re.sub(r"\s{2,}", " ", text)  # Remove excessive spaces
    text = re.sub(r"[^\x00-\x7F]+", " ", text)  # Remove non-ASCII characters

    # Standardize regulation names (e.g., "Regulation No. 48" → "R48")
    text = re.sub(r"Regulation No\.? (\d+)", r"R\1", text)

    # Standardize technical terms
    text = text.replace("Advanced Emergency Braking System", "AEBS")

    # Sentence segmentation for better entity recognition
    doc = nlp(text)
    sentences = [sent.text.strip() for sent in doc.sents]

    return sentences  # Return refined sentences for NER and relation extraction

# Apply refining function
input_file = "/content/drive/MyDrive/KnowledgeGraphResults/preprocessed_text.txt"
cleaned_sentences = refine_text(input_file)

# Save final cleaned text
final_output_path = "/content/drive/MyDrive/KnowledgeGraphResults/final_cleaned_text.txt"
with open(final_output_path, "w", encoding="utf-8") as file:
    for sentence in cleaned_sentences:
        file.write(sentence + "\n")

print(f"Final cleaned text is saved at: {final_output_path}")
# Out:
# Final cleaned text is saved at: /content/drive/MyDrive/KnowledgeGraphResults/final_cleaned_text.txt

# %%
# Process the file line by line to handle memory constraints
def process_file_line_by_line(input_path, output_path):
    with open(input_path, "r", encoding="utf-8") as infile, open(output_path, "w", encoding="utf-8") as outfile:
        for line in infile:
            # Remove unwanted formatting from each line
            line = re.sub(r"(?i)contents\s+page\s+\d+", "", line)  # Remove table of contents
            line = re.sub(r"\n+", " ", line)  # Normalize new lines
            line = re.sub(r"(^|\s)\d+\.\d+\s*", "", line)  # Remove numbered sections (e.g., 2.1, 7.10)
            line = re.sub(r"\s{2,}", " ", line)  # Remove excessive spaces
            line = re.sub(r"[^\x00-\x7F]+", " ", line)  # Remove non-ASCII characters
            line = re.sub(r"Regulation No\.? (\d+)", r"R\1", line)  # Standardize regulation references

            # Skip empty lines
            if line.strip():
                outfile.write(line.strip() + "\n")

# Define paths
input_file = "/content/drive/MyDrive/KnowledgeGraphResults/final_cleaned_text.txt"
output_file = "/content/drive/MyDrive/KnowledgeGraphResults/fully_preprocessed_text.txt"

# Process the file line by line
process_file_line_by_line(input_file, output_file)

# Return the path of the cleaned file
output_file
# Out:
# '/content/drive/MyDrive/KnowledgeGraphResults/fully_preprocessed_text.txt'

# %%
# Final Cleaning Script for Fully Preprocessed Text

def final_text_cleaning(file_path, output_path):
    cleaned_lines = []

    with open(file_path, "r", encoding="utf-8") as file:
        for line in file:
            line = line.strip()

            # Remove legal metadata and revision history
            line = re.sub(r"addendum\s+\d+.*", "", line, flags=re.IGNORECASE)
            line = re.sub(r"date of entry into force:.*", "", line, flags=re.IGNORECASE)

            # Remove numbered sections but keep regulatory references like R131
            line = re.sub(r"^\d+\.\d+\.\d+.*", "", line)  # E.g., "2.7.1.2.2"
            line = re.sub(r"^\d+\.\d+.*", "", line)  # E.g., "7.10"

            # Remove table of contents and annex references
            line = re.sub(r"contents\s+page\s+\d+", "", line, flags=re.IGNORECASE)
            line = re.sub(r"annex\s+\d+.*", "", line, flags=re.IGNORECASE)

            # Remove excessive whitespace
            line = re.sub(r"\s{2,}", " ", line)

            # Skip empty lines
            if line.strip():
                cleaned_lines.append(line)

    # Save the final cleaned file
    with open(output_path, "w", encoding="utf-8") as outfile:
        for line in cleaned_lines:
            outfile.write(line + "\n")

# Define paths
input_file = "/content/drive/MyDrive/KnowledgeGraphResults/fully_preprocessed_text.txt"
final_output_file = "/content/drive/MyDrive/KnowledgeGraphResults/ready_text.txt"

# Run final cleaning process
final_text_cleaning(input_file, final_output_file)

# Return path to the final cleaned file
final_output_file
# Out:
# '/content/drive/MyDrive/KnowledgeGraphResults/ready_text.txt'

# %% [markdown]
# # Entity Extraction

# %%
import spacy
from spacy.pipeline import EntityRuler

# Load Spacy's transformer-based model
nlp = spacy.load("en_core_web_trf")

# Function to add entity patterns
def add_custom_entities(nlp):
    ruler = nlp.add_pipe("entity_ruler", before="ner", config={"overwrite_ents": True})

    patterns = [
        # Regulations
        {"label": "REGULATION", "pattern": "R131"},
        {"label": "REGULATION", "pattern": "UNECE R131"},
        {"label": "REGULATION", "pattern": "Regulation 48"},
        {"label": "REGULATION", "pattern": "UNECE R48"},

        # AEBS Technology
        {"label": "AEBS_TECHNOLOGY", "pattern": "Advanced Emergency Braking System"},
        {"label": "AEBS_TECHNOLOGY", "pattern": "AEBS"},

        # Vehicle Types
        {"label": "VEHICLE_TYPE", "pattern": "trucks"},
        {"label": "VEHICLE_TYPE", "pattern": "buses"},
        {"label": "VEHICLE_TYPE", "pattern": "passenger cars"},
        {"label": "VEHICLE_TYPE", "pattern": "M3"},

        # Manufacturers
        {"label": "MANUFACTURER", "pattern": "Volvo"},
        {"label": "MANUFACTURER", "pattern": "Daimler"},
        {"label": "MANUFACTURER", "pattern": "Mercedes"},
        {"label": "MANUFACTURER", "pattern": "Tesla"},

        # Components
        {"label": "COMPONENT", "pattern": "radar sensors"},
        {"label": "COMPONENT", "pattern": "LiDAR sensors"},
        {"label": "COMPONENT", "pattern": "control units"},
        {"label": "COMPONENT", "pattern": "actuators"},

        # Testing Standards
        {"label": "TESTING_STANDARD", "pattern": "stationary target tests"},
        {"label": "TESTING_STANDARD", "pattern": "dynamic target detection"},

        # Geographic Regions
        {"label": "GEOGRAPHIC_REGION", "pattern": "European Union"},
        {"label": "GEOGRAPHIC_REGION", "pattern": "Japan"},
        {"label": "GEOGRAPHIC_REGION", "pattern": "United States"},

        # Certification Bodies
        {"label": "CERTIFICATION_BODY", "pattern": "TÜV Süd"},
        {"label": "CERTIFICATION_BODY", "pattern": "UNECE"},
        {"label": "CERTIFICATION_BODY", "pattern": "KBA"},
        {"label": "CERTIFICATION_BODY", "pattern": "NHTSA"},

        # Approval Authorities
        {"label": "APPROVAL_AUTHORITY", "pattern": "KBA"},
        {"label": "APPROVAL_AUTHORITY", "pattern": "NHTSA"},
    ]

    ruler.add_patterns(patterns)

# Add the custom entity patterns
add_custom_entities(nlp)

# Function to process text and extract entities
def extract_entities(file_path, output_path):
    with open(file_path, "r", encoding="utf-8") as file:
        text = file.read()

    # Process the text using Spacy's pipeline
    doc = nlp(text)

    # Extract entities
    extracted_entities = [(ent.text, ent.label_) for ent in doc.ents]

    # Save extracted entities
    with open(output_path, "w", encoding="utf-8") as file:
        for entity, label in extracted_entities:
            file.write(f"{entity} -> {label}\n")

    return output_path

# Define file paths
input_text_file = "/content/drive/MyDrive/KnowledgeGraphResults/ready_text.txt"
output_entities_file = "/content/drive/MyDrive/KnowledgeGraphResults/extracted_entities.txt"

# Extract and save entities
extracted_entities_path = extract_entities(input_text_file, output_entities_file)

# Return path to extracted entities
extracted_entities_path
# Out:
# '/content/drive/MyDrive/KnowledgeGraphResults/extracted_entities.txt'

# %%
import spacy
from spacy.pipeline import EntityRuler
import re

# Load Spacy transformer model
nlp = spacy.load("en_core_web_trf")

# Function to add improved entity patterns
def add_improved_entities(nlp):
    ruler = nlp.add_pipe("entity_ruler", before="ner", config={"overwrite_ents": True})

    patterns = [
        # Regulations (Explicitly Define Instead of Relying on Default "LAW")
        {"label": "REGULATION", "pattern": "R131"},
        {"label": "REGULATION", "pattern": "UNECE R131"},
        {"label": "REGULATION", "pattern": "Regulation 48"},
        {"label": "REGULATION", "pattern": "UNECE R48"},

        # AEBS Technology
        {"label": "AEBS_TECHNOLOGY", "pattern": "Advanced Emergency Braking System"},
        {"label": "AEBS_TECHNOLOGY", "pattern": "AEBS"},
        {"label": "AEBS_TECHNOLOGY", "pattern": "afs"},  # Fix misclassification

        # Vehicle Types (Override Incorrect "PRODUCT" Classification)
        {"label": "VEHICLE_TYPE", "pattern": "trucks"},
        {"label": "VEHICLE_TYPE", "pattern": "buses"},
        {"label": "VEHICLE_TYPE", "pattern": "passenger cars"},
        {"label": "VEHICLE_TYPE", "pattern": "M3"},
        {"label": "VEHICLE_TYPE", "pattern": "N2"},
        {"label": "VEHICLE_TYPE", "pattern": "N3"},

        # Manufacturers
        {"label": "MANUFACTURER", "pattern": "Volvo"},
        {"label": "MANUFACTURER", "pattern": "Daimler"},
        {"label": "MANUFACTURER", "pattern": "Mercedes"},
        {"label": "MANUFACTURER", "pattern": "Tesla"},

        # Components
        {"label": "COMPONENT", "pattern": "radar sensors"},
        {"label": "COMPONENT", "pattern": "LiDAR sensors"},
        {"label": "COMPONENT", "pattern": "control units"},
        {"label": "COMPONENT", "pattern": "actuators"},

        # Testing Standards
        {"label": "TESTING_STANDARD", "pattern": "stationary target tests"},
        {"label": "TESTING_STANDARD", "pattern": "dynamic target detection"},

        # Geographic Regions
        {"label": "GEOGRAPHIC_REGION", "pattern": "European Union"},
        {"label": "GEOGRAPHIC_REGION", "pattern": "Japan"},
        {"label": "GEOGRAPHIC_REGION", "pattern": "United States"},

        # Certification Bodies
        {"label": "CERTIFICATION_BODY", "pattern": "TÜV Süd"},
        {"label": "CERTIFICATION_BODY", "pattern": "UNECE"},
        {"label": "CERTIFICATION_BODY", "pattern": "KBA"},
        {"label": "CERTIFICATION_BODY", "pattern": "NHTSA"},

        # Approval Authorities
        {"label": "APPROVAL_AUTHORITY", "pattern": "KBA"},
        {"label": "APPROVAL_AUTHORITY", "pattern": "NHTSA"},
    ]

    ruler.add_patterns(patterns)

# Add improved entity patterns
add_improved_entities(nlp)

# Function to remove unwanted numbers and filter entities
def filter_entities(file_path, output_path):
    with open(file_path, "r", encoding="utf-8") as file:
        text = file.read()

    # Process the text using Spacy's pipeline
    doc = nlp(text)

    filtered_entities = []

    for ent in doc.ents:
        # Remove isolated numbers that are likely paragraph references
        if ent.label_ == "CARDINAL" and re.match(r"^\d+$", ent.text):
            continue
        # Ignore meaningless paragraph references (e.g., "paragraph 5.2.6.3")
        if re.match(r"paragraph\s*\d+(\.\d+)*", ent.text, re.IGNORECASE):
            continue
        # Ignore single-word numbers
        if ent.text.lower() in {"one", "two", "three", "four", "five", "six", "seven", "eight", "nine", "ten"}:
            continue

        filtered_entities.append((ent.text, ent.label_))

    # Save filtered entities
    with open(output_path, "w", encoding="utf-8") as file:
        for entity, label in filtered_entities:
            file.write(f"{entity} -> {label}\n")

    return output_path

# Define file paths
input_text_file = "/content/drive/MyDrive/KnowledgeGraphResults/ready_text.txt"
filtered_entities_file =  "/content/drive/MyDrive/KnowledgeGraphResults/extracted_entities1.txt"

# Extract and save improved entities
filtered_entities_path = filter_entities(input_text_file, filtered_entities_file)

# Return path to extracted entities
filtered_entities_path
# Out:
# '/content/drive/MyDrive/KnowledgeGraphResults/extracted_entities1.txt'

# %%
import spacy
from spacy.pipeline import EntityRuler
import re

# Load Spacy transformer model
nlp = spacy.load("en_core_web_trf")

# Function to add improved entity patterns
def add_improved_entities(nlp):
    ruler = nlp.add_pipe("entity_ruler", before="ner", config={"overwrite_ents": True})

    patterns = [
        # Regulations
        {"label": "REGULATION", "pattern": "R131"},
        {"label": "REGULATION", "pattern": "UNECE R131"},
        {"label": "REGULATION", "pattern": "Regulation 48"},
        {"label": "REGULATION", "pattern": "UNECE R48"},

        # AEBS Technology
        {"label": "AEBS_TECHNOLOGY", "pattern": "Advanced Emergency Braking System"},
        {"label": "AEBS_TECHNOLOGY", "pattern": "AEBS"},
        {"label": "AEBS_TECHNOLOGY", "pattern": "afs"},

        # Vehicle Types (Force Correct Classification)
        {"label": "VEHICLE_TYPE", "pattern": "M3"},
        {"label": "VEHICLE_TYPE", "pattern": "N2"},
        {"label": "VEHICLE_TYPE", "pattern": "N3"},
        {"label": "VEHICLE_TYPE", "pattern": "trucks"},
        {"label": "VEHICLE_TYPE", "pattern": "buses"},
        {"label": "VEHICLE_TYPE", "pattern": "passenger cars"},

        # Manufacturers
        {"label": "MANUFACTURER", "pattern": "Volvo"},
        {"label": "MANUFACTURER", "pattern": "Daimler"},
        {"label": "MANUFACTURER", "pattern": "Mercedes"},
        {"label": "MANUFACTURER", "pattern": "Tesla"},

        # Components
        {"label": "COMPONENT", "pattern": "radar sensors"},
        {"label": "COMPONENT", "pattern": "LiDAR sensors"},
        {"label": "COMPONENT", "pattern": "control units"},
        {"label": "COMPONENT", "pattern": "actuators"},

        # Testing Standards
        {"label": "TESTING_STANDARD", "pattern": "stationary target tests"},
        {"label": "TESTING_STANDARD", "pattern": "dynamic target detection"},

        # Geographic Regions
        {"label": "GEOGRAPHIC_REGION", "pattern": "European Union"},
        {"label": "GEOGRAPHIC_REGION", "pattern": "Japan"},
        {"label": "GEOGRAPHIC_REGION", "pattern": "United States"},

        # Certification Bodies
        {"label": "CERTIFICATION_BODY", "pattern": "TÜV Süd"},
        {"label": "CERTIFICATION_BODY", "pattern": "UNECE"},
        {"label": "CERTIFICATION_BODY", "pattern": "KBA"},
        {"label": "CERTIFICATION_BODY", "pattern": "NHTSA"},
    ]

    ruler.add_patterns(patterns)

# Add improved entity patterns
add_improved_entities(nlp)

# Function to remove unwanted numbers, paragraph references, and irrelevant entities
def filter_entities(file_path, output_path):
    with open(file_path, "r", encoding="utf-8") as file:
        text = file.read()

    # Process the text using Spacy's pipeline
    doc = nlp(text)

    filtered_entities = []

    for ent in doc.ents:
        # Remove standalone numbers that are likely paragraph references
        if ent.label_ in ["CARDINAL", "QUANTITY", "PERCENT"] and re.match(r"^\d+(\.\d+)?$", ent.text):
            continue
        # Ignore meaningless paragraph references (e.g., "paragraph 5.2.6.3")
        if re.match(r"paragraph\s*\d+(\.\d+)*", ent.text, re.IGNORECASE):
            continue
        # Remove unexpected LAW or WORK_OF_ART classifications
        if ent.label_ in ["LAW", "WORK_OF_ART"] and not ent.text.startswith("Regulation"):
            continue

        filtered_entities.append((ent.text, ent.label_))

    # Save filtered entities
    with open(output_path, "w", encoding="utf-8") as file:
        for entity, label in filtered_entities:
            file.write(f"{entity} -> {label}\n")

    return output_path

# Define file paths
input_text_file = "/content/drive/MyDrive/KnowledgeGraphResults/ready_text.txt"
filtered_entities_file =  "/content/drive/MyDrive/KnowledgeGraphResults/extracted_entities2.txt"

# Extract and save improved entities
filtered_entities_path = filter_entities(input_text_file, filtered_entities_file)

# Return path to extracted entities
filtered_entities_path
# Out:
# /usr/local/lib/python3.11/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# /usr/local/lib/python3.11/dist-packages/thinc/shims/pytorch.py:253: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(filelike, map_location=device))
# /usr/local/lib/python3.11/dist-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# '/content/drive/MyDrive/KnowledgeGraphResults/extracted_entities2.txt'
